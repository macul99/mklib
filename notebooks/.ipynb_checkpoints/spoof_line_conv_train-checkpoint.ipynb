# %%
import tensorflow as tf
import numpy as np
import os
from os.path import isdir
from os import mkdir
from shutil import copyfile
import time
from PIL import Image
import pickle
from spoofing_ld_conv.SpoofLineConvTf import SpoofLineConvTf
from tf_spoof.config import net_config_ld_conv as config
config.BASE_PATH = '/media/macul/black/spoof_db/train_test_all/tfrecord'
config.CFG_PATH = '/home/macul/libraries/mk_utils/tf_spoof/config'
config.OUT_PATH = '/home/macul/libraries/mk_utils/tf_spoof/output1'
config.TRAIN_REC = [os.path.sep.join([config.BASE_PATH, "train5-00000-of-00005"]),
                    os.path.sep.join([config.BASE_PATH, "train5-00001-of-00005"]),
                    os.path.sep.join([config.BASE_PATH, "train5-00002-of-00005"]),
                    os.path.sep.join([config.BASE_PATH, "train5-00003-of-00005"]),
                    os.path.sep.join([config.BASE_PATH, "train5-00004-of-00005"]),]
config.VAL_REC = [os.path.sep.join([config.BASE_PATH, "validation5-00000-of-00005"]),
                  os.path.sep.join([config.BASE_PATH, "validation5-00001-of-00005"]),
                  os.path.sep.join([config.BASE_PATH, "validation5-00002-of-00005"]),
                  os.path.sep.join([config.BASE_PATH, "validation5-00003-of-00005"]),
                  os.path.sep.join([config.BASE_PATH, "validation5-00004-of-00005"])]

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = config.DEVICE_IDS
#batchSize = config.BATCH_SIZE * config.NUM_DEVICES

# %%
SpoofVal = SpoofLineConvTf(config)

# backup net_config file
copyfile(config.CFG_PATH+'/net_config_ld_conv.py', os.path.sep.join([SpoofVal.checkpointsPath,'net_config_ld_conv_{}.py'.format(0)]))
# Out:
# '/home/macul/libraries/mk_utils/tf_spoof/output1/train_2/net_config_0.py'

# %%
SpoofVal.train_net(-1)
# Out:
# Train: epoch 0, step 10, inferLoss 1.36, cmpLoss 0.55, totalLoss 2.78, acc 0.367188, time 34.319 sp/s
# Train: epoch 0, step 20, inferLoss 1.08, cmpLoss 0.34, totalLoss 2.20, acc 0.437500, time 28.644 sp/s
# Train: epoch 0, step 30, inferLoss 1.08, cmpLoss 0.29, totalLoss 2.18, acc 0.425781, time 42.871 sp/s
# Train: epoch 0, step 40, inferLoss 1.08, cmpLoss 0.34, totalLoss 2.20, acc 0.421875, time 45.810 sp/s
# Train: epoch 0, step 50, inferLoss 1.03, cmpLoss 0.24, totalLoss 2.07, acc 0.492188, time 25.861 sp/s
# Train: epoch 0, step 60, inferLoss 1.06, cmpLoss 0.28, totalLoss 2.14, acc 0.476562, time 47.801 sp/s
# Train: epoch 0, step 70, inferLoss 1.01, cmpLoss 0.23, totalLoss 2.05, acc 0.421875, time 43.109 sp/s
# Train: epoch 0, step 80, inferLoss 1.03, cmpLoss 0.30, totalLoss 2.09, acc 0.453125, time 48.533 sp/s
# Train: epoch 0, step 90, inferLoss 1.00, cmpLoss 0.28, totalLoss 2.02, acc 0.484375, time 46.611 sp/s
# Train: epoch 0, step 100, inferLoss 0.93, cmpLoss 0.25, totalLoss 1.89, acc 0.515625, time 47.306 sp/s
# Train: epoch 0, step 110, inferLoss 1.00, cmpLoss 0.27, totalLoss 2.03, acc 0.468750, time 44.318 sp/s
# Train: epoch 0, step 120, inferLoss 0.92, cmpLoss 0.20, totalLoss 1.85, acc 0.488281, time 46.138 sp/s
# Train: epoch 0, step 130, inferLoss 0.90, cmpLoss 0.23, totalLoss 1.82, acc 0.554688, time 40.990 sp/s
# Train: epoch 0, step 140, inferLoss 0.85, cmpLoss 0.21, totalLoss 1.72, acc 0.609375, time 38.101 sp/s
# Train: epoch 0, step 150, inferLoss 0.93, cmpLoss 0.25, totalLoss 1.89, acc 0.515625, time 44.744 sp/s
# Train: epoch 0, step 160, inferLoss 0.85, cmpLoss 0.25, totalLoss 1.73, acc 0.570312, time 41.789 sp/s
# Train: epoch 0, step 170, inferLoss 0.86, cmpLoss 0.25, totalLoss 1.74, acc 0.578125, time 32.334 sp/s
# Train: epoch 0, step 180, inferLoss 0.85, cmpLoss 0.24, totalLoss 1.73, acc 0.597656, time 40.562 sp/s
# Train: epoch 0, step 190, inferLoss 0.82, cmpLoss 0.16, totalLoss 1.66, acc 0.640625, time 40.847 sp/s
# Train: epoch 0, step 200, inferLoss 0.84, cmpLoss 0.16, totalLoss 1.70, acc 0.652344, time 44.710 sp/s
# Train: epoch 0, step 210, inferLoss 0.81, cmpLoss 0.19, totalLoss 1.63, acc 0.636719, time 37.709 sp/s
# Train: epoch 0, step 220, inferLoss 0.77, cmpLoss 0.18, totalLoss 1.55, acc 0.667969, time 30.541 sp/s
# Train: epoch 0, step 230, inferLoss 0.78, cmpLoss 0.21, totalLoss 1.58, acc 0.656250, time 45.830 sp/s
# Train: epoch 0, step 240, inferLoss 0.71, cmpLoss 0.21, totalLoss 1.45, acc 0.699219, time 47.883 sp/s
# Train: epoch 0, step 250, inferLoss 0.76, cmpLoss 0.19, totalLoss 1.55, acc 0.664062, time 29.940 sp/s
# Train: epoch 0, step 260, inferLoss 0.88, cmpLoss 0.18, totalLoss 1.77, acc 0.625000, time 20.771 sp/s
# Train: epoch 0, step 270, inferLoss 0.77, cmpLoss 0.22, totalLoss 1.55, acc 0.675781, time 10.963 sp/s
# Train: epoch 0, step 280, inferLoss 0.77, cmpLoss 0.17, totalLoss 1.56, acc 0.679688, time 10.261 sp/s
# Train: epoch 0, step 290, inferLoss 0.69, cmpLoss 0.19, totalLoss 1.40, acc 0.683594, time 8.546 sp/s
# Train: epoch 0, step 300, inferLoss 0.78, cmpLoss 0.17, totalLoss 1.57, acc 0.683594, time 14.133 sp/s
# Train: epoch 0, step 310, inferLoss 0.71, cmpLoss 0.20, totalLoss 1.44, acc 0.683594, time 12.371 sp/s
# Train: epoch 0, step 320, inferLoss 0.68, cmpLoss 0.20, totalLoss 1.38, acc 0.718750, time 13.517 sp/s
# Train: epoch 0, step 330, inferLoss 0.75, cmpLoss 0.18, totalLoss 1.51, acc 0.664062, time 26.423 sp/s
# Train: epoch 0, step 340, inferLoss 0.77, cmpLoss 0.17, totalLoss 1.55, acc 0.660156, time 18.556 sp/s
# Train: epoch 0, step 350, inferLoss 0.69, cmpLoss 0.20, totalLoss 1.40, acc 0.679688, time 24.519 sp/s
# Train: epoch 0, step 360, inferLoss 0.74, cmpLoss 0.17, totalLoss 1.50, acc 0.648438, time 22.235 sp/s
# Train: epoch 0, step 370, inferLoss 0.74, cmpLoss 0.21, totalLoss 1.50, acc 0.664062, time 24.824 sp/s
# Train: epoch 0, step 380, inferLoss 0.73, cmpLoss 0.18, totalLoss 1.48, acc 0.675781, time 23.819 sp/s
# Train: epoch 0, step 390, inferLoss 0.75, cmpLoss 0.18, totalLoss 1.52, acc 0.671875, time 22.915 sp/s
# Train: epoch 0, step 400, inferLoss 0.67, cmpLoss 0.16, totalLoss 1.35, acc 0.722656, time 21.955 sp/s
# Train: epoch 0, step 410, inferLoss 0.68, cmpLoss 0.16, totalLoss 1.38, acc 0.710938, time 23.478 sp/s
# Train: epoch 0, step 420, inferLoss 0.72, cmpLoss 0.22, totalLoss 1.45, acc 0.667969, time 17.074 sp/s
# Train: epoch 0, step 430, inferLoss 0.70, cmpLoss 0.20, totalLoss 1.42, acc 0.648438, time 24.583 sp/s
# Train: epoch 0, step 440, inferLoss 0.70, cmpLoss 0.17, totalLoss 1.42, acc 0.695312, time 18.771 sp/s
# Train: epoch 0, step 450, inferLoss 0.71, cmpLoss 0.16, totalLoss 1.43, acc 0.660156, time 16.293 sp/s
# Train: epoch 0, step 460, inferLoss 0.81, cmpLoss 0.19, totalLoss 1.64, acc 0.644531, time 18.720 sp/s
# Train: epoch 0, step 470, inferLoss 0.69, cmpLoss 0.17, totalLoss 1.39, acc 0.695312, time 15.620 sp/s
# Train: epoch 0, step 480, inferLoss 0.60, cmpLoss 0.16, totalLoss 1.21, acc 0.765625, time 14.101 sp/s
# Train: epoch 0, step 490, inferLoss 0.70, cmpLoss 0.18, totalLoss 1.41, acc 0.699219, time 26.193 sp/s
# Train: epoch 0, step 500, inferLoss 0.73, cmpLoss 0.21, totalLoss 1.48, acc 0.632812, time 26.337 sp/s
# Train: epoch 0, step 510, inferLoss 0.58, cmpLoss 0.18, totalLoss 1.18, acc 0.753906, time 20.099 sp/s
# Train: epoch 0, step 520, inferLoss 0.69, cmpLoss 0.17, totalLoss 1.40, acc 0.656250, time 22.789 sp/s
# Train: epoch 0, step 530, inferLoss 0.66, cmpLoss 0.16, totalLoss 1.34, acc 0.675781, time 21.686 sp/s
# Train: epoch 0, step 540, inferLoss 0.71, cmpLoss 0.21, totalLoss 1.44, acc 0.734375, time 26.153 sp/s
# Train: epoch 0, step 550, inferLoss 0.77, cmpLoss 0.17, totalLoss 1.56, acc 0.667969, time 20.138 sp/s
# Train: epoch 0, step 560, inferLoss 0.58, cmpLoss 0.19, totalLoss 1.19, acc 0.750000, time 15.363 sp/s
# End of epoch 0
# ######### Save checkpoint: /home/macul/libraries/mk_utils/tf_spoof/output1/train_2/train_2_0.ckpt
# $$$$$$$$ Validation: epoch 0, accuracy is 0.784993
# Train: epoch 1, step 570, inferLoss 0.66, cmpLoss 0.16, totalLoss 1.34, acc 0.718750, time 25.048 sp/s
# Train: epoch 1, step 580, inferLoss 0.63, cmpLoss 0.21, totalLoss 1.28, acc 0.742188, time 26.514 sp/s
# Train: epoch 1, step 590, inferLoss 0.66, cmpLoss 0.17, totalLoss 1.33, acc 0.667969, time 25.198 sp/s
# Train: epoch 1, step 600, inferLoss 0.71, cmpLoss 0.16, totalLoss 1.44, acc 0.691406, time 15.402 sp/s
# Train: epoch 1, step 610, inferLoss 0.67, cmpLoss 0.20, totalLoss 1.37, acc 0.687500, time 17.263 sp/s
# Train: epoch 1, step 620, inferLoss 0.62, cmpLoss 0.18, totalLoss 1.26, acc 0.710938, time 22.196 sp/s
# Train: epoch 1, step 630, inferLoss 0.73, cmpLoss 0.23, totalLoss 1.49, acc 0.632812, time 21.346 sp/s
# Train: epoch 1, step 640, inferLoss 0.65, cmpLoss 0.17, totalLoss 1.32, acc 0.691406, time 21.632 sp/s
# Train: epoch 1, step 650, inferLoss 0.66, cmpLoss 0.13, totalLoss 1.33, acc 0.699219, time 19.374 sp/s
# Train: epoch 1, step 660, inferLoss 0.63, cmpLoss 0.20, totalLoss 1.29, acc 0.730469, time 22.990 sp/s
# Train: epoch 1, step 670, inferLoss 0.62, cmpLoss 0.17, totalLoss 1.26, acc 0.722656, time 24.283 sp/s
# Train: epoch 1, step 680, inferLoss 0.60, cmpLoss 0.15, totalLoss 1.21, acc 0.699219, time 20.047 sp/s
# Train: epoch 1, step 690, inferLoss 0.71, cmpLoss 0.16, totalLoss 1.44, acc 0.675781, time 18.599 sp/s
# Train: epoch 1, step 700, inferLoss 0.58, cmpLoss 0.18, totalLoss 1.18, acc 0.707031, time 21.248 sp/s
# Train: epoch 1, step 710, inferLoss 0.61, cmpLoss 0.20, totalLoss 1.25, acc 0.722656, time 16.574 sp/s
# Train: epoch 1, step 720, inferLoss 0.64, cmpLoss 0.18, totalLoss 1.30, acc 0.714844, time 13.420 sp/s
# Train: epoch 1, step 730, inferLoss 0.56, cmpLoss 0.15, totalLoss 1.13, acc 0.726562, time 15.544 sp/s
# Train: epoch 1, step 740, inferLoss 0.68, cmpLoss 0.18, totalLoss 1.38, acc 0.683594, time 16.178 sp/s
# Train: epoch 1, step 750, inferLoss 0.58, cmpLoss 0.17, totalLoss 1.18, acc 0.726562, time 22.157 sp/s
# Train: epoch 1, step 760, inferLoss 0.60, cmpLoss 0.19, totalLoss 1.22, acc 0.722656, time 14.455 sp/s
# Train: epoch 1, step 770, inferLoss 0.59, cmpLoss 0.22, totalLoss 1.21, acc 0.738281, time 23.351 sp/s
# Train: epoch 1, step 780, inferLoss 0.56, cmpLoss 0.15, totalLoss 1.13, acc 0.750000, time 19.114 sp/s
# Train: epoch 1, step 790, inferLoss 0.69, cmpLoss 0.13, totalLoss 1.39, acc 0.652344, time 25.236 sp/s
# Train: epoch 1, step 800, inferLoss 0.55, cmpLoss 0.21, totalLoss 1.12, acc 0.734375, time 23.995 sp/s
# Train: epoch 1, step 810, inferLoss 0.56, cmpLoss 0.17, totalLoss 1.14, acc 0.730469, time 26.312 sp/s
# Train: epoch 1, step 820, inferLoss 0.60, cmpLoss 0.16, totalLoss 1.21, acc 0.734375, time 27.930 sp/s
# Train: epoch 1, step 830, inferLoss 0.66, cmpLoss 0.16, totalLoss 1.33, acc 0.675781, time 27.880 sp/s
# Train: epoch 1, step 840, inferLoss 0.56, cmpLoss 0.18, totalLoss 1.13, acc 0.738281, time 32.748 sp/s
# Train: epoch 1, step 850, inferLoss 0.62, cmpLoss 0.18, totalLoss 1.26, acc 0.722656, time 28.526 sp/s
# Train: epoch 1, step 860, inferLoss 0.54, cmpLoss 0.18, totalLoss 1.11, acc 0.750000, time 38.197 sp/s
# Train: epoch 1, step 870, inferLoss 0.60, cmpLoss 0.18, totalLoss 1.21, acc 0.718750, time 40.163 sp/s
# Train: epoch 1, step 880, inferLoss 0.58, cmpLoss 0.15, totalLoss 1.18, acc 0.730469, time 39.673 sp/s
# Train: epoch 1, step 890, inferLoss 0.57, cmpLoss 0.16, totalLoss 1.15, acc 0.738281, time 35.678 sp/s
# Train: epoch 1, step 900, inferLoss 0.59, cmpLoss 0.15, totalLoss 1.20, acc 0.757812, time 37.122 sp/s
# Train: epoch 1, step 910, inferLoss 0.62, cmpLoss 0.16, totalLoss 1.26, acc 0.664062, time 29.339 sp/s
# Train: epoch 1, step 920, inferLoss 0.60, cmpLoss 0.18, totalLoss 1.23, acc 0.738281, time 40.437 sp/s
# Train: epoch 1, step 930, inferLoss 0.62, cmpLoss 0.16, totalLoss 1.26, acc 0.718750, time 33.913 sp/s
# Train: epoch 1, step 940, inferLoss 0.54, cmpLoss 0.15, totalLoss 1.10, acc 0.734375, time 32.743 sp/s
# Train: epoch 1, step 950, inferLoss 0.65, cmpLoss 0.15, totalLoss 1.32, acc 0.703125, time 25.208 sp/s
# Train: epoch 1, step 960, inferLoss 0.59, cmpLoss 0.18, totalLoss 1.20, acc 0.753906, time 25.755 sp/s
# Train: epoch 1, step 970, inferLoss 0.57, cmpLoss 0.17, totalLoss 1.16, acc 0.714844, time 23.911 sp/s
# Train: epoch 1, step 980, inferLoss 0.59, cmpLoss 0.20, totalLoss 1.20, acc 0.707031, time 14.655 sp/s
# Train: epoch 1, step 990, inferLoss 0.58, cmpLoss 0.18, totalLoss 1.17, acc 0.703125, time 17.532 sp/s
# Train: epoch 1, step 1000, inferLoss 0.65, cmpLoss 0.17, totalLoss 1.32, acc 0.667969, time 16.943 sp/s
# Train: epoch 1, step 1010, inferLoss 0.68, cmpLoss 0.17, totalLoss 1.38, acc 0.687500, time 21.901 sp/s
# Train: epoch 1, step 1020, inferLoss 0.51, cmpLoss 0.11, totalLoss 1.04, acc 0.746094, time 17.863 sp/s
# Train: epoch 1, step 1030, inferLoss 0.54, cmpLoss 0.15, totalLoss 1.09, acc 0.753906, time 16.569 sp/s
# Train: epoch 1, step 1040, inferLoss 0.61, cmpLoss 0.17, totalLoss 1.24, acc 0.710938, time 12.270 sp/s
# Train: epoch 1, step 1050, inferLoss 0.55, cmpLoss 0.20, totalLoss 1.12, acc 0.769531, time 15.227 sp/s
# Train: epoch 1, step 1060, inferLoss 0.72, cmpLoss 0.20, totalLoss 1.45, acc 0.648438, time 12.268 sp/s
# Train: epoch 1, step 1070, inferLoss 0.61, cmpLoss 0.18, totalLoss 1.25, acc 0.707031, time 12.411 sp/s
# Train: epoch 1, step 1080, inferLoss 0.62, cmpLoss 0.15, totalLoss 1.25, acc 0.722656, time 18.287 sp/s
# Train: epoch 1, step 1090, inferLoss 0.58, cmpLoss 0.16, totalLoss 1.18, acc 0.714844, time 18.631 sp/s
# Train: epoch 1, step 1100, inferLoss 0.68, cmpLoss 0.16, totalLoss 1.37, acc 0.652344, time 22.656 sp/s
# Train: epoch 1, step 1110, inferLoss 0.60, cmpLoss 0.19, totalLoss 1.23, acc 0.691406, time 18.340 sp/s
# Train: epoch 1, step 1120, inferLoss 0.62, cmpLoss 0.16, totalLoss 1.26, acc 0.718750, time 11.094 sp/s
# Train: epoch 1, step 1130, inferLoss 0.61, cmpLoss 0.15, totalLoss 1.23, acc 0.742188, time 9.763 sp/s
# End of epoch 1
# ######### Save checkpoint: /home/macul/libraries/mk_utils/tf_spoof/output1/train_2/train_2_1.ckpt
# $$$$$$$$ Validation: epoch 1, accuracy is 0.896123
# Train: epoch 2, step 1140, inferLoss 0.63, cmpLoss 0.18, totalLoss 1.29, acc 0.679688, time 29.199 sp/s
# Train: epoch 2, step 1150, inferLoss 0.55, cmpLoss 0.14, totalLoss 1.10, acc 0.769531, time 18.828 sp/s
# Train: epoch 2, step 1160, inferLoss 0.54, cmpLoss 0.19, totalLoss 1.10, acc 0.757812, time 16.491 sp/s
# Train: epoch 2, step 1170, inferLoss 0.61, cmpLoss 0.15, totalLoss 1.23, acc 0.714844, time 25.058 sp/s
# Train: epoch 2, step 1180, inferLoss 0.55, cmpLoss 0.17, totalLoss 1.12, acc 0.730469, time 15.967 sp/s
# Train: epoch 2, step 1190, inferLoss 0.54, cmpLoss 0.13, totalLoss 1.10, acc 0.750000, time 23.042 sp/s
# Train: epoch 2, step 1200, inferLoss 0.50, cmpLoss 0.14, totalLoss 1.02, acc 0.757812, time 19.258 sp/s
# Train: epoch 2, step 1210, inferLoss 0.78, cmpLoss 0.19, totalLoss 1.57, acc 0.671875, time 24.061 sp/s
# Train: epoch 2, step 1220, inferLoss 0.71, cmpLoss 0.16, totalLoss 1.44, acc 0.664062, time 28.961 sp/s
# Train: epoch 2, step 1230, inferLoss 0.55, cmpLoss 0.14, totalLoss 1.11, acc 0.765625, time 19.055 sp/s
# Train: epoch 2, step 1240, inferLoss 0.58, cmpLoss 0.18, totalLoss 1.18, acc 0.695312, time 24.524 sp/s
# Train: epoch 2, step 1250, inferLoss 0.57, cmpLoss 0.20, totalLoss 1.17, acc 0.707031, time 15.622 sp/s
# Train: epoch 2, step 1260, inferLoss 0.60, cmpLoss 0.16, totalLoss 1.21, acc 0.750000, time 20.503 sp/s
# Train: epoch 2, step 1270, inferLoss 0.63, cmpLoss 0.14, totalLoss 1.28, acc 0.714844, time 17.602 sp/s
# Train: epoch 2, step 1280, inferLoss 0.64, cmpLoss 0.16, totalLoss 1.30, acc 0.656250, time 16.090 sp/s
# Train: epoch 2, step 1290, inferLoss 0.61, cmpLoss 0.19, totalLoss 1.23, acc 0.722656, time 13.304 sp/s
# Train: epoch 2, step 1300, inferLoss 0.54, cmpLoss 0.15, totalLoss 1.09, acc 0.718750, time 15.230 sp/s
# Train: epoch 2, step 1310, inferLoss 0.64, cmpLoss 0.16, totalLoss 1.29, acc 0.703125, time 16.755 sp/s
# Train: epoch 2, step 1320, inferLoss 0.59, cmpLoss 0.15, totalLoss 1.20, acc 0.734375, time 13.249 sp/s
# Train: epoch 2, step 1330, inferLoss 0.64, cmpLoss 0.18, totalLoss 1.30, acc 0.718750, time 17.127 sp/s
# Train: epoch 2, step 1340, inferLoss 0.62, cmpLoss 0.15, totalLoss 1.25, acc 0.738281, time 19.510 sp/s
# Train: epoch 2, step 1350, inferLoss 0.55, cmpLoss 0.17, totalLoss 1.12, acc 0.765625, time 15.502 sp/s
# Train: epoch 2, step 1360, inferLoss 0.59, cmpLoss 0.17, totalLoss 1.20, acc 0.726562, time 14.917 sp/s
# Train: epoch 2, step 1370, inferLoss 0.55, cmpLoss 0.17, totalLoss 1.11, acc 0.734375, time 18.818 sp/s
# Train: epoch 2, step 1380, inferLoss 0.56, cmpLoss 0.16, totalLoss 1.14, acc 0.730469, time 16.002 sp/s
# Train: epoch 2, step 1390, inferLoss 0.50, cmpLoss 0.15, totalLoss 1.01, acc 0.789062, time 23.704 sp/s
# Train: epoch 2, step 1400, inferLoss 0.59, cmpLoss 0.17, totalLoss 1.20, acc 0.714844, time 12.779 sp/s
# Train: epoch 2, step 1410, inferLoss 0.63, cmpLoss 0.14, totalLoss 1.27, acc 0.710938, time 16.014 sp/s
# Train: epoch 2, step 1420, inferLoss 0.57, cmpLoss 0.18, totalLoss 1.16, acc 0.707031, time 17.146 sp/s
# Train: epoch 2, step 1430, inferLoss 0.57, cmpLoss 0.16, totalLoss 1.16, acc 0.710938, time 16.048 sp/s
# Train: epoch 2, step 1440, inferLoss 0.55, cmpLoss 0.16, totalLoss 1.12, acc 0.726562, time 14.409 sp/s
# Train: epoch 2, step 1450, inferLoss 0.64, cmpLoss 0.17, totalLoss 1.29, acc 0.714844, time 12.757 sp/s
# Train: epoch 2, step 1460, inferLoss 0.52, cmpLoss 0.17, totalLoss 1.06, acc 0.710938, time 14.907 sp/s
# Train: epoch 2, step 1470, inferLoss 0.52, cmpLoss 0.14, totalLoss 1.04, acc 0.718750, time 20.869 sp/s
# Train: epoch 2, step 1480, inferLoss 0.54, cmpLoss 0.13, totalLoss 1.10, acc 0.726562, time 17.829 sp/s
# Train: epoch 2, step 1490, inferLoss 0.56, cmpLoss 0.14, totalLoss 1.13, acc 0.738281, time 17.658 sp/s
# Train: epoch 2, step 1500, inferLoss 0.54, cmpLoss 0.14, totalLoss 1.10, acc 0.738281, time 23.964 sp/s
# Train: epoch 2, step 1510, inferLoss 0.54, cmpLoss 0.14, totalLoss 1.09, acc 0.746094, time 24.365 sp/s
# Train: epoch 2, step 1520, inferLoss 0.56, cmpLoss 0.12, totalLoss 1.13, acc 0.726562, time 24.997 sp/s
# Train: epoch 2, step 1530, inferLoss 0.58, cmpLoss 0.16, totalLoss 1.18, acc 0.699219, time 26.941 sp/s
# Train: epoch 2, step 1540, inferLoss 0.50, cmpLoss 0.15, totalLoss 1.02, acc 0.765625, time 26.389 sp/s
# Train: epoch 2, step 1550, inferLoss 0.56, cmpLoss 0.15, totalLoss 1.13, acc 0.714844, time 30.556 sp/s
# Train: epoch 2, step 1560, inferLoss 0.56, cmpLoss 0.13, totalLoss 1.14, acc 0.742188, time 38.449 sp/s
# Train: epoch 2, step 1570, inferLoss 0.57, cmpLoss 0.16, totalLoss 1.16, acc 0.757812, time 33.196 sp/s
# Train: epoch 2, step 1580, inferLoss 0.56, cmpLoss 0.17, totalLoss 1.15, acc 0.699219, time 39.053 sp/s
# Train: epoch 2, step 1590, inferLoss 0.54, cmpLoss 0.15, totalLoss 1.09, acc 0.726562, time 31.805 sp/s
# Train: epoch 2, step 1600, inferLoss 0.63, cmpLoss 0.16, totalLoss 1.28, acc 0.703125, time 30.002 sp/s
# Train: epoch 2, step 1610, inferLoss 0.59, cmpLoss 0.16, totalLoss 1.21, acc 0.695312, time 36.849 sp/s
# Train: epoch 2, step 1620, inferLoss 0.51, cmpLoss 0.15, totalLoss 1.04, acc 0.726562, time 35.443 sp/s
# Train: epoch 2, step 1630, inferLoss 0.58, cmpLoss 0.16, totalLoss 1.17, acc 0.675781, time 40.163 sp/s
# Train: epoch 2, step 1640, inferLoss 0.52, cmpLoss 0.16, totalLoss 1.06, acc 0.761719, time 22.685 sp/s
# Train: epoch 2, step 1650, inferLoss 0.50, cmpLoss 0.15, totalLoss 1.02, acc 0.753906, time 31.140 sp/s
# Train: epoch 2, step 1660, inferLoss 0.52, cmpLoss 0.12, totalLoss 1.04, acc 0.773438, time 38.543 sp/s
# Train: epoch 2, step 1670, inferLoss 0.53, cmpLoss 0.14, totalLoss 1.08, acc 0.746094, time 41.608 sp/s
# Train: epoch 2, step 1680, inferLoss 0.58, cmpLoss 0.11, totalLoss 1.18, acc 0.734375, time 33.631 sp/s
# Train: epoch 2, step 1690, inferLoss 0.51, cmpLoss 0.15, totalLoss 1.04, acc 0.785156, time 23.582 sp/s
# End of epoch 2
# ######### Save checkpoint: /home/macul/libraries/mk_utils/tf_spoof/output1/train_2/train_2_2.ckpt
# $$$$$$$$ Validation: epoch 2, accuracy is 0.880435
# Train: epoch 3, step 1700, inferLoss 0.53, cmpLoss 0.12, totalLoss 1.06, acc 0.761719, time 17.083 sp/s
# Train: epoch 3, step 1710, inferLoss 0.53, cmpLoss 0.15, totalLoss 1.07, acc 0.753906, time 21.428 sp/s
# Train: epoch 3, step 1720, inferLoss 0.57, cmpLoss 0.14, totalLoss 1.16, acc 0.730469, time 29.083 sp/s
# Train: epoch 3, step 1730, inferLoss 0.54, cmpLoss 0.16, totalLoss 1.09, acc 0.738281, time 23.593 sp/s
# Train: epoch 3, step 1740, inferLoss 0.54, cmpLoss 0.16, totalLoss 1.10, acc 0.753906, time 26.176 sp/s
# Train: epoch 3, step 1750, inferLoss 0.50, cmpLoss 0.14, totalLoss 1.02, acc 0.757812, time 19.372 sp/s
# Train: epoch 3, step 1760, inferLoss 0.59, cmpLoss 0.13, totalLoss 1.19, acc 0.714844, time 18.068 sp/s
# Train: epoch 3, step 1770, inferLoss 0.63, cmpLoss 0.13, totalLoss 1.27, acc 0.710938, time 20.637 sp/s
# Train: epoch 3, step 1780, inferLoss 0.51, cmpLoss 0.13, totalLoss 1.04, acc 0.746094, time 19.579 sp/s
# Train: epoch 3, step 1790, inferLoss 0.59, cmpLoss 0.15, totalLoss 1.19, acc 0.695312, time 19.798 sp/s
# Train: epoch 3, step 1800, inferLoss 0.54, cmpLoss 0.11, totalLoss 1.10, acc 0.734375, time 18.886 sp/s
# Train: epoch 3, step 1810, inferLoss 0.59, cmpLoss 0.14, totalLoss 1.20, acc 0.683594, time 19.775 sp/s
# Train: epoch 3, step 1820, inferLoss 0.57, cmpLoss 0.13, totalLoss 1.16, acc 0.722656, time 19.890 sp/s
# Train: epoch 3, step 1830, inferLoss 0.60, cmpLoss 0.13, totalLoss 1.22, acc 0.738281, time 14.859 sp/s
# Train: epoch 3, step 1840, inferLoss 0.52, cmpLoss 0.13, totalLoss 1.05, acc 0.753906, time 17.901 sp/s
# Train: epoch 3, step 1850, inferLoss 0.54, cmpLoss 0.17, totalLoss 1.11, acc 0.761719, time 12.563 sp/s
# Train: epoch 3, step 1860, inferLoss 0.59, cmpLoss 0.15, totalLoss 1.19, acc 0.667969, time 15.065 sp/s
# Train: epoch 3, step 1870, inferLoss 0.58, cmpLoss 0.15, totalLoss 1.17, acc 0.707031, time 19.390 sp/s
# Train: epoch 3, step 1880, inferLoss 0.59, cmpLoss 0.16, totalLoss 1.21, acc 0.695312, time 18.683 sp/s
# Train: epoch 3, step 1890, inferLoss 0.55, cmpLoss 0.12, totalLoss 1.11, acc 0.726562, time 13.715 sp/s
# Train: epoch 3, step 1900, inferLoss 0.51, cmpLoss 0.15, totalLoss 1.04, acc 0.753906, time 16.327 sp/s
# Train: epoch 3, step 1910, inferLoss 0.47, cmpLoss 0.14, totalLoss 0.95, acc 0.773438, time 17.127 sp/s
# Train: epoch 3, step 1920, inferLoss 0.57, cmpLoss 0.15, totalLoss 1.15, acc 0.714844, time 15.611 sp/s
# Train: epoch 3, step 1930, inferLoss 0.56, cmpLoss 0.14, totalLoss 1.14, acc 0.757812, time 23.418 sp/s
# Train: epoch 3, step 1940, inferLoss 0.53, cmpLoss 0.12, totalLoss 1.07, acc 0.757812, time 17.986 sp/s
# Train: epoch 3, step 1950, inferLoss 0.56, cmpLoss 0.11, totalLoss 1.13, acc 0.750000, time 14.742 sp/s
# Train: epoch 3, step 1960, inferLoss 0.59, cmpLoss 0.15, totalLoss 1.19, acc 0.710938, time 18.500 sp/s
# Train: epoch 3, step 1970, inferLoss 0.53, cmpLoss 0.17, totalLoss 1.08, acc 0.761719, time 21.941 sp/s
# Train: epoch 3, step 1980, inferLoss 0.47, cmpLoss 0.13, totalLoss 0.96, acc 0.777344, time 16.067 sp/s
# Train: epoch 3, step 1990, inferLoss 0.53, cmpLoss 0.12, totalLoss 1.07, acc 0.742188, time 17.748 sp/s
# Train: epoch 3, step 2000, inferLoss 0.58, cmpLoss 0.16, totalLoss 1.17, acc 0.726562, time 13.638 sp/s
# Train: epoch 3, step 2010, inferLoss 0.48, cmpLoss 0.13, totalLoss 0.97, acc 0.757812, time 21.305 sp/s
# Train: epoch 3, step 2020, inferLoss 0.56, cmpLoss 0.19, totalLoss 1.15, acc 0.703125, time 13.288 sp/s
# Train: epoch 3, step 2030, inferLoss 0.53, cmpLoss 0.11, totalLoss 1.07, acc 0.761719, time 22.922 sp/s
# Train: epoch 3, step 2040, inferLoss 0.52, cmpLoss 0.15, totalLoss 1.05, acc 0.773438, time 13.731 sp/s
# Train: epoch 3, step 2050, inferLoss 0.60, cmpLoss 0.11, totalLoss 1.20, acc 0.718750, time 17.839 sp/s
# Train: epoch 3, step 2060, inferLoss 0.54, cmpLoss 0.13, totalLoss 1.09, acc 0.730469, time 18.612 sp/s
# Train: epoch 3, step 2070, inferLoss 0.49, cmpLoss 0.14, totalLoss 1.00, acc 0.746094, time 17.245 sp/s
# Train: epoch 3, step 2080, inferLoss 0.52, cmpLoss 0.14, totalLoss 1.04, acc 0.765625, time 14.588 sp/s
# Train: epoch 3, step 2090, inferLoss 0.57, cmpLoss 0.14, totalLoss 1.15, acc 0.714844, time 16.726 sp/s
# Train: epoch 3, step 2100, inferLoss 0.51, cmpLoss 0.14, totalLoss 1.04, acc 0.738281, time 15.403 sp/s
# Train: epoch 3, step 2110, inferLoss 0.60, cmpLoss 0.13, totalLoss 1.22, acc 0.738281, time 15.896 sp/s
# Train: epoch 3, step 2120, inferLoss 0.55, cmpLoss 0.12, totalLoss 1.11, acc 0.722656, time 16.181 sp/s
# Train: epoch 3, step 2130, inferLoss 0.51, cmpLoss 0.15, totalLoss 1.04, acc 0.765625, time 12.400 sp/s
# Train: epoch 3, step 2140, inferLoss 0.44, cmpLoss 0.12, totalLoss 0.90, acc 0.812500, time 11.517 sp/s
# Train: epoch 3, step 2150, inferLoss 0.48, cmpLoss 0.14, totalLoss 0.97, acc 0.753906, time 9.379 sp/s
# Train: epoch 3, step 2160, inferLoss 0.54, cmpLoss 0.14, totalLoss 1.10, acc 0.769531, time 14.753 sp/s
# Train: epoch 3, step 2170, inferLoss 0.57, cmpLoss 0.13, totalLoss 1.16, acc 0.738281, time 13.210 sp/s
# Train: epoch 3, step 2180, inferLoss 0.50, cmpLoss 0.17, totalLoss 1.02, acc 0.730469, time 13.392 sp/s
# Train: epoch 3, step 2190, inferLoss 0.61, cmpLoss 0.15, totalLoss 1.23, acc 0.703125, time 20.845 sp/s
# Train: epoch 3, step 2200, inferLoss 0.53, cmpLoss 0.14, totalLoss 1.07, acc 0.742188, time 21.327 sp/s
# Train: epoch 3, step 2210, inferLoss 0.59, cmpLoss 0.15, totalLoss 1.20, acc 0.707031, time 19.726 sp/s
# Train: epoch 3, step 2220, inferLoss 0.51, cmpLoss 0.13, totalLoss 1.04, acc 0.726562, time 28.707 sp/s
# Train: epoch 3, step 2230, inferLoss 0.49, cmpLoss 0.10, totalLoss 1.00, acc 0.765625, time 33.583 sp/s
# Train: epoch 3, step 2240, inferLoss 0.48, cmpLoss 0.11, totalLoss 0.96, acc 0.753906, time 24.081 sp/s
# Train: epoch 3, step 2250, inferLoss 0.52, cmpLoss 0.14, totalLoss 1.05, acc 0.738281, time 35.116 sp/s
# Train: epoch 3, step 2260, inferLoss 0.61, cmpLoss 0.19, totalLoss 1.23, acc 0.703125, time 32.903 sp/s
# End of epoch 3
# ######### Save checkpoint: /home/macul/libraries/mk_utils/tf_spoof/output1/train_2/train_2_3.ckpt
# $$$$$$$$ Validation: epoch 3, accuracy is 0.944790
# Train: epoch 4, step 2270, inferLoss 0.58, cmpLoss 0.18, totalLoss 1.18, acc 0.703125, time 43.438 sp/s
# Train: epoch 4, step 2280, inferLoss 0.50, cmpLoss 0.15, totalLoss 1.02, acc 0.734375, time 45.919 sp/s
# Train: epoch 4, step 2290, inferLoss 0.51, cmpLoss 0.14, totalLoss 1.02, acc 0.773438, time 47.125 sp/s
# Train: epoch 4, step 2300, inferLoss 0.54, cmpLoss 0.12, totalLoss 1.09, acc 0.746094, time 47.684 sp/s
# Train: epoch 4, step 2310, inferLoss 0.54, cmpLoss 0.12, totalLoss 1.08, acc 0.742188, time 44.264 sp/s
# Train: epoch 4, step 2320, inferLoss 0.60, cmpLoss 0.14, totalLoss 1.21, acc 0.726562, time 47.513 sp/s
# Train: epoch 4, step 2330, inferLoss 0.51, cmpLoss 0.13, totalLoss 1.04, acc 0.757812, time 41.529 sp/s
# Train: epoch 4, step 2340, inferLoss 0.59, cmpLoss 0.12, totalLoss 1.19, acc 0.718750, time 44.873 sp/s
# Train: epoch 4, step 2350, inferLoss 0.54, cmpLoss 0.13, totalLoss 1.09, acc 0.722656, time 47.644 sp/s
# Train: epoch 4, step 2360, inferLoss 0.54, cmpLoss 0.15, totalLoss 1.10, acc 0.781250, time 49.642 sp/s
# Train: epoch 4, step 2370, inferLoss 0.54, cmpLoss 0.16, totalLoss 1.10, acc 0.718750, time 47.841 sp/s
# Train: epoch 4, step 2380, inferLoss 0.59, cmpLoss 0.10, totalLoss 1.20, acc 0.714844, time 47.087 sp/s
# Train: epoch 4, step 2390, inferLoss 0.55, cmpLoss 0.11, totalLoss 1.11, acc 0.714844, time 45.383 sp/s
# Train: epoch 4, step 2400, inferLoss 0.54, cmpLoss 0.15, totalLoss 1.09, acc 0.699219, time 43.859 sp/s
# Train: epoch 4, step 2410, inferLoss 0.55, cmpLoss 0.14, totalLoss 1.11, acc 0.707031, time 46.151 sp/s
# Train: epoch 4, step 2420, inferLoss 0.51, cmpLoss 0.13, totalLoss 1.03, acc 0.746094, time 55.092 sp/s
# Train: epoch 4, step 2430, inferLoss 0.51, cmpLoss 0.15, totalLoss 1.04, acc 0.734375, time 43.438 sp/s
# Train: epoch 4, step 2440, inferLoss 0.51, cmpLoss 0.15, totalLoss 1.04, acc 0.738281, time 43.853 sp/s
# Train: epoch 4, step 2450, inferLoss 0.50, cmpLoss 0.12, totalLoss 1.01, acc 0.742188, time 49.639 sp/s
# Train: epoch 4, step 2460, inferLoss 0.57, cmpLoss 0.14, totalLoss 1.16, acc 0.726562, time 42.473 sp/s
# Train: epoch 4, step 2470, inferLoss 0.55, cmpLoss 0.13, totalLoss 1.10, acc 0.699219, time 54.165 sp/s
# Train: epoch 4, step 2480, inferLoss 0.58, cmpLoss 0.14, totalLoss 1.18, acc 0.703125, time 47.624 sp/s
# Train: epoch 4, step 2490, inferLoss 0.52, cmpLoss 0.13, totalLoss 1.05, acc 0.777344, time 45.921 sp/s
# Train: epoch 4, step 2500, inferLoss 0.50, cmpLoss 0.11, totalLoss 1.01, acc 0.738281, time 44.227 sp/s
# Train: epoch 4, step 2510, inferLoss 0.60, cmpLoss 0.13, totalLoss 1.21, acc 0.726562, time 46.387 sp/s
# Train: epoch 4, step 2520, inferLoss 0.51, cmpLoss 0.14, totalLoss 1.04, acc 0.742188, time 47.906 sp/s
# Train: epoch 4, step 2530, inferLoss 0.47, cmpLoss 0.13, totalLoss 0.95, acc 0.820312, time 48.504 sp/s
# Train: epoch 4, step 2540, inferLoss 0.47, cmpLoss 0.13, totalLoss 0.95, acc 0.789062, time 46.231 sp/s
# Train: epoch 4, step 2550, inferLoss 0.50, cmpLoss 0.12, totalLoss 1.02, acc 0.734375, time 46.104 sp/s
# Train: epoch 4, step 2560, inferLoss 0.49, cmpLoss 0.11, totalLoss 0.99, acc 0.773438, time 52.055 sp/s
# Train: epoch 4, step 2570, inferLoss 0.58, cmpLoss 0.16, totalLoss 1.17, acc 0.742188, time 49.750 sp/s
# Train: epoch 4, step 2580, inferLoss 0.59, cmpLoss 0.15, totalLoss 1.19, acc 0.695312, time 44.758 sp/s
# Train: epoch 4, step 2590, inferLoss 0.51, cmpLoss 0.14, totalLoss 1.04, acc 0.746094, time 52.584 sp/s
# Train: epoch 4, step 2600, inferLoss 0.48, cmpLoss 0.12, totalLoss 0.97, acc 0.750000, time 49.998 sp/s
# Train: epoch 4, step 2610, inferLoss 0.48, cmpLoss 0.12, totalLoss 0.97, acc 0.769531, time 42.324 sp/s
# Train: epoch 4, step 2620, inferLoss 0.52, cmpLoss 0.14, totalLoss 1.05, acc 0.722656, time 47.873 sp/s
# Train: epoch 4, step 2630, inferLoss 0.48, cmpLoss 0.11, totalLoss 0.96, acc 0.753906, time 48.335 sp/s
# Train: epoch 4, step 2640, inferLoss 0.58, cmpLoss 0.14, totalLoss 1.18, acc 0.710938, time 48.988 sp/s
# Train: epoch 4, step 2650, inferLoss 0.52, cmpLoss 0.14, totalLoss 1.06, acc 0.738281, time 50.697 sp/s
# Train: epoch 4, step 2660, inferLoss 0.55, cmpLoss 0.15, totalLoss 1.11, acc 0.726562, time 45.854 sp/s
# Train: epoch 4, step 2670, inferLoss 0.48, cmpLoss 0.13, totalLoss 0.98, acc 0.738281, time 44.034 sp/s
# Train: epoch 4, step 2680, inferLoss 0.57, cmpLoss 0.13, totalLoss 1.15, acc 0.730469, time 48.390 sp/s
# Train: epoch 4, step 2690, inferLoss 0.47, cmpLoss 0.12, totalLoss 0.96, acc 0.800781, time 49.794 sp/s
# Train: epoch 4, step 2700, inferLoss 0.55, cmpLoss 0.12, totalLoss 1.12, acc 0.761719, time 51.801 sp/s
# Train: epoch 4, step 2710, inferLoss 0.52, cmpLoss 0.16, totalLoss 1.05, acc 0.734375, time 43.458 sp/s
# Train: epoch 4, step 2720, inferLoss 0.52, cmpLoss 0.11, totalLoss 1.05, acc 0.757812, time 48.933 sp/s
# Train: epoch 4, step 2730, inferLoss 0.53, cmpLoss 0.13, totalLoss 1.07, acc 0.730469, time 50.889 sp/s
# Train: epoch 4, step 2740, inferLoss 0.52, cmpLoss 0.13, totalLoss 1.06, acc 0.746094, time 44.089 sp/s
# Train: epoch 4, step 2750, inferLoss 0.46, cmpLoss 0.12, totalLoss 0.93, acc 0.785156, time 48.898 sp/s
# Train: epoch 4, step 2760, inferLoss 0.54, cmpLoss 0.12, totalLoss 1.08, acc 0.699219, time 45.339 sp/s
# Train: epoch 4, step 2770, inferLoss 0.53, cmpLoss 0.15, totalLoss 1.07, acc 0.730469, time 49.143 sp/s
# Train: epoch 4, step 2780, inferLoss 0.49, cmpLoss 0.14, totalLoss 0.99, acc 0.765625, time 49.873 sp/s
# Train: epoch 4, step 2790, inferLoss 0.49, cmpLoss 0.14, totalLoss 1.00, acc 0.761719, time 44.977 sp/s
# Train: epoch 4, step 2800, inferLoss 0.52, cmpLoss 0.13, totalLoss 1.05, acc 0.753906, time 95.218 sp/s
# Train: epoch 4, step 2810, inferLoss 0.51, cmpLoss 0.11, totalLoss 1.02, acc 0.734375, time 95.780 sp/s
# Train: epoch 4, step 2820, inferLoss 0.55, cmpLoss 0.14, totalLoss 1.11, acc 0.746094, time 94.322 sp/s
# End of epoch 4
# ######### Save checkpoint: /home/macul/libraries/mk_utils/tf_spoof/output1/train_2/train_2_4.ckpt
# $$$$$$$$ Validation: epoch 4, accuracy is 0.884209
# Train: epoch 5, step 2830, inferLoss 0.57, cmpLoss 0.12, totalLoss 1.14, acc 0.757812, time 2.470 sp/s
# Train: epoch 5, step 2840, inferLoss 0.59, cmpLoss 0.13, totalLoss 1.19, acc 0.707031, time 46.562 sp/s
# Train: epoch 5, step 2850, inferLoss 0.57, cmpLoss 0.12, totalLoss 1.15, acc 0.710938, time 45.722 sp/s
# Train: epoch 5, step 2860, inferLoss 0.52, cmpLoss 0.16, totalLoss 1.06, acc 0.707031, time 49.950 sp/s
# Train: epoch 5, step 2870, inferLoss 0.51, cmpLoss 0.12, totalLoss 1.03, acc 0.792969, time 45.052 sp/s
# Train: epoch 5, step 2880, inferLoss 0.53, cmpLoss 0.17, totalLoss 1.07, acc 0.718750, time 51.165 sp/s
# Train: epoch 5, step 2890, inferLoss 0.52, cmpLoss 0.11, totalLoss 1.06, acc 0.726562, time 48.791 sp/s
# Train: epoch 5, step 2900, inferLoss 0.53, cmpLoss 0.10, totalLoss 1.07, acc 0.738281, time 50.404 sp/s
# Train: epoch 5, step 2910, inferLoss 0.57, cmpLoss 0.16, totalLoss 1.17, acc 0.683594, time 46.833 sp/s
# Train: epoch 5, step 2920, inferLoss 0.52, cmpLoss 0.15, totalLoss 1.05, acc 0.753906, time 47.147 sp/s
# Train: epoch 5, step 2930, inferLoss 0.55, cmpLoss 0.13, totalLoss 1.11, acc 0.691406, time 51.447 sp/s
# Train: epoch 5, step 2940, inferLoss 0.66, cmpLoss 0.15, totalLoss 1.34, acc 0.671875, time 47.719 sp/s
# Train: epoch 5, step 2950, inferLoss 0.49, cmpLoss 0.11, totalLoss 0.98, acc 0.792969, time 51.546 sp/s
# Train: epoch 5, step 2960, inferLoss 0.54, cmpLoss 0.11, totalLoss 1.08, acc 0.746094, time 46.815 sp/s
# Train: epoch 5, step 2970, inferLoss 0.48, cmpLoss 0.13, totalLoss 0.97, acc 0.742188, time 47.803 sp/s
# Train: epoch 5, step 2980, inferLoss 0.55, cmpLoss 0.15, totalLoss 1.11, acc 0.730469, time 44.832 sp/s
# Train: epoch 5, step 2990, inferLoss 0.44, cmpLoss 0.12, totalLoss 0.90, acc 0.769531, time 44.772 sp/s
# Train: epoch 5, step 3000, inferLoss 0.48, cmpLoss 0.11, totalLoss 0.97, acc 0.773438, time 47.312 sp/s
# Train: epoch 5, step 3010, inferLoss 0.48, cmpLoss 0.11, totalLoss 0.97, acc 0.773438, time 45.807 sp/s
# Train: epoch 5, step 3020, inferLoss 0.52, cmpLoss 0.09, totalLoss 1.04, acc 0.730469, time 45.330 sp/s
# Train: epoch 5, step 3030, inferLoss 0.50, cmpLoss 0.10, totalLoss 1.00, acc 0.750000, time 47.658 sp/s
# Train: epoch 5, step 3040, inferLoss 0.49, cmpLoss 0.11, totalLoss 1.00, acc 0.816406, time 48.184 sp/s
# Train: epoch 5, step 3050, inferLoss 0.53, cmpLoss 0.14, totalLoss 1.08, acc 0.730469, time 44.627 sp/s
# Train: epoch 5, step 3060, inferLoss 0.50, cmpLoss 0.10, totalLoss 1.01, acc 0.738281, time 49.272 sp/s
# Train: epoch 5, step 3070, inferLoss 0.61, cmpLoss 0.13, totalLoss 1.22, acc 0.722656, time 50.802 sp/s
# Train: epoch 5, step 3080, inferLoss 0.47, cmpLoss 0.13, totalLoss 0.96, acc 0.773438, time 47.237 sp/s
# Train: epoch 5, step 3090, inferLoss 0.49, cmpLoss 0.13, totalLoss 1.00, acc 0.773438, time 49.935 sp/s
# Train: epoch 5, step 3100, inferLoss 0.51, cmpLoss 0.14, totalLoss 1.04, acc 0.757812, time 42.679 sp/s
# Train: epoch 5, step 3110, inferLoss 0.50, cmpLoss 0.15, totalLoss 1.02, acc 0.742188, time 49.164 sp/s
# Train: epoch 5, step 3120, inferLoss 0.51, cmpLoss 0.14, totalLoss 1.04, acc 0.707031, time 57.001 sp/s
# Train: epoch 5, step 3130, inferLoss 0.53, cmpLoss 0.11, totalLoss 1.07, acc 0.710938, time 48.735 sp/s
# Train: epoch 5, step 3140, inferLoss 0.49, cmpLoss 0.12, totalLoss 1.00, acc 0.773438, time 46.594 sp/s
# Train: epoch 5, step 3150, inferLoss 0.56, cmpLoss 0.10, totalLoss 1.13, acc 0.718750, time 48.352 sp/s
# Train: epoch 5, step 3160, inferLoss 0.44, cmpLoss 0.11, totalLoss 0.90, acc 0.781250, time 48.330 sp/s
# Train: epoch 5, step 3170, inferLoss 0.51, cmpLoss 0.13, totalLoss 1.03, acc 0.714844, time 45.819 sp/s
# Train: epoch 5, step 3180, inferLoss 0.50, cmpLoss 0.16, totalLoss 1.02, acc 0.746094, time 47.847 sp/s
# Train: epoch 5, step 3190, inferLoss 0.50, cmpLoss 0.11, totalLoss 1.01, acc 0.757812, time 44.566 sp/s
# Train: epoch 5, step 3200, inferLoss 0.51, cmpLoss 0.13, totalLoss 1.04, acc 0.726562, time 49.082 sp/s
# Train: epoch 5, step 3210, inferLoss 0.46, cmpLoss 0.12, totalLoss 0.93, acc 0.796875, time 49.683 sp/s
# Train: epoch 5, step 3220, inferLoss 0.58, cmpLoss 0.14, totalLoss 1.17, acc 0.699219, time 42.594 sp/s
# Train: epoch 5, step 3230, inferLoss 0.51, cmpLoss 0.16, totalLoss 1.04, acc 0.718750, time 45.839 sp/s
# Train: epoch 5, step 3240, inferLoss 0.48, cmpLoss 0.13, totalLoss 0.98, acc 0.765625, time 46.914 sp/s
# Train: epoch 5, step 3250, inferLoss 0.53, cmpLoss 0.13, totalLoss 1.07, acc 0.703125, time 46.051 sp/s
# Train: epoch 5, step 3260, inferLoss 0.51, cmpLoss 0.11, totalLoss 1.03, acc 0.722656, time 49.318 sp/s
# Train: epoch 5, step 3270, inferLoss 0.46, cmpLoss 0.12, totalLoss 0.92, acc 0.769531, time 49.496 sp/s
# Train: epoch 5, step 3280, inferLoss 0.49, cmpLoss 0.10, totalLoss 0.99, acc 0.753906, time 53.458 sp/s
# Train: epoch 5, step 3290, inferLoss 0.55, cmpLoss 0.12, totalLoss 1.12, acc 0.734375, time 42.087 sp/s
# Train: epoch 5, step 3300, inferLoss 0.54, cmpLoss 0.09, totalLoss 1.08, acc 0.718750, time 43.918 sp/s
# Train: epoch 5, step 3310, inferLoss 0.47, cmpLoss 0.09, totalLoss 0.95, acc 0.765625, time 47.107 sp/s
# Train: epoch 5, step 3320, inferLoss 0.53, cmpLoss 0.13, totalLoss 1.07, acc 0.742188, time 47.116 sp/s
# Train: epoch 5, step 3330, inferLoss 0.50, cmpLoss 0.16, totalLoss 1.02, acc 0.757812, time 44.383 sp/s
# Train: epoch 5, step 3340, inferLoss 0.48, cmpLoss 0.12, totalLoss 0.97, acc 0.761719, time 52.994 sp/s
# Train: epoch 5, step 3350, inferLoss 0.52, cmpLoss 0.11, totalLoss 1.05, acc 0.750000, time 47.207 sp/s
# Train: epoch 5, step 3360, inferLoss 0.54, cmpLoss 0.13, totalLoss 1.10, acc 0.718750, time 101.071 sp/s
# Train: epoch 5, step 3370, inferLoss 0.45, cmpLoss 0.09, totalLoss 0.91, acc 0.781250, time 93.104 sp/s
# Train: epoch 5, step 3380, inferLoss 0.50, cmpLoss 0.14, totalLoss 1.01, acc 0.738281, time 87.154 sp/s
# Train: epoch 5, step 3390, inferLoss 0.59, cmpLoss 0.12, totalLoss 1.18, acc 0.707031, time 92.516 sp/s
# End of epoch 5
# ######### Save checkpoint: /home/macul/libraries/mk_utils/tf_spoof/output1/train_2/train_2_5.ckpt
# $$$$$$$$ Validation: epoch 5, accuracy is 0.798372
# Train: epoch 6, step 3400, inferLoss 0.53, cmpLoss 0.12, totalLoss 1.07, acc 0.710938, time 49.315 sp/s
# Train: epoch 6, step 3410, inferLoss 0.56, cmpLoss 0.10, totalLoss 1.13, acc 0.707031, time 46.953 sp/s
# Train: epoch 6, step 3420, inferLoss 0.48, cmpLoss 0.09, totalLoss 0.96, acc 0.757812, time 47.997 sp/s
# Train: epoch 6, step 3430, inferLoss 0.51, cmpLoss 0.13, totalLoss 1.04, acc 0.753906, time 44.238 sp/s
# Train: epoch 6, step 3440, inferLoss 0.55, cmpLoss 0.11, totalLoss 1.11, acc 0.726562, time 44.787 sp/s
# Train: epoch 6, step 3450, inferLoss 0.51, cmpLoss 0.15, totalLoss 1.04, acc 0.734375, time 43.744 sp/s
# Train: epoch 6, step 3460, inferLoss 0.50, cmpLoss 0.12, totalLoss 1.01, acc 0.734375, time 43.112 sp/s
# Train: epoch 6, step 3470, inferLoss 0.51, cmpLoss 0.12, totalLoss 1.02, acc 0.746094, time 46.589 sp/s
# Train: epoch 6, step 3480, inferLoss 0.49, cmpLoss 0.11, totalLoss 0.99, acc 0.730469, time 46.120 sp/s
# Train: epoch 6, step 3490, inferLoss 0.53, cmpLoss 0.13, totalLoss 1.08, acc 0.726562, time 46.635 sp/s
# Train: epoch 6, step 3500, inferLoss 0.51, cmpLoss 0.10, totalLoss 1.04, acc 0.773438, time 46.081 sp/s
# Train: epoch 6, step 3510, inferLoss 0.50, cmpLoss 0.11, totalLoss 1.01, acc 0.761719, time 47.704 sp/s
# Train: epoch 6, step 3520, inferLoss 0.53, cmpLoss 0.13, totalLoss 1.07, acc 0.730469, time 49.104 sp/s
# Train: epoch 6, step 3530, inferLoss 0.47, cmpLoss 0.17, totalLoss 0.95, acc 0.742188, time 46.484 sp/s
# Train: epoch 6, step 3540, inferLoss 0.46, cmpLoss 0.11, totalLoss 0.93, acc 0.765625, time 51.811 sp/s
# Train: epoch 6, step 3550, inferLoss 0.56, cmpLoss 0.11, totalLoss 1.14, acc 0.714844, time 49.315 sp/s
# Train: epoch 6, step 3560, inferLoss 0.56, cmpLoss 0.17, totalLoss 1.13, acc 0.687500, time 45.654 sp/s
# Train: epoch 6, step 3570, inferLoss 0.52, cmpLoss 0.11, totalLoss 1.04, acc 0.746094, time 48.165 sp/s
# Train: epoch 6, step 3580, inferLoss 0.46, cmpLoss 0.13, totalLoss 0.94, acc 0.750000, time 46.592 sp/s
# Train: epoch 6, step 3590, inferLoss 0.52, cmpLoss 0.17, totalLoss 1.05, acc 0.687500, time 51.598 sp/s
# Train: epoch 6, step 3600, inferLoss 0.51, cmpLoss 0.12, totalLoss 1.03, acc 0.750000, time 49.005 sp/s
# Train: epoch 6, step 3610, inferLoss 0.49, cmpLoss 0.10, totalLoss 1.00, acc 0.746094, time 46.477 sp/s
# Train: epoch 6, step 3620, inferLoss 0.51, cmpLoss 0.10, totalLoss 1.03, acc 0.746094, time 51.336 sp/s
# Train: epoch 6, step 3630, inferLoss 0.45, cmpLoss 0.11, totalLoss 0.92, acc 0.785156, time 47.419 sp/s
# Train: epoch 6, step 3640, inferLoss 0.54, cmpLoss 0.13, totalLoss 1.10, acc 0.718750, time 54.676 sp/s
# Train: epoch 6, step 3650, inferLoss 0.51, cmpLoss 0.13, totalLoss 1.04, acc 0.746094, time 48.524 sp/s
# Train: epoch 6, step 3660, inferLoss 0.52, cmpLoss 0.13, totalLoss 1.05, acc 0.730469, time 46.113 sp/s
# Train: epoch 6, step 3670, inferLoss 0.48, cmpLoss 0.11, totalLoss 0.97, acc 0.746094, time 46.712 sp/s
# Train: epoch 6, step 3680, inferLoss 0.52, cmpLoss 0.10, totalLoss 1.05, acc 0.722656, time 50.466 sp/s
# Train: epoch 6, step 3690, inferLoss 0.54, cmpLoss 0.16, totalLoss 1.09, acc 0.718750, time 44.759 sp/s
# Train: epoch 6, step 3700, inferLoss 0.54, cmpLoss 0.10, totalLoss 1.08, acc 0.730469, time 50.844 sp/s
# Train: epoch 6, step 3710, inferLoss 0.43, cmpLoss 0.10, totalLoss 0.86, acc 0.781250, time 44.436 sp/s
# Train: epoch 6, step 3720, inferLoss 0.51, cmpLoss 0.15, totalLoss 1.04, acc 0.730469, time 48.329 sp/s
# Train: epoch 6, step 3730, inferLoss 0.52, cmpLoss 0.11, totalLoss 1.05, acc 0.750000, time 44.827 sp/s
# Train: epoch 6, step 3740, inferLoss 0.48, cmpLoss 0.11, totalLoss 0.97, acc 0.769531, time 48.057 sp/s
# Train: epoch 6, step 3750, inferLoss 0.51, cmpLoss 0.11, totalLoss 1.02, acc 0.765625, time 47.552 sp/s
# Train: epoch 6, step 3760, inferLoss 0.54, cmpLoss 0.12, totalLoss 1.10, acc 0.714844, time 47.561 sp/s
# Train: epoch 6, step 3770, inferLoss 0.52, cmpLoss 0.11, totalLoss 1.05, acc 0.730469, time 46.753 sp/s
# Train: epoch 6, step 3780, inferLoss 0.45, cmpLoss 0.13, totalLoss 0.92, acc 0.757812, time 48.676 sp/s
# Train: epoch 6, step 3790, inferLoss 0.53, cmpLoss 0.10, totalLoss 1.06, acc 0.750000, time 50.977 sp/s
# Train: epoch 6, step 3800, inferLoss 0.52, cmpLoss 0.11, totalLoss 1.05, acc 0.765625, time 46.153 sp/s
# Train: epoch 6, step 3810, inferLoss 0.47, cmpLoss 0.11, totalLoss 0.95, acc 0.765625, time 48.623 sp/s
# Train: epoch 6, step 3820, inferLoss 0.47, cmpLoss 0.10, totalLoss 0.96, acc 0.761719, time 47.588 sp/s
# Train: epoch 6, step 3830, inferLoss 0.49, cmpLoss 0.12, totalLoss 0.99, acc 0.750000, time 53.180 sp/s
# Train: epoch 6, step 3840, inferLoss 0.56, cmpLoss 0.13, totalLoss 1.12, acc 0.714844, time 46.771 sp/s
# Train: epoch 6, step 3850, inferLoss 0.58, cmpLoss 0.11, totalLoss 1.18, acc 0.687500, time 49.998 sp/s
# Train: epoch 6, step 3860, inferLoss 0.58, cmpLoss 0.09, totalLoss 1.18, acc 0.710938, time 51.032 sp/s
# Train: epoch 6, step 3870, inferLoss 0.48, cmpLoss 0.11, totalLoss 0.97, acc 0.773438, time 43.993 sp/s
# Train: epoch 6, step 3880, inferLoss 0.48, cmpLoss 0.11, totalLoss 0.98, acc 0.757812, time 48.075 sp/s
# Train: epoch 6, step 3890, inferLoss 0.51, cmpLoss 0.11, totalLoss 1.03, acc 0.753906, time 47.546 sp/s
# Train: epoch 6, step 3900, inferLoss 0.51, cmpLoss 0.11, totalLoss 1.03, acc 0.738281, time 53.264 sp/s
# Train: epoch 6, step 3910, inferLoss 0.49, cmpLoss 0.12, totalLoss 0.99, acc 0.765625, time 47.415 sp/s
# Train: epoch 6, step 3920, inferLoss 0.49, cmpLoss 0.13, totalLoss 1.00, acc 0.757812, time 46.405 sp/s
# Train: epoch 6, step 3930, inferLoss 0.52, cmpLoss 0.14, totalLoss 1.05, acc 0.734375, time 97.723 sp/s
# Train: epoch 6, step 3940, inferLoss 0.48, cmpLoss 0.10, totalLoss 0.98, acc 0.734375, time 100.184 sp/s
# Train: epoch 6, step 3950, inferLoss 0.55, cmpLoss 0.14, totalLoss 1.12, acc 0.714844, time 90.701 sp/s
# Train: epoch 6, step 3960, inferLoss 0.51, cmpLoss 0.13, totalLoss 1.04, acc 0.738281, time 84.703 sp/s
# End of epoch 6
# ######### Save checkpoint: /home/macul/libraries/mk_utils/tf_spoof/output1/train_2/train_2_6.ckpt
# $$$$$$$$ Validation: epoch 6, accuracy is 0.936361
# Train: epoch 7, step 3970, inferLoss 0.44, cmpLoss 0.13, totalLoss 0.90, acc 0.777344, time 47.274 sp/s
# Train: epoch 7, step 3980, inferLoss 0.47, cmpLoss 0.13, totalLoss 0.96, acc 0.757812, time 46.283 sp/s
# Train: epoch 7, step 3990, inferLoss 0.48, cmpLoss 0.08, totalLoss 0.97, acc 0.777344, time 48.060 sp/s
# Train: epoch 7, step 4000, inferLoss 0.46, cmpLoss 0.11, totalLoss 0.93, acc 0.769531, time 49.626 sp/s
# Train: epoch 7, step 4010, inferLoss 0.47, cmpLoss 0.11, totalLoss 0.95, acc 0.757812, time 44.879 sp/s
# Train: epoch 7, step 4020, inferLoss 0.64, cmpLoss 0.19, totalLoss 1.30, acc 0.691406, time 49.747 sp/s
# Train: epoch 7, step 4030, inferLoss 0.52, cmpLoss 0.17, totalLoss 1.06, acc 0.746094, time 46.086 sp/s
# Train: epoch 7, step 4040, inferLoss 0.49, cmpLoss 0.10, totalLoss 1.00, acc 0.753906, time 50.876 sp/s
# Train: epoch 7, step 4050, inferLoss 0.60, cmpLoss 0.11, totalLoss 1.22, acc 0.695312, time 51.424 sp/s
# Train: epoch 7, step 4060, inferLoss 0.53, cmpLoss 0.16, totalLoss 1.08, acc 0.707031, time 46.729 sp/s
# Train: epoch 7, step 4070, inferLoss 0.52, cmpLoss 0.11, totalLoss 1.06, acc 0.769531, time 45.648 sp/s
# Train: epoch 7, step 4080, inferLoss 0.52, cmpLoss 0.11, totalLoss 1.06, acc 0.730469, time 51.807 sp/s
# Train: epoch 7, step 4090, inferLoss 0.47, cmpLoss 0.11, totalLoss 0.96, acc 0.761719, time 47.056 sp/s
# Train: epoch 7, step 4100, inferLoss 0.50, cmpLoss 0.13, totalLoss 1.02, acc 0.773438, time 44.122 sp/s
# Train: epoch 7, step 4110, inferLoss 0.46, cmpLoss 0.11, totalLoss 0.93, acc 0.769531, time 50.661 sp/s
# Train: epoch 7, step 4120, inferLoss 0.44, cmpLoss 0.09, totalLoss 0.89, acc 0.800781, time 48.510 sp/s
# Train: epoch 7, step 4130, inferLoss 0.45, cmpLoss 0.10, totalLoss 0.92, acc 0.781250, time 49.465 sp/s
# Train: epoch 7, step 4140, inferLoss 0.41, cmpLoss 0.09, totalLoss 0.83, acc 0.792969, time 45.066 sp/s
# Train: epoch 7, step 4150, inferLoss 0.46, cmpLoss 0.12, totalLoss 0.94, acc 0.738281, time 49.353 sp/s
# Train: epoch 7, step 4160, inferLoss 0.51, cmpLoss 0.11, totalLoss 1.04, acc 0.742188, time 49.338 sp/s
# Train: epoch 7, step 4170, inferLoss 0.57, cmpLoss 0.14, totalLoss 1.16, acc 0.699219, time 49.106 sp/s
# Train: epoch 7, step 4180, inferLoss 0.51, cmpLoss 0.11, totalLoss 1.04, acc 0.710938, time 45.726 sp/s
# Train: epoch 7, step 4190, inferLoss 0.50, cmpLoss 0.10, totalLoss 1.00, acc 0.738281, time 43.539 sp/s
# Train: epoch 7, step 4200, inferLoss 0.51, cmpLoss 0.12, totalLoss 1.03, acc 0.738281, time 49.899 sp/s
# Train: epoch 7, step 4210, inferLoss 0.50, cmpLoss 0.10, totalLoss 1.01, acc 0.765625, time 49.009 sp/s
# Train: epoch 7, step 4220, inferLoss 0.54, cmpLoss 0.11, totalLoss 1.09, acc 0.726562, time 47.538 sp/s
# Train: epoch 7, step 4230, inferLoss 0.48, cmpLoss 0.10, totalLoss 0.98, acc 0.773438, time 41.379 sp/s
# Train: epoch 7, step 4240, inferLoss 0.49, cmpLoss 0.12, totalLoss 0.99, acc 0.753906, time 46.552 sp/s
# Train: epoch 7, step 4250, inferLoss 0.52, cmpLoss 0.10, totalLoss 1.05, acc 0.757812, time 43.406 sp/s
# Train: epoch 7, step 4260, inferLoss 0.54, cmpLoss 0.11, totalLoss 1.09, acc 0.722656, time 49.263 sp/s
# Train: epoch 7, step 4270, inferLoss 0.52, cmpLoss 0.11, totalLoss 1.05, acc 0.757812, time 45.236 sp/s
# Train: epoch 7, step 4280, inferLoss 0.54, cmpLoss 0.12, totalLoss 1.08, acc 0.710938, time 50.983 sp/s
# Train: epoch 7, step 4290, inferLoss 0.50, cmpLoss 0.09, totalLoss 1.00, acc 0.742188, time 45.812 sp/s
# Train: epoch 7, step 4300, inferLoss 0.50, cmpLoss 0.11, totalLoss 1.00, acc 0.753906, time 47.977 sp/s
# Train: epoch 7, step 4310, inferLoss 0.51, cmpLoss 0.12, totalLoss 1.03, acc 0.746094, time 47.470 sp/s
# Train: epoch 7, step 4320, inferLoss 0.56, cmpLoss 0.11, totalLoss 1.14, acc 0.707031, time 50.200 sp/s
# Train: epoch 7, step 4330, inferLoss 0.54, cmpLoss 0.12, totalLoss 1.09, acc 0.726562, time 51.477 sp/s
# Train: epoch 7, step 4340, inferLoss 0.50, cmpLoss 0.09, totalLoss 1.02, acc 0.750000, time 45.432 sp/s
# Train: epoch 7, step 4350, inferLoss 0.49, cmpLoss 0.13, totalLoss 0.99, acc 0.781250, time 47.992 sp/s
# Train: epoch 7, step 4360, inferLoss 0.47, cmpLoss 0.09, totalLoss 0.95, acc 0.765625, time 48.447 sp/s
# Train: epoch 7, step 4370, inferLoss 0.54, cmpLoss 0.09, totalLoss 1.10, acc 0.722656, time 47.679 sp/s
# Train: epoch 7, step 4380, inferLoss 0.46, cmpLoss 0.09, totalLoss 0.94, acc 0.785156, time 46.629 sp/s
# Train: epoch 7, step 4390, inferLoss 0.48, cmpLoss 0.12, totalLoss 0.97, acc 0.761719, time 46.948 sp/s
# Train: epoch 7, step 4400, inferLoss 0.51, cmpLoss 0.13, totalLoss 1.03, acc 0.714844, time 45.373 sp/s
# Train: epoch 7, step 4410, inferLoss 0.49, cmpLoss 0.10, totalLoss 1.00, acc 0.761719, time 50.805 sp/s
# Train: epoch 7, step 4420, inferLoss 0.52, cmpLoss 0.11, totalLoss 1.05, acc 0.726562, time 47.007 sp/s
# Train: epoch 7, step 4430, inferLoss 0.48, cmpLoss 0.12, totalLoss 0.98, acc 0.781250, time 42.315 sp/s
# Train: epoch 7, step 4440, inferLoss 0.48, cmpLoss 0.14, totalLoss 0.98, acc 0.785156, time 52.218 sp/s
# Train: epoch 7, step 4450, inferLoss 0.48, cmpLoss 0.09, totalLoss 0.98, acc 0.757812, time 47.688 sp/s
# Train: epoch 7, step 4460, inferLoss 0.54, cmpLoss 0.10, totalLoss 1.08, acc 0.750000, time 53.046 sp/s
# Train: epoch 7, step 4470, inferLoss 0.53, cmpLoss 0.11, totalLoss 1.06, acc 0.703125, time 43.176 sp/s
# Train: epoch 7, step 4480, inferLoss 0.49, cmpLoss 0.14, totalLoss 0.99, acc 0.765625, time 50.236 sp/s
# Train: epoch 7, step 4490, inferLoss 0.46, cmpLoss 0.11, totalLoss 0.92, acc 0.773438, time 94.449 sp/s
# Train: epoch 7, step 4500, inferLoss 0.46, cmpLoss 0.12, totalLoss 0.94, acc 0.769531, time 96.618 sp/s
# Train: epoch 7, step 4510, inferLoss 0.57, cmpLoss 0.13, totalLoss 1.16, acc 0.765625, time 102.868 sp/s
# Train: epoch 7, step 4520, inferLoss 0.52, cmpLoss 0.12, totalLoss 1.06, acc 0.718750, time 100.898 sp/s
# End of epoch 7
# ######### Save checkpoint: /home/macul/libraries/mk_utils/tf_spoof/output1/train_2/train_2_7.ckpt
# $$$$$$$$ Validation: epoch 7, accuracy is 0.961717
# Train: epoch 8, step 4530, inferLoss 0.50, cmpLoss 0.11, totalLoss 1.00, acc 0.734375, time 53.992 sp/s
# Train: epoch 8, step 4540, inferLoss 0.49, cmpLoss 0.14, totalLoss 1.00, acc 0.718750, time 50.653 sp/s
# Train: epoch 8, step 4550, inferLoss 0.52, cmpLoss 0.13, totalLoss 1.06, acc 0.746094, time 47.964 sp/s
# Train: epoch 8, step 4560, inferLoss 0.49, cmpLoss 0.07, totalLoss 0.99, acc 0.800781, time 48.526 sp/s
# Train: epoch 8, step 4570, inferLoss 0.44, cmpLoss 0.10, totalLoss 0.89, acc 0.789062, time 51.345 sp/s
# Train: epoch 8, step 4580, inferLoss 0.50, cmpLoss 0.10, totalLoss 1.01, acc 0.714844, time 52.000 sp/s
# Train: epoch 8, step 4590, inferLoss 0.57, cmpLoss 0.12, totalLoss 1.15, acc 0.742188, time 49.556 sp/s
# Train: epoch 8, step 4600, inferLoss 0.48, cmpLoss 0.08, totalLoss 0.96, acc 0.742188, time 50.141 sp/s
# Train: epoch 8, step 4610, inferLoss 0.48, cmpLoss 0.12, totalLoss 0.96, acc 0.761719, time 48.474 sp/s
# Train: epoch 8, step 4620, inferLoss 0.51, cmpLoss 0.14, totalLoss 1.03, acc 0.722656, time 56.440 sp/s
# Train: epoch 8, step 4630, inferLoss 0.53, cmpLoss 0.12, totalLoss 1.08, acc 0.722656, time 47.735 sp/s
# Train: epoch 8, step 4640, inferLoss 0.50, cmpLoss 0.13, totalLoss 1.01, acc 0.718750, time 49.384 sp/s
# Train: epoch 8, step 4650, inferLoss 0.48, cmpLoss 0.09, totalLoss 0.97, acc 0.761719, time 44.712 sp/s
# Train: epoch 8, step 4660, inferLoss 0.51, cmpLoss 0.11, totalLoss 1.04, acc 0.699219, time 45.637 sp/s
# Train: epoch 8, step 4670, inferLoss 0.54, cmpLoss 0.10, totalLoss 1.10, acc 0.753906, time 47.438 sp/s
# Train: epoch 8, step 4680, inferLoss 0.48, cmpLoss 0.11, totalLoss 0.98, acc 0.781250, time 49.462 sp/s
# Train: epoch 8, step 4690, inferLoss 0.58, cmpLoss 0.12, totalLoss 1.17, acc 0.695312, time 51.263 sp/s
# Train: epoch 8, step 4700, inferLoss 0.55, cmpLoss 0.15, totalLoss 1.12, acc 0.738281, time 48.467 sp/s
# Train: epoch 8, step 4710, inferLoss 0.44, cmpLoss 0.11, totalLoss 0.90, acc 0.777344, time 44.751 sp/s
# Train: epoch 8, step 4720, inferLoss 0.52, cmpLoss 0.11, totalLoss 1.05, acc 0.761719, time 44.104 sp/s
# Train: epoch 8, step 4730, inferLoss 0.48, cmpLoss 0.10, totalLoss 0.97, acc 0.742188, time 42.384 sp/s
# Train: epoch 8, step 4740, inferLoss 0.46, cmpLoss 0.10, totalLoss 0.93, acc 0.765625, time 49.909 sp/s
# Train: epoch 8, step 4750, inferLoss 0.53, cmpLoss 0.11, totalLoss 1.07, acc 0.738281, time 46.677 sp/s
# Train: epoch 8, step 4760, inferLoss 0.54, cmpLoss 0.14, totalLoss 1.08, acc 0.718750, time 41.013 sp/s
# Train: epoch 8, step 4770, inferLoss 0.48, cmpLoss 0.13, totalLoss 0.98, acc 0.750000, time 49.844 sp/s
# Train: epoch 8, step 4780, inferLoss 0.47, cmpLoss 0.10, totalLoss 0.94, acc 0.761719, time 47.007 sp/s
# Train: epoch 8, step 4790, inferLoss 0.41, cmpLoss 0.10, totalLoss 0.84, acc 0.792969, time 39.315 sp/s
# Train: epoch 8, step 4800, inferLoss 0.45, cmpLoss 0.12, totalLoss 0.92, acc 0.792969, time 55.365 sp/s
# Train: epoch 8, step 4810, inferLoss 0.52, cmpLoss 0.11, totalLoss 1.05, acc 0.746094, time 42.672 sp/s
# Train: epoch 8, step 4820, inferLoss 0.51, cmpLoss 0.13, totalLoss 1.03, acc 0.734375, time 46.636 sp/s
# Train: epoch 8, step 4830, inferLoss 0.49, cmpLoss 0.10, totalLoss 0.98, acc 0.730469, time 53.054 sp/s
# Train: epoch 8, step 4840, inferLoss 0.50, cmpLoss 0.09, totalLoss 1.01, acc 0.753906, time 51.251 sp/s
# Train: epoch 8, step 4850, inferLoss 0.51, cmpLoss 0.12, totalLoss 1.02, acc 0.757812, time 49.600 sp/s
# Train: epoch 8, step 4860, inferLoss 0.49, cmpLoss 0.11, totalLoss 0.99, acc 0.753906, time 49.309 sp/s
# Train: epoch 8, step 4870, inferLoss 0.52, cmpLoss 0.15, totalLoss 1.05, acc 0.699219, time 46.712 sp/s
# Train: epoch 8, step 4880, inferLoss 0.52, cmpLoss 0.09, totalLoss 1.05, acc 0.730469, time 47.078 sp/s
# Train: epoch 8, step 4890, inferLoss 0.45, cmpLoss 0.12, totalLoss 0.91, acc 0.761719, time 50.772 sp/s
# Train: epoch 8, step 4900, inferLoss 0.53, cmpLoss 0.11, totalLoss 1.07, acc 0.734375, time 41.388 sp/s
# Train: epoch 8, step 4910, inferLoss 0.52, cmpLoss 0.11, totalLoss 1.04, acc 0.714844, time 52.539 sp/s
# Train: epoch 8, step 4920, inferLoss 0.40, cmpLoss 0.11, totalLoss 0.82, acc 0.792969, time 45.774 sp/s
# Train: epoch 8, step 4930, inferLoss 0.43, cmpLoss 0.08, totalLoss 0.88, acc 0.777344, time 52.005 sp/s
# Train: epoch 8, step 4940, inferLoss 0.50, cmpLoss 0.12, totalLoss 1.01, acc 0.718750, time 45.425 sp/s
# Train: epoch 8, step 4950, inferLoss 0.51, cmpLoss 0.10, totalLoss 1.02, acc 0.734375, time 50.134 sp/s
# Train: epoch 8, step 4960, inferLoss 0.43, cmpLoss 0.11, totalLoss 0.88, acc 0.785156, time 54.820 sp/s
# Train: epoch 8, step 4970, inferLoss 0.46, cmpLoss 0.10, totalLoss 0.92, acc 0.777344, time 43.152 sp/s
# Train: epoch 8, step 4980, inferLoss 0.48, cmpLoss 0.10, totalLoss 0.98, acc 0.792969, time 49.453 sp/s
# Train: epoch 8, step 4990, inferLoss 0.48, cmpLoss 0.10, totalLoss 0.98, acc 0.738281, time 46.978 sp/s
# Train: epoch 8, step 5000, inferLoss 0.52, cmpLoss 0.11, totalLoss 1.04, acc 0.730469, time 47.064 sp/s
# Train: epoch 8, step 5010, inferLoss 0.51, cmpLoss 0.12, totalLoss 1.04, acc 0.742188, time 51.728 sp/s
# Train: epoch 8, step 5020, inferLoss 0.50, cmpLoss 0.10, totalLoss 1.01, acc 0.742188, time 48.171 sp/s
# Train: epoch 8, step 5030, inferLoss 0.52, cmpLoss 0.11, totalLoss 1.04, acc 0.734375, time 49.165 sp/s
# Train: epoch 8, step 5040, inferLoss 0.58, cmpLoss 0.11, totalLoss 1.16, acc 0.734375, time 45.777 sp/s
# Train: epoch 8, step 5050, inferLoss 0.45, cmpLoss 0.12, totalLoss 0.92, acc 0.785156, time 48.402 sp/s
# Train: epoch 8, step 5060, inferLoss 0.47, cmpLoss 0.11, totalLoss 0.95, acc 0.761719, time 92.319 sp/s
# Train: epoch 8, step 5070, inferLoss 0.46, cmpLoss 0.11, totalLoss 0.93, acc 0.742188, time 111.778 sp/s
# Train: epoch 8, step 5080, inferLoss 0.49, cmpLoss 0.10, totalLoss 0.99, acc 0.753906, time 99.706 sp/s
# Train: epoch 8, step 5090, inferLoss 0.48, cmpLoss 0.09, totalLoss 0.97, acc 0.773438, time 99.244 sp/s
# End of epoch 8
# ######### Save checkpoint: /home/macul/libraries/mk_utils/tf_spoof/output1/train_2/train_2_8.ckpt
# $$$$$$$$ Validation: epoch 8, accuracy is 0.964768
# Train: epoch 9, step 5100, inferLoss 0.41, cmpLoss 0.11, totalLoss 0.84, acc 0.765625, time 45.112 sp/s
# Train: epoch 9, step 5110, inferLoss 0.50, cmpLoss 0.10, totalLoss 1.00, acc 0.734375, time 47.267 sp/s
# Train: epoch 9, step 5120, inferLoss 0.47, cmpLoss 0.09, totalLoss 0.94, acc 0.742188, time 49.451 sp/s
# Train: epoch 9, step 5130, inferLoss 0.46, cmpLoss 0.11, totalLoss 0.93, acc 0.757812, time 46.382 sp/s
# Train: epoch 9, step 5140, inferLoss 0.42, cmpLoss 0.12, totalLoss 0.85, acc 0.785156, time 43.774 sp/s
# Train: epoch 9, step 5150, inferLoss 0.49, cmpLoss 0.11, totalLoss 1.00, acc 0.742188, time 49.481 sp/s
# Train: epoch 9, step 5160, inferLoss 0.53, cmpLoss 0.09, totalLoss 1.06, acc 0.742188, time 45.752 sp/s
# Train: epoch 9, step 5170, inferLoss 0.50, cmpLoss 0.11, totalLoss 1.01, acc 0.730469, time 46.244 sp/s
# Train: epoch 9, step 5180, inferLoss 0.49, cmpLoss 0.09, totalLoss 1.00, acc 0.714844, time 43.918 sp/s
# Train: epoch 9, step 5190, inferLoss 0.50, cmpLoss 0.10, totalLoss 1.00, acc 0.761719, time 49.715 sp/s
# Train: epoch 9, step 5200, inferLoss 0.51, cmpLoss 0.11, totalLoss 1.04, acc 0.710938, time 45.654 sp/s
# Train: epoch 9, step 5210, inferLoss 0.51, cmpLoss 0.13, totalLoss 1.04, acc 0.695312, time 46.989 sp/s
# Train: epoch 9, step 5220, inferLoss 0.46, cmpLoss 0.11, totalLoss 0.93, acc 0.769531, time 43.820 sp/s
# Train: epoch 9, step 5230, inferLoss 0.46, cmpLoss 0.10, totalLoss 0.92, acc 0.753906, time 46.234 sp/s
# Train: epoch 9, step 5240, inferLoss 0.48, cmpLoss 0.10, totalLoss 0.98, acc 0.742188, time 46.223 sp/s
# Train: epoch 9, step 5250, inferLoss 0.48, cmpLoss 0.13, totalLoss 0.97, acc 0.722656, time 52.468 sp/s
# Train: epoch 9, step 5260, inferLoss 0.53, cmpLoss 0.12, totalLoss 1.08, acc 0.675781, time 46.251 sp/s
# Train: epoch 9, step 5270, inferLoss 0.49, cmpLoss 0.10, totalLoss 0.98, acc 0.718750, time 44.588 sp/s
# Train: epoch 9, step 5280, inferLoss 0.48, cmpLoss 0.09, totalLoss 0.96, acc 0.753906, time 47.302 sp/s
# Train: epoch 9, step 5290, inferLoss 0.48, cmpLoss 0.13, totalLoss 0.98, acc 0.722656, time 42.378 sp/s
# Train: epoch 9, step 5300, inferLoss 0.43, cmpLoss 0.11, totalLoss 0.87, acc 0.753906, time 45.926 sp/s
# Train: epoch 9, step 5310, inferLoss 0.52, cmpLoss 0.09, totalLoss 1.04, acc 0.753906, time 45.544 sp/s
# Train: epoch 9, step 5320, inferLoss 0.45, cmpLoss 0.10, totalLoss 0.92, acc 0.757812, time 41.892 sp/s
# Train: epoch 9, step 5330, inferLoss 0.54, cmpLoss 0.12, totalLoss 1.10, acc 0.714844, time 42.525 sp/s
# Train: epoch 9, step 5340, inferLoss 0.51, cmpLoss 0.10, totalLoss 1.03, acc 0.757812, time 46.629 sp/s
# Train: epoch 9, step 5350, inferLoss 0.50, cmpLoss 0.12, totalLoss 1.02, acc 0.746094, time 52.086 sp/s
# Train: epoch 9, step 5360, inferLoss 0.44, cmpLoss 0.11, totalLoss 0.90, acc 0.761719, time 47.182 sp/s
# Train: epoch 9, step 5370, inferLoss 0.55, cmpLoss 0.11, totalLoss 1.10, acc 0.738281, time 53.752 sp/s
# Train: epoch 9, step 5380, inferLoss 0.49, cmpLoss 0.13, totalLoss 0.99, acc 0.714844, time 40.547 sp/s
# Train: epoch 9, step 5390, inferLoss 0.50, cmpLoss 0.11, totalLoss 1.02, acc 0.734375, time 50.753 sp/s
# Train: epoch 9, step 5400, inferLoss 0.48, cmpLoss 0.11, totalLoss 0.98, acc 0.773438, time 52.506 sp/s
# Train: epoch 9, step 5410, inferLoss 0.45, cmpLoss 0.11, totalLoss 0.91, acc 0.781250, time 43.611 sp/s
# Train: epoch 9, step 5420, inferLoss 0.49, cmpLoss 0.12, totalLoss 0.98, acc 0.742188, time 52.002 sp/s
# Train: epoch 9, step 5430, inferLoss 0.45, cmpLoss 0.10, totalLoss 0.91, acc 0.808594, time 49.743 sp/s
# Train: epoch 9, step 5440, inferLoss 0.47, cmpLoss 0.09, totalLoss 0.94, acc 0.757812, time 43.635 sp/s
# Train: epoch 9, step 5450, inferLoss 0.56, cmpLoss 0.11, totalLoss 1.13, acc 0.679688, time 51.180 sp/s
# Train: epoch 9, step 5460, inferLoss 0.49, cmpLoss 0.10, totalLoss 0.98, acc 0.722656, time 50.993 sp/s
# Train: epoch 9, step 5470, inferLoss 0.47, cmpLoss 0.11, totalLoss 0.95, acc 0.710938, time 46.858 sp/s
# Train: epoch 9, step 5480, inferLoss 0.51, cmpLoss 0.09, totalLoss 1.02, acc 0.710938, time 47.539 sp/s
# Train: epoch 9, step 5490, inferLoss 0.47, cmpLoss 0.11, totalLoss 0.95, acc 0.714844, time 41.005 sp/s
# Train: epoch 9, step 5500, inferLoss 0.49, cmpLoss 0.11, totalLoss 0.98, acc 0.679688, time 52.634 sp/s
# Train: epoch 9, step 5510, inferLoss 0.51, cmpLoss 0.10, totalLoss 1.02, acc 0.683594, time 45.888 sp/s
# Train: epoch 9, step 5520, inferLoss 0.47, cmpLoss 0.08, totalLoss 0.94, acc 0.687500, time 49.473 sp/s
# Train: epoch 9, step 5530, inferLoss 0.50, cmpLoss 0.13, totalLoss 1.02, acc 0.714844, time 49.665 sp/s
# Train: epoch 9, step 5540, inferLoss 0.51, cmpLoss 0.12, totalLoss 1.03, acc 0.714844, time 44.680 sp/s
# Train: epoch 9, step 5550, inferLoss 0.54, cmpLoss 0.11, totalLoss 1.10, acc 0.703125, time 44.492 sp/s
# Train: epoch 9, step 5560, inferLoss 0.49, cmpLoss 0.10, totalLoss 1.00, acc 0.707031, time 44.887 sp/s
# Train: epoch 9, step 5570, inferLoss 0.47, cmpLoss 0.10, totalLoss 0.95, acc 0.703125, time 42.936 sp/s
# Train: epoch 9, step 5580, inferLoss 0.47, cmpLoss 0.10, totalLoss 0.96, acc 0.710938, time 48.308 sp/s
# Train: epoch 9, step 5590, inferLoss 0.46, cmpLoss 0.10, totalLoss 0.93, acc 0.695312, time 46.017 sp/s
# Train: epoch 9, step 5600, inferLoss 0.52, cmpLoss 0.12, totalLoss 1.05, acc 0.691406, time 50.169 sp/s
# Train: epoch 9, step 5610, inferLoss 0.53, cmpLoss 0.12, totalLoss 1.06, acc 0.683594, time 46.098 sp/s
# Train: epoch 9, step 5620, inferLoss 0.45, cmpLoss 0.10, totalLoss 0.91, acc 0.718750, time 42.241 sp/s
# Train: epoch 9, step 5630, inferLoss 0.49, cmpLoss 0.12, totalLoss 1.00, acc 0.671875, time 90.872 sp/s
# Train: epoch 9, step 5640, inferLoss 0.50, cmpLoss 0.10, totalLoss 1.00, acc 0.687500, time 96.064 sp/s
# Train: epoch 9, step 5650, inferLoss 0.42, cmpLoss 0.08, totalLoss 0.85, acc 0.714844, time 89.918 sp/s
# End of epoch 9
# ######### Save checkpoint: /home/macul/libraries/mk_utils/tf_spoof/output1/train_2/train_2_9.ckpt
# $$$$$$$$ Validation: epoch 9, accuracy is 0.952232

# %%
# RESTART KERNEL AND RUN FROM HERE TO DO VALIDATION

# %%
import tensorflow as tf
import numpy as np
import os
from os.path import isdir
from os import mkdir
from shutil import copyfile
import time
from PIL import Image
import pickle
from spoofing_lbp.SpoofDspTf import SpoofDspTf

# %%
ckpt_num = 9
prefix = 'train_1'
import sys
sys.path.append('/home/macul/libraries/mk_utils/tf_spoof/output/{}'.format(prefix))
import net_config_0 as config
config.BASE_PATH = '/media/macul/black/spoof_db/train_test_all/tfrecord'
config.CFG_PATH = '/home/macul/libraries/mk_utils/tf_spoof/config'
config.OUT_PATH = '/home/macul/libraries/mk_utils/tf_spoof/output'
config.VAL_REC = os.path.sep.join([config.BASE_PATH, "validation.tfrecords"])

SpoofVal = SpoofDspTf(config)

rst_val = SpoofVal.validate_net(ckpt_num, '/home/macul/test.pkl')

# %%
# RESTART KERNEL AND RUN FROM HERE TO DO EVALUATION

# %%
import tensorflow as tf
import numpy as np
import os
from os.path import isdir
from os import mkdir
from shutil import copyfile
import time
from PIL import Image
import pickle
from spoofing_lbp.SpoofDspTf import SpoofDspTf

# %%
ckpt_num = 9
prefix = 'train_1'
import sys
sys.path.append('/home/macul/libraries/mk_utils/tf_spoof/output/{}'.format(prefix))
import net_config_0 as config
config.BASE_PATH = '/media/macul/black/spoof_db/train_test_all/tfrecord'
config.CFG_PATH = '/home/macul/libraries/mk_utils/tf_spoof/config'
config.OUT_PATH = '/home/macul/libraries/mk_utils/tf_spoof/output'

SpoofVal = SpoofDspTf(config)

sess, embeddings, logit, pred, acc = SpoofVal.deploy_net(ckpt_num)

# %%
import cv2

# %%
img = cv2.imread('/home/macul/figure_1-5.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
rst = SpoofVal.eval(img, sess, pred)

# %%
print(rst[0])

# %%
a.shape

# %%
a.reshape([1,-1])

# %%
a.shape

# %%
a[np.newaxis,:].shape

# %%
a
