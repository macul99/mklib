# %%
import numpy as np
import pickle
import os
from os.path import join

# %%
folder_path = '/home/macul/libraries/mk_utils/tf_spoof/eval_rst'
#file_name = ['train_4_0.pkl', 'train_17_0.pkl', 'train_18_4.pkl', 'train_28_1.pkl', 'train_38_9.pkl', 'train_40_2.pkl', 'train_39_3.pkl', 'train_37_8.pkl', 'train_35_2.pkl']
file_name = ['train_38_9.pkl', 'train_41_1.pkl', 'train_39_3.pkl', 'train_37_8.pkl', 'train_36_2.pkl', 'train_35_2.pkl']
th = [0.7, 0.75, 0.8, 0.85, 0.9, 0.95]
tf_f = [0.6, 0.65, 0.7, 0.75]

# %%
rst_dic = {}
for fn in file_name:
    print(fn)
    print('')
    print('')
    
    with open(join(folder_path, fn),'rb') as f:
        rst = pickle.load(f)
        tmp_dic = {}
        
        for t in th:
            for tf in tf_f:
                true_true = 0 # gd_pred
                true_false = 0
                false_true = 0
                false_false = 0
                total = 0
                for cat in ['real','image_attack','video_attack']:
                    for k in rst[cat].keys():                    
                        data = rst[cat][k].copy()
                        total += data.shape[0]

                        tmp = np.sum(data[:,1:], axis=1)
                        data[:,1] = tmp
                        data = data[:,0:2]
                        data_real = data[np.argmax(data,axis=1)==0,:]
                        data_fake = data[np.argmax(data,axis=1)!=0,:]

                        real_rst = np.sum(data_real[:,0]>t)
                        fake_rst = np.sum(data_fake[:,1]>tf)
                        
                        #print(t, tf, k, real_rst, fake_rst)
                        
                        if cat=='real':
                            true_true += real_rst
                            true_false += fake_rst
                        else:
                            false_true += real_rst
                            false_false += fake_rst
                #print(t, tf, k, true_true, true_false, false_true, false_false)
                tmp_dic['{},{}'.format(t,tf)] = {'total': total,
                                                 'true_true': true_true,
                                                 'true_false': true_false,
                                                 'false_true': false_true,
                                                 'false_false': false_false,
                                                 'detection_rate': 1.0*(true_true+true_false+false_true+false_false)/total,
                                                 'recall': 1.0*true_true/(true_true+true_false),
                                                 'precision': 1.0*true_true/(true_true+false_true),
                                                 'accuracy': 1.0*(true_true+false_false)/(true_true+true_false+false_true+false_false),
                                                 'FPR': 1.0*false_true/(false_true+false_false)}
        
        for tk in tmp_dic.keys():
            print(tk)
            print(tmp_dic[tk])
            print('')
            '''
            print('detection_rate', tmp_dic[tk]['detection_rate'])
            print('recall', tmp_dic[tk]['recall'])
            print('precision', tmp_dic[tk]['precision'])
            print('accuracy', tmp_dic[tk]['accuracy'])
            print('FPR', tmp_dic[tk]['FPR'])
            '''
        rst_dic[fn] = tmp_dic
# Out:
# train_38_9.pkl
#
#
# 0.8,0.65
# {'false_false': 8862, 'true_false': 765, 'false_true': 672, 'recall': 0.9368551382583574, 'detection_rate': 0.48896668548842465, 'accuracy': 0.9336228001293362, 'true_true': 11350, 'total': 44275, 'FPR': 0.07048458149779736, 'precision': 0.9441024787888871}
#
# 0.8,0.7
# {'false_false': 4369, 'true_false': 507, 'false_true': 672, 'recall': 0.9572404486801046, 'detection_rate': 0.3816600790513834, 'accuracy': 0.930228429399929, 'true_true': 11350, 'total': 44275, 'FPR': 0.13330688355485024, 'precision': 0.9441024787888871}
#
# 0.85,0.65
# {'false_false': 8862, 'true_false': 765, 'false_true': 300, 'recall': 0.9168387868246548, 'detection_rate': 0.41470355731225295, 'accuracy': 0.9419966232775993, 'true_true': 8434, 'total': 44275, 'FPR': 0.03274394237066143, 'precision': 0.9656514769864896}
#
# 0.85,0.75
# {'false_false': 2606, 'true_false': 373, 'false_true': 300, 'recall': 0.9576473259906892, 'detection_rate': 0.2645511010728402, 'accuracy': 0.9425424741739947, 'true_true': 8434, 'total': 44275, 'FPR': 0.10323468685478321, 'precision': 0.9656514769864896}
#
# 0.95,0.7
# {'false_false': 4369, 'true_false': 507, 'false_true': 24, 'recall': 0.7939861844778545, 'detection_rate': 0.1548051948051948, 'accuracy': 0.9225269915377882, 'true_true': 1954, 'total': 44275, 'FPR': 0.005463236967903483, 'precision': 0.9878665318503539}
#
# 0.8,0.6
# {'false_false': 12292, 'true_false': 1302, 'false_true': 672, 'recall': 0.8970913689535251, 'detection_rate': 0.578565782044043, 'accuracy': 0.9229387882573392, 'true_true': 11350, 'total': 44275, 'FPR': 0.05183585313174946, 'precision': 0.9441024787888871}
#
# 0.7,0.7
# {'false_false': 4369, 'true_false': 507, 'false_true': 1849, 'recall': 0.9684838689625164, 'detection_rate': 0.5037831733483907, 'accuracy': 0.8943734588657252, 'true_true': 15580, 'total': 44275, 'FPR': 0.2973624959794146, 'precision': 0.8939124447759481}
#
# 0.95,0.75
# {'false_false': 2606, 'true_false': 373, 'false_true': 24, 'recall': 0.8397077782552643, 'detection_rate': 0.11195934500282326, 'accuracy': 0.9199112366350616, 'true_true': 1954, 'total': 44275, 'FPR': 0.009125475285171103, 'precision': 0.9878665318503539}
#
# 0.75,0.65
# {'false_false': 8862, 'true_false': 765, 'false_true': 1219, 'recall': 0.9474660074165636, 'detection_rate': 0.5565894974590627, 'accuracy': 0.9194903217952359, 'true_true': 13797, 'total': 44275, 'FPR': 0.1209205435968654, 'precision': 0.9188199254128929}
#
# 0.9,0.65
# {'false_false': 8862, 'true_false': 765, 'false_true': 125, 'recall': 0.8731763925729443, 'detection_rate': 0.3392207792207792, 'accuracy': 0.9407417271456155, 'true_true': 5267, 'total': 44275, 'FPR': 0.01390897963725381, 'precision': 0.9768175074183977}
#
# 0.8,0.75
# {'false_false': 2606, 'true_false': 373, 'false_true': 672, 'recall': 0.9681822059199864, 'detection_rate': 0.33881422924901183, 'accuracy': 0.9303379774681688, 'true_true': 11350, 'total': 44275, 'FPR': 0.20500305064063454, 'precision': 0.9441024787888871}
#
# 0.9,0.75
# {'false_false': 2606, 'true_false': 373, 'false_true': 125, 'recall': 0.9338652482269504, 'detection_rate': 0.18906832298136647, 'accuracy': 0.9405088997730259, 'true_true': 5267, 'total': 44275, 'FPR': 0.045770779934090074, 'precision': 0.9768175074183977}
#
# 0.75,0.75
# {'false_false': 2606, 'true_false': 373, 'false_true': 1219, 'recall': 0.9736767819336627, 'detection_rate': 0.4064370412196499, 'accuracy': 0.9115309808280078, 'true_true': 13797, 'total': 44275, 'FPR': 0.31869281045751635, 'precision': 0.9188199254128929}
#
# 0.75,0.7
# {'false_false': 4369, 'true_false': 507, 'false_true': 1219, 'recall': 0.9645553691275168, 'detection_rate': 0.44928289102202146, 'accuracy': 0.913231449829077, 'true_true': 13797, 'total': 44275, 'FPR': 0.21814602720114531, 'precision': 0.9188199254128929}
#
# 0.85,0.6
# {'false_false': 12292, 'true_false': 1302, 'false_true': 300, 'recall': 0.8662695152013147, 'detection_rate': 0.5043026538678712, 'accuracy': 0.9282515227517019, 'true_true': 8434, 'total': 44275, 'FPR': 0.023824650571791613, 'precision': 0.9656514769864896}
#
# 0.95,0.6
# {'false_false': 12292, 'true_false': 1302, 'false_true': 24, 'recall': 0.6001228501228502, 'detection_rate': 0.3517108977978543, 'accuracy': 0.9148471615720524, 'true_true': 1954, 'total': 44275, 'FPR': 0.001948684637869438, 'precision': 0.9878665318503539}
#
# 0.7,0.75
# {'false_false': 2606, 'true_false': 373, 'false_true': 1849, 'recall': 0.9766188177772206, 'detection_rate': 0.4609373235460192, 'accuracy': 0.8911211289690317, 'true_true': 15580, 'total': 44275, 'FPR': 0.4150392817059484, 'precision': 0.8939124447759481}
#
# 0.9,0.7
# {'false_false': 4369, 'true_false': 507, 'false_true': 125, 'recall': 0.9121925874610323, 'detection_rate': 0.231914172783738, 'accuracy': 0.9384495520062329, 'true_true': 5267, 'total': 44275, 'FPR': 0.027814864263462396, 'precision': 0.9768175074183977}
#
# 0.75,0.6
# {'false_false': 12292, 'true_false': 1302, 'false_true': 1219, 'recall': 0.913769123783032, 'detection_rate': 0.646188594014681, 'accuracy': 0.911883956658511, 'true_true': 13797, 'total': 44275, 'FPR': 0.09022278143734734, 'precision': 0.9188199254128929}
#
# 0.85,0.7
# {'false_false': 4369, 'true_false': 507, 'false_true': 300, 'recall': 0.9432949334526339, 'detection_rate': 0.30739695087521174, 'accuracy': 0.9407053637031595, 'true_true': 8434, 'total': 44275, 'FPR': 0.0642535874919683, 'precision': 0.9656514769864896}
#
# 0.95,0.65
# {'false_false': 8862, 'true_false': 765, 'false_true': 24, 'recall': 0.7186465612357484, 'detection_rate': 0.26211180124223604, 'accuracy': 0.9320120637656183, 'true_true': 1954, 'total': 44275, 'FPR': 0.0027008777852802163, 'precision': 0.9878665318503539}
#
# 0.7,0.6
# {'false_false': 12292, 'true_false': 1302, 'false_true': 1849, 'recall': 0.92287643644118, 'detection_rate': 0.7006888763410503, 'accuracy': 0.8984301969506495, 'true_true': 15580, 'total': 44275, 'FPR': 0.13075454352591753, 'precision': 0.8939124447759481}
#
# 0.9,0.6
# {'false_false': 12292, 'true_false': 1302, 'false_true': 125, 'recall': 0.8017963160298371, 'detection_rate': 0.4288198757763975, 'accuracy': 0.9248393553144422, 'true_true': 5267, 'total': 44275, 'FPR': 0.010066843843118305, 'precision': 0.9768175074183977}
#
# 0.7,0.65
# {'false_false': 8862, 'true_false': 765, 'false_true': 1849, 'recall': 0.9531966962373815, 'detection_rate': 0.611089779785432, 'accuracy': 0.9033855706682437, 'true_true': 15580, 'total': 44275, 'FPR': 0.17262627205676406, 'precision': 0.8939124447759481}
#
# train_41_1.pkl
#
#
# 0.8,0.65
# {'false_false': 3495, 'true_false': 469, 'false_true': 1698, 'recall': 0.9637389825266739, 'detection_rate': 0.40941840767927723, 'accuracy': 0.8804545705301484, 'true_true': 12465, 'total': 44275, 'FPR': 0.3269786250722126, 'precision': 0.8801101461554756}
#
# 0.8,0.7
# {'false_false': 2110, 'true_false': 301, 'false_true': 1698, 'recall': 0.9764217452608491, 'detection_rate': 0.3743421795595709, 'accuracy': 0.8793894050923132, 'true_true': 12465, 'total': 44275, 'FPR': 0.44590336134453784, 'precision': 0.8801101461554756}
#
# 0.85,0.65
# {'false_false': 3495, 'true_false': 469, 'false_true': 969, 'recall': 0.9582888651725364, 'detection_rate': 0.35478260869565215, 'accuracy': 0.908454290807232, 'true_true': 10775, 'total': 44275, 'FPR': 0.21706989247311828, 'precision': 0.9174897820163488}
#
# 0.85,0.75
# {'false_false': 1007, 'true_false': 151, 'false_true': 969, 'recall': 0.9861797547135274, 'detection_rate': 0.2914059853190288, 'accuracy': 0.9131917532165555, 'true_true': 10775, 'total': 44275, 'FPR': 0.49038461538461536, 'precision': 0.9174897820163488}
#
# 0.95,0.7
# {'false_false': 2110, 'true_false': 301, 'false_true': 148, 'recall': 0.9527843137254902, 'detection_rate': 0.19498588368153585, 'accuracy': 0.9479902698945906, 'true_true': 6074, 'total': 44275, 'FPR': 0.06554472984942426, 'precision': 0.9762134361941498}
#
# 0.8,0.6
# {'false_false': 4940, 'true_false': 688, 'false_true': 1698, 'recall': 0.9476925416254847, 'detection_rate': 0.4470016939582157, 'accuracy': 0.8794401495629326, 'true_true': 12465, 'total': 44275, 'FPR': 0.25579993974088583, 'precision': 0.8801101461554756}
#
# 0.7,0.7
# {'false_false': 2110, 'true_false': 301, 'false_true': 3690, 'recall': 0.980828025477707, 'detection_rate': 0.48560135516657255, 'accuracy': 0.8143720930232559, 'true_true': 15399, 'total': 44275, 'FPR': 0.6362068965517241, 'precision': 0.8066949552098067}
#
# 0.95,0.75
# {'false_false': 1007, 'true_false': 151, 'false_true': 148, 'recall': 0.9757429718875502, 'detection_rate': 0.16668548842461886, 'accuracy': 0.9594850948509485, 'true_true': 6074, 'total': 44275, 'FPR': 0.12813852813852813, 'precision': 0.9762134361941498}
#
# 0.75,0.65
# {'false_false': 3495, 'true_false': 469, 'false_true': 2591, 'recall': 0.9675522346755223, 'detection_rate': 0.4639186900056465, 'accuracy': 0.8510223953261928, 'true_true': 13985, 'total': 44275, 'FPR': 0.4257311863292803, 'precision': 0.8436896718146718}
#
# 0.9,0.65
# {'false_false': 3495, 'true_false': 469, 'false_true': 459, 'recall': 0.9492808478425435, 'detection_rate': 0.29815923207227557, 'accuracy': 0.9297022952806605, 'true_true': 8778, 'total': 44275, 'FPR': 0.11608497723823975, 'precision': 0.9503085417343293}
#
# 0.8,0.75
# {'false_false': 1007, 'true_false': 151, 'false_true': 1698, 'recall': 0.9880310716550412, 'detection_rate': 0.34604178430265387, 'accuracy': 0.8793159715423275, 'true_true': 12465, 'total': 44275, 'FPR': 0.6277264325323475, 'precision': 0.8801101461554756}
#
# 0.9,0.75
# {'false_false': 1007, 'true_false': 151, 'false_true': 459, 'recall': 0.9830888117370367, 'detection_rate': 0.23478260869565218, 'accuracy': 0.9413179413179413, 'true_true': 8778, 'total': 44275, 'FPR': 0.3130968622100955, 'precision': 0.9503085417343293}
#
# 0.75,0.75
# {'false_false': 1007, 'true_false': 151, 'false_true': 2591, 'recall': 0.9893180531975099, 'detection_rate': 0.40054206662902314, 'accuracy': 0.845381752565693, 'true_true': 13985, 'total': 44275, 'FPR': 0.7201222901612007, 'precision': 0.8436896718146718}
#
# 0.75,0.7
# {'false_false': 2110, 'true_false': 301, 'false_true': 2591, 'recall': 0.9789304213915722, 'detection_rate': 0.42884246188594016, 'accuracy': 0.84768525833465, 'true_true': 13985, 'total': 44275, 'FPR': 0.5511593278025952, 'precision': 0.8436896718146718}
#
# 0.85,0.6
# {'false_false': 4940, 'true_false': 688, 'false_true': 969, 'recall': 0.939980807816453, 'detection_rate': 0.3923658949745906, 'accuracy': 0.904616624453143, 'true_true': 10775, 'total': 44275, 'FPR': 0.1639871382636656, 'precision': 0.9174897820163488}
#
# 0.95,0.6
# {'false_false': 4940, 'true_false': 688, 'false_true': 148, 'recall': 0.8982549541555753, 'detection_rate': 0.2676453980801807, 'accuracy': 0.9294514767932489, 'true_true': 6074, 'total': 44275, 'FPR': 0.02908805031446541, 'precision': 0.9762134361941498}
#
# 0.7,0.75
# {'false_false': 1007, 'true_false': 151, 'false_true': 3690, 'recall': 0.9902893890675241, 'detection_rate': 0.4573009599096556, 'accuracy': 0.8102928828962316, 'true_true': 15399, 'total': 44275, 'FPR': 0.7856078347881627, 'precision': 0.8066949552098067}
#
# 0.9,0.7
# {'false_false': 2110, 'true_false': 301, 'false_true': 459, 'recall': 0.9668465690053971, 'detection_rate': 0.26308300395256917, 'accuracy': 0.9347527472527473, 'true_true': 8778, 'total': 44275, 'FPR': 0.17866874270144026, 'precision': 0.9503085417343293}
#
# 0.75,0.6
# {'false_false': 4940, 'true_false': 688, 'false_true': 2591, 'recall': 0.953111156546037, 'detection_rate': 0.5015019762845849, 'accuracy': 0.8523239056025941, 'true_true': 13985, 'total': 44275, 'FPR': 0.3440446155888992, 'precision': 0.8436896718146718}
#
# 0.85,0.7
# {'false_false': 2110, 'true_false': 301, 'false_true': 969, 'recall': 0.9728241242325749, 'detection_rate': 0.3197063805759458, 'accuracy': 0.910279053338043, 'true_true': 10775, 'total': 44275, 'FPR': 0.31471256901591427, 'precision': 0.9174897820163488}
#
# 0.95,0.65
# {'false_false': 3495, 'true_false': 469, 'false_true': 148, 'recall': 0.9283203423506037, 'detection_rate': 0.23006211180124223, 'accuracy': 0.9394266640486942, 'true_true': 6074, 'total': 44275, 'FPR': 0.040625857809497665, 'precision': 0.9762134361941498}
#
# 0.7,0.6
# {'false_false': 4940, 'true_false': 688, 'false_true': 3690, 'recall': 0.9572325480201405, 'detection_rate': 0.5582608695652174, 'accuracy': 0.8228749443702714, 'true_true': 15399, 'total': 44275, 'FPR': 0.4275782155272306, 'precision': 0.8066949552098067}
#
# 0.9,0.6
# {'false_false': 4940, 'true_false': 688, 'false_true': 459, 'recall': 0.9273188252693851, 'detection_rate': 0.335742518351214, 'accuracy': 0.9228388832828792, 'true_true': 8778, 'total': 44275, 'FPR': 0.08501574365623264, 'precision': 0.9503085417343293}
#
# 0.7,0.65
# {'false_false': 3495, 'true_false': 469, 'false_true': 3690, 'recall': 0.9704436601966221, 'detection_rate': 0.5206775832862789, 'accuracy': 0.8195896412614411, 'true_true': 15399, 'total': 44275, 'FPR': 0.5135699373695198, 'precision': 0.8066949552098067}
#
# train_39_3.pkl
#
#
# 0.8,0.65
# {'false_false': 4874, 'true_false': 605, 'false_true': 135, 'recall': 0.9074074074074074, 'detection_rate': 0.2607114624505929, 'accuracy': 0.9358918825262064, 'true_true': 5929, 'total': 44275, 'FPR': 0.026951487322818928, 'precision': 0.9777374670184696}
#
# 0.8,0.7
# {'false_false': 3285, 'true_false': 382, 'false_true': 135, 'recall': 0.9394707653303755, 'detection_rate': 0.219785431959345, 'accuracy': 0.9468708251978214, 'true_true': 5929, 'total': 44275, 'FPR': 0.039473684210526314, 'precision': 0.9777374670184696}
#
# 0.85,0.65
# {'false_false': 4874, 'true_false': 605, 'false_true': 33, 'recall': 0.7894919972164232, 'detection_rate': 0.17574251835121402, 'accuracy': 0.9180053977637835, 'true_true': 2269, 'total': 44275, 'FPR': 0.006725086610963929, 'precision': 0.9856646394439618}
#
# 0.85,0.75
# {'false_false': 1902, 'true_false': 242, 'false_true': 33, 'recall': 0.9036240541616886, 'detection_rate': 0.10041784302653868, 'accuracy': 0.9381466486729645, 'true_true': 2269, 'total': 44275, 'FPR': 0.017054263565891473, 'precision': 0.9856646394439618}
#
# 0.95,0.7
# {'false_false': 3285, 'true_false': 382, 'false_true': 1, 'recall': 0.056790123456790124, 'detection_rate': 0.08336533032185206, 'accuracy': 0.8962340829043619, 'true_true': 23, 'total': 44275, 'FPR': 0.00030432136335970786, 'precision': 0.9583333333333334}
#
# 0.8,0.6
# {'false_false': 6923, 'true_false': 937, 'false_true': 135, 'recall': 0.863530439848529, 'detection_rate': 0.31448898927159796, 'accuracy': 0.9230106291295604, 'true_true': 5929, 'total': 44275, 'FPR': 0.019127231510342874, 'precision': 0.9777374670184696}
#
# 0.7,0.7
# {'false_false': 3285, 'true_false': 382, 'false_true': 1115, 'recall': 0.9733370559084247, 'detection_rate': 0.42297007340485604, 'accuracy': 0.9200619426496502, 'true_true': 13945, 'total': 44275, 'FPR': 0.2534090909090909, 'precision': 0.9259628154050464}
#
# 0.95,0.75
# {'false_false': 1902, 'true_false': 242, 'false_true': 1, 'recall': 0.08679245283018867, 'detection_rate': 0.048966685488424616, 'accuracy': 0.8879151291512916, 'true_true': 23, 'total': 44275, 'FPR': 0.0005254860746190226, 'precision': 0.9583333333333334}
#
# 0.75,0.65
# {'false_false': 4874, 'true_false': 605, 'false_true': 466, 'recall': 0.9448043061764437, 'detection_rate': 0.3681761716544325, 'accuracy': 0.9342985092939083, 'true_true': 10356, 'total': 44275, 'FPR': 0.08726591760299625, 'precision': 0.9569395675475882}
#
# 0.9,0.65
# {'false_false': 4874, 'true_false': 605, 'false_true': 7, 'recall': 0.3876518218623482, 'detection_rate': 0.132557876905703, 'accuracy': 0.8957232918725507, 'true_true': 383, 'total': 44275, 'FPR': 0.0014341323499282934, 'precision': 0.982051282051282}
#
# 0.8,0.75
# {'false_false': 1902, 'true_false': 242, 'false_true': 135, 'recall': 0.9607843137254902, 'detection_rate': 0.18538678712591755, 'accuracy': 0.9540692007797271, 'true_true': 5929, 'total': 44275, 'FPR': 0.0662739322533137, 'precision': 0.9777374670184696}
#
# 0.9,0.75
# {'false_false': 1902, 'true_false': 242, 'false_true': 7, 'recall': 0.6128, 'detection_rate': 0.05723320158102767, 'accuracy': 0.9017363851617995, 'true_true': 383, 'total': 44275, 'FPR': 0.003666841278156103, 'precision': 0.982051282051282}
#
# 0.75,0.75
# {'false_false': 1902, 'true_false': 242, 'false_true': 466, 'recall': 0.9771655029250802, 'detection_rate': 0.2928514963297572, 'accuracy': 0.945395650161962, 'true_true': 10356, 'total': 44275, 'FPR': 0.19679054054054054, 'precision': 0.9569395675475882}
#
# 0.75,0.7
# {'false_false': 3285, 'true_false': 382, 'false_true': 466, 'recall': 0.9644254051033712, 'detection_rate': 0.3272501411631846, 'accuracy': 0.9414728414659397, 'true_true': 10356, 'total': 44275, 'FPR': 0.1242335377232738, 'precision': 0.9569395675475882}
#
# 0.85,0.6
# {'false_false': 6923, 'true_false': 937, 'false_true': 33, 'recall': 0.7077354959451029, 'detection_rate': 0.22952004517221908, 'accuracy': 0.9045463491438693, 'true_true': 2269, 'total': 44275, 'FPR': 0.004744105807935595, 'precision': 0.9856646394439618}
#
# 0.95,0.6
# {'false_false': 6923, 'true_false': 937, 'false_true': 1, 'recall': 0.023958333333333335, 'detection_rate': 0.17806888763410503, 'accuracy': 0.8810248604769153, 'true_true': 23, 'total': 44275, 'FPR': 0.00014442518775274407, 'precision': 0.9583333333333334}
#
# 0.7,0.75
# {'false_false': 1902, 'true_false': 242, 'false_true': 1115, 'recall': 0.9829421301191231, 'detection_rate': 0.38857142857142857, 'accuracy': 0.9211229946524064, 'true_true': 13945, 'total': 44275, 'FPR': 0.36957242293669207, 'precision': 0.9259628154050464}
#
# 0.9,0.7
# {'false_false': 3285, 'true_false': 382, 'false_true': 7, 'recall': 0.5006535947712418, 'detection_rate': 0.09163184641445511, 'accuracy': 0.9041163421247227, 'true_true': 383, 'total': 44275, 'FPR': 0.00212636695018226, 'precision': 0.982051282051282}
#
# 0.75,0.6
# {'false_false': 6923, 'true_false': 937, 'false_true': 466, 'recall': 0.9170282475870007, 'detection_rate': 0.4219536984754376, 'accuracy': 0.9249009741997645, 'true_true': 10356, 'total': 44275, 'FPR': 0.06306672080119095, 'precision': 0.9569395675475882}
#
# 0.85,0.7
# {'false_false': 3285, 'true_false': 382, 'false_true': 33, 'recall': 0.8559034326669182, 'detection_rate': 0.1348164878599661, 'accuracy': 0.9304741162673815, 'true_true': 2269, 'total': 44275, 'FPR': 0.009945750452079566, 'precision': 0.9856646394439618}
#
# 0.95,0.65
# {'false_false': 4874, 'true_false': 605, 'false_true': 1, 'recall': 0.03662420382165605, 'detection_rate': 0.12429136081309994, 'accuracy': 0.8898782482282391, 'true_true': 23, 'total': 44275, 'FPR': 0.00020512820512820512, 'precision': 0.9583333333333334}
#
# 0.7,0.6
# {'false_false': 6923, 'true_false': 937, 'false_true': 1115, 'recall': 0.9370380325225104, 'detection_rate': 0.5176736307171089, 'accuracy': 0.9104712041884817, 'true_true': 13945, 'total': 44275, 'FPR': 0.13871609853197311, 'precision': 0.9259628154050464}
#
# 0.9,0.6
# {'false_false': 6923, 'true_false': 937, 'false_true': 7, 'recall': 0.29015151515151516, 'detection_rate': 0.18633540372670807, 'accuracy': 0.8855757575757576, 'true_true': 383, 'total': 44275, 'FPR': 0.00101010101010101, 'precision': 0.982051282051282}
#
# 0.7,0.65
# {'false_false': 4874, 'true_false': 605, 'false_true': 1115, 'recall': 0.9584192439862543, 'detection_rate': 0.4638961038961039, 'accuracy': 0.9162568771605238, 'true_true': 13945, 'total': 44275, 'FPR': 0.18617465353147436, 'precision': 0.9259628154050464}
#
# train_37_8.pkl
#
#
# 0.8,0.65
# {'false_false': 7187, 'true_false': 281, 'false_true': 241, 'recall': 0.9575785024154589, 'detection_rate': 0.31738001129305476, 'accuracy': 0.9628522630230573, 'true_true': 6343, 'total': 44275, 'FPR': 0.03244480344641896, 'precision': 0.9633961117861483}
#
# 0.8,0.7
# {'false_false': 5065, 'true_false': 195, 'false_true': 241, 'recall': 0.9701743652493117, 'detection_rate': 0.2675098814229249, 'accuracy': 0.9631881121242823, 'true_true': 6343, 'total': 44275, 'FPR': 0.04542027892951376, 'precision': 0.9633961117861483}
#
# 0.85,0.65
# {'false_false': 7187, 'true_false': 281, 'false_true': 111, 'recall': 0.8947959565705729, 'detection_rate': 0.22516092603049126, 'accuracy': 0.9606781021165613, 'true_true': 2390, 'total': 44275, 'FPR': 0.015209646478487257, 'precision': 0.9556177528988404}
#
# 0.85,0.75
# {'false_false': 2259, 'true_false': 111, 'false_true': 111, 'recall': 0.9556177528988404, 'detection_rate': 0.11001693958215697, 'accuracy': 0.9544241428864709, 'true_true': 2390, 'total': 44275, 'FPR': 0.04683544303797468, 'precision': 0.9556177528988404}
#
# 0.95,0.7
# {'false_false': 5065, 'true_false': 195, 'false_true': 22, 'recall': 0.4827586206896552, 'detection_rate': 0.12341050254093733, 'accuracy': 0.960285505124451, 'true_true': 182, 'total': 44275, 'FPR': 0.004324749361116572, 'precision': 0.8921568627450981}
#
# 0.8,0.6
# {'false_false': 8945, 'true_false': 448, 'false_true': 241, 'recall': 0.9340303342659402, 'detection_rate': 0.36085827216262, 'accuracy': 0.9568755085435313, 'true_true': 6343, 'total': 44275, 'FPR': 0.02623557587633355, 'precision': 0.9633961117861483}
#
# 0.7,0.7
# {'false_false': 5065, 'true_false': 195, 'false_true': 1540, 'recall': 0.98956326268465, 'detection_rate': 0.5711801242236025, 'accuracy': 0.9313930958124086, 'true_true': 18489, 'total': 44275, 'FPR': 0.2331566994700984, 'precision': 0.9231114883419043}
#
# 0.95,0.75
# {'false_false': 2259, 'true_false': 111, 'false_true': 22, 'recall': 0.621160409556314, 'detection_rate': 0.05813664596273292, 'accuracy': 0.9483294483294483, 'true_true': 182, 'total': 44275, 'FPR': 0.009644892590968873, 'precision': 0.8921568627450981}
#
# 0.75,0.65
# {'false_false': 7187, 'true_false': 281, 'false_true': 567, 'recall': 0.9789985052316891, 'detection_rate': 0.4773348390739695, 'accuracy': 0.9598750828049588, 'true_true': 13099, 'total': 44275, 'FPR': 0.07312354913592985, 'precision': 0.9585101712278647}
#
# 0.9,0.65
# {'false_false': 7187, 'true_false': 281, 'false_true': 52, 'recall': 0.7491071428571429, 'detection_rate': 0.18879728966685488, 'accuracy': 0.9601626988874268, 'true_true': 839, 'total': 44275, 'FPR': 0.007183312612239259, 'precision': 0.941638608305275}
#
# 0.8,0.75
# {'false_false': 2259, 'true_false': 111, 'false_true': 241, 'recall': 0.9828013634955066, 'detection_rate': 0.2022360248447205, 'accuracy': 0.9606879606879607, 'true_true': 6343, 'total': 44275, 'FPR': 0.0964, 'precision': 0.9633961117861483}
#
# 0.9,0.75
# {'false_false': 2259, 'true_false': 111, 'false_true': 52, 'recall': 0.8831578947368421, 'detection_rate': 0.07365330321852061, 'accuracy': 0.9500153327200246, 'true_true': 839, 'total': 44275, 'FPR': 0.02250108178277802, 'precision': 0.941638608305275}
#
# 0.75,0.75
# {'false_false': 2259, 'true_false': 111, 'false_true': 567, 'recall': 0.9915972747918244, 'detection_rate': 0.3621908526256352, 'accuracy': 0.9577201297081567, 'true_true': 13099, 'total': 44275, 'FPR': 0.20063694267515925, 'precision': 0.9585101712278647}
#
# 0.75,0.7
# {'false_false': 5065, 'true_false': 195, 'false_true': 567, 'recall': 0.9853317285993681, 'detection_rate': 0.42746470920383967, 'accuracy': 0.9597379266617352, 'true_true': 13099, 'total': 44275, 'FPR': 0.10067471590909091, 'precision': 0.9585101712278647}
#
# 0.85,0.6
# {'false_false': 8945, 'true_false': 448, 'false_true': 111, 'recall': 0.8421423537702607, 'detection_rate': 0.26863918690005645, 'accuracy': 0.9530015133680847, 'true_true': 2390, 'total': 44275, 'FPR': 0.012257067137809188, 'precision': 0.9556177528988404}
#
# 0.95,0.6
# {'false_false': 8945, 'true_false': 448, 'false_true': 22, 'recall': 0.28888888888888886, 'detection_rate': 0.21675889328063241, 'accuracy': 0.9510263624049182, 'true_true': 182, 'total': 44275, 'FPR': 0.002453440392550463, 'precision': 0.8921568627450981}
#
# 0.7,0.75
# {'false_false': 2259, 'true_false': 111, 'false_true': 1540, 'recall': 0.9940322580645161, 'detection_rate': 0.505906267645398, 'accuracy': 0.926291352292513, 'true_true': 18489, 'total': 44275, 'FPR': 0.40536983416688604, 'precision': 0.9231114883419043}
#
# 0.9,0.7
# {'false_false': 5065, 'true_false': 195, 'false_true': 52, 'recall': 0.811411992263056, 'detection_rate': 0.138927159796725, 'accuracy': 0.9598439278166152, 'true_true': 839, 'total': 44275, 'FPR': 0.010162204416650382, 'precision': 0.941638608305275}
#
# 0.75,0.6
# {'false_false': 8945, 'true_false': 448, 'false_true': 567, 'recall': 0.9669299475898723, 'detection_rate': 0.5208130999435348, 'accuracy': 0.9559824797259204, 'true_true': 13099, 'total': 44275, 'FPR': 0.05960891505466779, 'precision': 0.9585101712278647}
#
# 0.85,0.7
# {'false_false': 5065, 'true_false': 195, 'false_true': 111, 'recall': 0.9245647969052224, 'detection_rate': 0.1752907961603614, 'accuracy': 0.9605720912253576, 'true_true': 2390, 'total': 44275, 'FPR': 0.021445131375579598, 'precision': 0.9556177528988404}
#
# 0.95,0.65
# {'false_false': 7187, 'true_false': 281, 'false_true': 22, 'recall': 0.3930885529157667, 'detection_rate': 0.1732806324110672, 'accuracy': 0.9605057351407716, 'true_true': 182, 'total': 44275, 'FPR': 0.003051740879456235, 'precision': 0.8921568627450981}
#
# 0.7,0.6
# {'false_false': 8945, 'true_false': 448, 'false_true': 1540, 'recall': 0.9763426097058668, 'detection_rate': 0.6645285149632976, 'accuracy': 0.932431513833186, 'true_true': 18489, 'total': 44275, 'FPR': 0.1468764902241297, 'precision': 0.9231114883419043}
#
# 0.9,0.6
# {'false_false': 8945, 'true_false': 448, 'false_true': 52, 'recall': 0.6519036519036518, 'detection_rate': 0.2322755505364201, 'accuracy': 0.9513807856865033, 'true_true': 839, 'total': 44275, 'FPR': 0.0057797043458930756, 'precision': 0.941638608305275}
#
# 0.7,0.65
# {'false_false': 7187, 'true_false': 281, 'false_true': 1540, 'recall': 0.9850293020777837, 'detection_rate': 0.6210502540937324, 'accuracy': 0.9337745935920282, 'true_true': 18489, 'total': 44275, 'FPR': 0.17646384782857796, 'precision': 0.9231114883419043}
#
# train_35_2.pkl
# 0.8,0.65
# {'false_false': 2639, 'true_false': 216, 'false_true': 1331, 'recall': 0.9829693290231017, 'detection_rate': 0.37612648221343875, 'accuracy': 0.907103825136612, 'true_true': 12467, 'total': 44275, 'FPR': 0.335264483627204, 'precision': 0.9035367444557182}
#
# 0.8,0.7
# {'false_false': 1489, 'true_false': 131, 'false_true': 1331, 'recall': 0.9896015240514368, 'detection_rate': 0.3482326369282891, 'accuracy': 0.9051757685821766, 'true_true': 12467, 'total': 44275, 'FPR': 0.47198581560283687, 'precision': 0.9035367444557182}
#
# 0.85,0.65
# {'false_false': 2639, 'true_false': 216, 'false_true': 289, 'recall': 0.97500867754252, 'detection_rate': 0.26134387351778654, 'accuracy': 0.9563564082620344, 'true_true': 8427, 'total': 44275, 'FPR': 0.09870218579234973, 'precision': 0.9668425883432767}
#
# 0.85,0.75
# {'false_false': 683, 'true_false': 73, 'false_true': 289, 'recall': 0.9914117647058823, 'detection_rate': 0.2139356295878035, 'accuracy': 0.9617820945945946, 'true_true': 8427, 'total': 44275, 'FPR': 0.29732510288065844, 'precision': 0.9668425883432767}
#
# 0.95,0.7
# {'false_false': 1489, 'true_false': 131, 'false_true': 1, 'recall': 0.733739837398374, 'detection_rate': 0.0447656691134952, 'accuracy': 0.9334006054490414, 'true_true': 361, 'total': 44275, 'FPR': 0.0006711409395973154, 'precision': 0.9972375690607734}
#
# 0.8,0.6
# {'false_false': 4024, 'true_false': 339, 'false_true': 1331, 'recall': 0.9735280337341871, 'detection_rate': 0.41018633540372673, 'accuracy': 0.9080447111943175, 'true_true': 12467, 'total': 44275, 'FPR': 0.24855275443510738, 'precision': 0.9035367444557182}
#
# 0.7,0.7
# {'false_false': 1489, 'true_false': 131, 'false_true': 5243, 'recall': 0.9924678012879485, 'detection_rate': 0.544867306606437, 'accuracy': 0.7772342895042281, 'true_true': 17261, 'total': 44275, 'FPR': 0.7788175876411171, 'precision': 0.7670191965872734}
#
# 0.95,0.75
# {'false_false': 683, 'true_false': 73, 'false_true': 1, 'recall': 0.8317972350230415, 'detection_rate': 0.025251270468661772, 'accuracy': 0.9338103756708408, 'true_true': 361, 'total': 44275, 'FPR': 0.0014619883040935672, 'precision': 0.9972375690607734}
#
# 0.75,0.65
# {'false_false': 2639, 'true_false': 216, 'false_true': 3209, 'recall': 0.9859108994847042, 'detection_rate': 0.4783512140033879, 'accuracy': 0.8382832050616177, 'true_true': 15115, 'total': 44275, 'FPR': 0.548734610123119, 'precision': 0.8248744815542458}
#
# 0.9,0.65
# {'false_false': 2639, 'true_false': 216, 'false_true': 31, 'recall': 0.9364705882352942, 'detection_rate': 0.1370976849237719, 'accuracy': 0.9593080724876442, 'true_true': 3184, 'total': 44275, 'FPR': 0.011610486891385767, 'precision': 0.990357698289269}
#
# 0.8,0.75
# {'false_false': 683, 'true_false': 73, 'false_true': 1331, 'recall': 0.9941786283891547, 'detection_rate': 0.3287182382834557, 'accuracy': 0.9035316751408548, 'true_true': 12467, 'total': 44275, 'FPR': 0.6608738828202582, 'precision': 0.9035367444557182}
#
# 0.9,0.75
# {'false_false': 683, 'true_false': 73, 'false_true': 31, 'recall': 0.9775867362603623, 'detection_rate': 0.08968944099378882, 'accuracy': 0.9738101233946109, 'true_true': 3184, 'total': 44275, 'FPR': 0.04341736694677871, 'precision': 0.990357698289269}
#
# 0.75,0.75
# {'false_false': 683, 'true_false': 73, 'false_true': 3209, 'recall': 0.9951935738741111, 'detection_rate': 0.4309429700734049, 'accuracy': 0.8279874213836478, 'true_true': 15115, 'total': 44275, 'FPR': 0.8245118191161357, 'precision': 0.8248744815542458}
#
# 0.75,0.7
# {'false_false': 1489, 'true_false': 131, 'false_true': 3209, 'recall': 0.9914075823166733, 'detection_rate': 0.45045736871823827, 'accuracy': 0.8325310870437225, 'true_true': 15115, 'total': 44275, 'FPR': 0.6830566198382291, 'precision': 0.8248744815542458}
#
# 0.85,0.6
# {'false_false': 4024, 'true_false': 339, 'false_true': 289, 'recall': 0.9613278576317591, 'detection_rate': 0.2954037267080745, 'accuracy': 0.9519840966434743, 'true_true': 8427, 'total': 44275, 'FPR': 0.06700672385810341, 'precision': 0.9668425883432767}
#
# 0.95,0.6
# {'false_false': 4024, 'true_false': 339, 'false_true': 1, 'recall': 0.5157142857142857, 'detection_rate': 0.1067193675889328, 'accuracy': 0.928042328042328, 'true_true': 361, 'total': 44275, 'FPR': 0.0002484472049689441, 'precision': 0.9972375690607734}
#
# 0.7,0.75
# {'false_false': 683, 'true_false': 73, 'false_true': 5243, 'recall': 0.9957886235144802, 'detection_rate': 0.5253529079616036, 'accuracy': 0.7714531384350817, 'true_true': 17261, 'total': 44275, 'FPR': 0.8847451906851165, 'precision': 0.7670191965872734}
#
# 0.9,0.7
# {'false_false': 1489, 'true_false': 131, 'false_true': 31, 'recall': 0.9604826546003017, 'detection_rate': 0.10920383963862225, 'accuracy': 0.9664943123061014, 'true_true': 3184, 'total': 44275, 'FPR': 0.020394736842105264, 'precision': 0.990357698289269}
#
# 0.75,0.6
# {'false_false': 4024, 'true_false': 339, 'false_true': 3209, 'recall': 0.9780639316681765, 'detection_rate': 0.5124110671936759, 'accuracy': 0.8436108784766606, 'true_true': 15115, 'total': 44275, 'FPR': 0.4436609982026822, 'precision': 0.8248744815542458}
#
# 0.85,0.7
# {'false_false': 1489, 'true_false': 131, 'false_true': 289, 'recall': 0.9846926852068241, 'detection_rate': 0.23345002823263694, 'accuracy': 0.9593653250773994, 'true_true': 8427, 'total': 44275, 'FPR': 0.1625421822272216, 'precision': 0.9668425883432767}
#
# 0.95,0.65
# {'false_false': 2639, 'true_false': 216, 'false_true': 1, 'recall': 0.6256499133448874, 'detection_rate': 0.07265951439864483, 'accuracy': 0.9325458501709667, 'true_true': 361, 'total': 44275, 'FPR': 0.0003787878787878788, 'precision': 0.9972375690607734}
#
# 0.7,0.6
# {'false_false': 4024, 'true_false': 339, 'false_true': 5243, 'recall': 0.9807386363636363, 'detection_rate': 0.6068210050818746, 'accuracy': 0.7922358283395987, 'true_true': 17261, 'total': 44275, 'FPR': 0.5657710154310996, 'precision': 0.7670191965872734}
#
# 0.9,0.6
# {'false_false': 4024, 'true_false': 339, 'false_true': 31, 'recall': 0.9037751915980698, 'detection_rate': 0.17115753811405984, 'accuracy': 0.9511744523621009, 'true_true': 3184, 'total': 44275, 'FPR': 0.0076448828606658446, 'precision': 0.990357698289269}
#
# 0.7,0.65
# {'false_false': 2639, 'true_false': 216, 'false_true': 5243, 'recall': 0.987640899467872, 'detection_rate': 0.5727611518915867, 'accuracy': 0.7847312591190504, 'true_true': 17261, 'total': 44275, 'FPR': 0.6651865008880995, 'precision': 0.7670191965872734}

# %%
rst_dic = {}
for fn in file_name:
    print(fn)
    real_dic = {}
    image_attack_dic = {}
    video_attack_dic = {}
    
    with open(join(folder_path, fn),'rb') as f:
        rst = pickle.load(f)
        for k in rst['real'].keys():
            real = rst['real'][k]
            tmp_dic = {}
            tmp_dic['total'] = real.shape[0]
            tmp = np.sum(real[:,1:], axis=1)
            real[:,1] = tmp
            real = real[:,0:2]
            real_real = real[np.argmax(real,axis=1)==0,:]
            real_fake = real[np.argmax(real,axis=1)!=0,:]
            
            for t in th:
                for tf in tf_f:
                    real_rst = np.sum(real_real[:,0]>t)                    
                    fake_rst = np.sum(real_real[:,1]>tf) + np.sum(real_fake[:,1]>tf)
                    tmp_dic['{},{}'.format(t,tf)] = [1.0*(real_rst+fake_rst)/tmp_dic['total'], 
                                                     1.0*real_rst/(real_rst+fake_rst),
                                                     1.0*fake_rst/(real_rst+fake_rst)]
            real_dic[k] = tmp_dic
            #print(tmp_dic)
            
        for k in rst['image_attack'].keys():
            print(k)
            image_attack = rst['image_attack'][k]
            tmp_dic = {}
            tmp_dic['total'] = image_attack.shape[0]
            tmp = np.sum(image_attack[:,1:], axis=1)
            image_attack[:,1] = tmp
            image_attack = image_attack[:,0:2]
            image_attack_real = image_attack[np.argmax(image_attack,axis=1)==0,:]
            image_attack_fake = image_attack[np.argmax(image_attack,axis=1)!=0,:]
            
            for t in th:
                for tf in tf_f:
                    real_rst = np.sum(image_attack_real[:,0]>t)                    
                    fake_rst = np.sum(image_attack_real[:,1]>tf) + np.sum(image_attack_fake[:,1]>tf)
                    tmp_dic['{},{}'.format(t,tf)] = [tmp_dic['total'], real_rst, fake_rst, 
                                                     1.0*(real_rst+fake_rst)/tmp_dic['total'], 
                                                     1.0*real_rst/(real_rst+fake_rst),
                                                     1.0*fake_rst/(real_rst+fake_rst)]
            image_attack_dic[k] = tmp_dic
            print(tmp_dic)
            
        for k in rst['video_attack'].keys():
            print(k)
            video_attack = rst['video_attack'][k]
            tmp_dic = {}
            tmp_dic['total'] = video_attack.shape[0]
            tmp = np.sum(video_attack[:,1:], axis=1)
            video_attack[:,1] = tmp
            video_attack = video_attack[:,0:2]
            video_attack_real = video_attack[np.argmax(video_attack,axis=1)==0,:]
            video_attack_fake = video_attack[np.argmax(video_attack,axis=1)!=0,:]
            
            for t in th:
                for tf in tf_f:
                    real_rst = np.sum(video_attack_real[:,0]>t)                    
                    fake_rst = np.sum(video_attack_real[:,1]>tf) + np.sum(video_attack_fake[:,1]>tf)
                    tmp_dic['{},{}'.format(t,tf)] = [tmp_dic['total'], real_rst, fake_rst, 
                                                     1.0*(real_rst+fake_rst)/tmp_dic['total'], 
                                                     1.0*real_rst/(real_rst+fake_rst),
                                                     1.0*fake_rst/(real_rst+fake_rst)]
            video_attack_dic[k] = tmp_dic
            #print(tmp_dic)

# %%
np.multiply([True,False,True],[True,False,False])
