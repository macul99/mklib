# %%
import tensorflow as tf
import numpy as np
import os
from os.path import isdir
from os import mkdir
from shutil import copyfile
import time
from PIL import Image
import pickle
from spoofing_ld_conv.SpoofLineConvTf import SpoofLineConvTf
from tf_spoof.config import net_config_ld_conv as config
config.BASE_PATH = '/media/macul/black/spoof_db/train_test_all/tfrecord'
config.CFG_PATH = '/home/macul/libraries/mk_utils/tf_spoof/config'
config.OUT_PATH = '/home/macul/libraries/mk_utils/tf_spoof/output1'
'''
config.TRAIN_REC = [os.path.sep.join([config.BASE_PATH, "train6-00000-of-00005"]),
                    os.path.sep.join([config.BASE_PATH, "train6-00001-of-00005"]),
                    os.path.sep.join([config.BASE_PATH, "train6-00002-of-00005"]),
                    os.path.sep.join([config.BASE_PATH, "train6-00003-of-00005"]),
                    os.path.sep.join([config.BASE_PATH, "train6-00004-of-00005"]),]
config.VAL_REC = [os.path.sep.join([config.BASE_PATH, "validation6-00000-of-00005"]),
                  os.path.sep.join([config.BASE_PATH, "validation6-00001-of-00005"]),
                  os.path.sep.join([config.BASE_PATH, "validation6-00002-of-00005"]),
                  os.path.sep.join([config.BASE_PATH, "validation6-00003-of-00005"]),
                  os.path.sep.join([config.BASE_PATH, "validation6-00004-of-00005"])]
'''
config.TRAIN_REC = [ os.path.sep.join([config.BASE_PATH, "train6_mtcnn-00000-of-00005"]),
                     os.path.sep.join([config.BASE_PATH, "train6_mtcnn-00001-of-00005"]),
                     os.path.sep.join([config.BASE_PATH, "train6_mtcnn-00002-of-00005"]),
                     os.path.sep.join([config.BASE_PATH, "train6_mtcnn-00003-of-00005"]),
                     os.path.sep.join([config.BASE_PATH, "train6_mtcnn-00004-of-00005"]),]
config.VAL_REC = [ os.path.sep.join([config.BASE_PATH, "val6_mtcnn-00000-of-00005"]),
                   os.path.sep.join([config.BASE_PATH, "val6_mtcnn-00001-of-00005"]),
                   os.path.sep.join([config.BASE_PATH, "val6_mtcnn-00002-of-00005"]),
                   os.path.sep.join([config.BASE_PATH, "val6_mtcnn-00003-of-00005"]),
                   os.path.sep.join([config.BASE_PATH, "val6_mtcnn-00004-of-00005"])]
print(config.Opt_lr)
# Out:
# [0.01, 0.001, 0.0001, 1e-05, 1e-06]

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = config.DEVICE_IDS
#batchSize = config.BATCH_SIZE * config.NUM_DEVICES

# %%
SpoofVal = SpoofLineConvTf(config)

# backup net_config file
copyfile(config.CFG_PATH+'/net_config_ld_conv.py', os.path.sep.join([SpoofVal.checkpointsPath,'net_config_ld_conv_{}.py'.format(0)]))
# Out:
# '/home/macul/libraries/mk_utils/tf_spoof/output1/train_23/net_config_ld_conv_0.py'

# %%
SpoofVal.train_net(-1)
# Out:
# Train: epoch 0, step 10, inferLoss 1.18, cmpLoss 0.36, totalLoss 1.54, acc 0.421875, time 15.097 sp/s
# Train: epoch 0, step 20, inferLoss 1.15, cmpLoss 0.32, totalLoss 1.48, acc 0.429688, time 16.379 sp/s
# Train: epoch 0, step 30, inferLoss 1.04, cmpLoss 0.30, totalLoss 1.34, acc 0.535156, time 18.205 sp/s
# Train: epoch 0, step 40, inferLoss 0.96, cmpLoss 0.29, totalLoss 1.25, acc 0.542969, time 16.031 sp/s
# Train: epoch 0, step 50, inferLoss 0.94, cmpLoss 0.31, totalLoss 1.25, acc 0.597656, time 14.760 sp/s
# Train: epoch 0, step 60, inferLoss 0.90, cmpLoss 0.32, totalLoss 1.22, acc 0.578125, time 15.565 sp/s
# Train: epoch 0, step 70, inferLoss 0.77, cmpLoss 0.29, totalLoss 1.06, acc 0.636719, time 17.388 sp/s
# Train: epoch 0, step 80, inferLoss 0.71, cmpLoss 0.27, totalLoss 0.98, acc 0.718750, time 15.118 sp/s
# Train: epoch 0, step 90, inferLoss 0.81, cmpLoss 0.31, totalLoss 1.12, acc 0.656250, time 16.551 sp/s
# Train: epoch 0, step 100, inferLoss 0.74, cmpLoss 0.28, totalLoss 1.02, acc 0.679688, time 17.308 sp/s
# Train: epoch 0, step 110, inferLoss 0.85, cmpLoss 0.28, totalLoss 1.13, acc 0.675781, time 15.099 sp/s
# Train: epoch 0, step 120, inferLoss 0.69, cmpLoss 0.33, totalLoss 1.02, acc 0.730469, time 18.494 sp/s
# Train: epoch 0, step 130, inferLoss 0.72, cmpLoss 0.27, totalLoss 1.00, acc 0.691406, time 14.749 sp/s
# Train: epoch 0, step 140, inferLoss 0.72, cmpLoss 0.27, totalLoss 0.99, acc 0.667969, time 14.889 sp/s
# Train: epoch 0, step 150, inferLoss 0.72, cmpLoss 0.23, totalLoss 0.95, acc 0.679688, time 14.069 sp/s
# Train: epoch 0, step 160, inferLoss 0.80, cmpLoss 0.26, totalLoss 1.06, acc 0.652344, time 15.545 sp/s
# Train: epoch 0, step 170, inferLoss 0.72, cmpLoss 0.26, totalLoss 0.98, acc 0.714844, time 15.493 sp/s
# Train: epoch 0, step 180, inferLoss 0.62, cmpLoss 0.23, totalLoss 0.85, acc 0.769531, time 14.059 sp/s
# Train: epoch 0, step 190, inferLoss 0.66, cmpLoss 0.28, totalLoss 0.94, acc 0.726562, time 15.879 sp/s
# Train: epoch 0, step 200, inferLoss 0.68, cmpLoss 0.18, totalLoss 0.86, acc 0.718750, time 15.520 sp/s
# Train: epoch 0, step 210, inferLoss 0.62, cmpLoss 0.20, totalLoss 0.83, acc 0.738281, time 17.776 sp/s
# Train: epoch 0, step 220, inferLoss 0.62, cmpLoss 0.20, totalLoss 0.82, acc 0.730469, time 14.004 sp/s
# Train: epoch 0, step 230, inferLoss 0.63, cmpLoss 0.22, totalLoss 0.85, acc 0.722656, time 14.812 sp/s
# Train: epoch 0, step 240, inferLoss 0.59, cmpLoss 0.19, totalLoss 0.78, acc 0.750000, time 15.692 sp/s
# Train: epoch 0, step 250, inferLoss 0.70, cmpLoss 0.25, totalLoss 0.96, acc 0.687500, time 15.842 sp/s
# Train: epoch 0, step 260, inferLoss 0.63, cmpLoss 0.20, totalLoss 0.83, acc 0.738281, time 13.955 sp/s
# Train: epoch 0, step 270, inferLoss 0.70, cmpLoss 0.21, totalLoss 0.91, acc 0.722656, time 14.488 sp/s
# Train: epoch 0, step 280, inferLoss 0.57, cmpLoss 0.21, totalLoss 0.78, acc 0.777344, time 14.655 sp/s
# Train: epoch 0, step 290, inferLoss 0.66, cmpLoss 0.19, totalLoss 0.84, acc 0.703125, time 12.731 sp/s
# Train: epoch 0, step 300, inferLoss 0.59, cmpLoss 0.21, totalLoss 0.80, acc 0.777344, time 16.280 sp/s
# Train: epoch 0, step 310, inferLoss 0.51, cmpLoss 0.20, totalLoss 0.71, acc 0.777344, time 16.637 sp/s
# Train: epoch 0, step 320, inferLoss 0.59, cmpLoss 0.20, totalLoss 0.79, acc 0.761719, time 15.012 sp/s
# Train: epoch 0, step 330, inferLoss 0.58, cmpLoss 0.22, totalLoss 0.80, acc 0.761719, time 14.791 sp/s
# Train: epoch 0, step 340, inferLoss 0.62, cmpLoss 0.23, totalLoss 0.86, acc 0.765625, time 17.232 sp/s
# Train: epoch 0, step 350, inferLoss 0.55, cmpLoss 0.20, totalLoss 0.75, acc 0.789062, time 13.330 sp/s
# Train: epoch 0, step 360, inferLoss 0.60, cmpLoss 0.18, totalLoss 0.78, acc 0.781250, time 12.445 sp/s
# Train: epoch 0, step 370, inferLoss 0.55, cmpLoss 0.21, totalLoss 0.76, acc 0.765625, time 16.717 sp/s
# Train: epoch 0, step 380, inferLoss 0.57, cmpLoss 0.20, totalLoss 0.76, acc 0.750000, time 13.641 sp/s
# Train: epoch 0, step 390, inferLoss 0.55, cmpLoss 0.19, totalLoss 0.74, acc 0.773438, time 16.116 sp/s
# Train: epoch 0, step 400, inferLoss 0.57, cmpLoss 0.24, totalLoss 0.81, acc 0.789062, time 13.862 sp/s
# Train: epoch 0, step 410, inferLoss 0.53, cmpLoss 0.20, totalLoss 0.73, acc 0.769531, time 15.102 sp/s
# Train: epoch 0, step 420, inferLoss 0.51, cmpLoss 0.17, totalLoss 0.68, acc 0.808594, time 15.950 sp/s
# Train: epoch 0, step 430, inferLoss 0.53, cmpLoss 0.16, totalLoss 0.69, acc 0.777344, time 16.027 sp/s
# Train: epoch 0, step 440, inferLoss 0.47, cmpLoss 0.15, totalLoss 0.63, acc 0.816406, time 13.836 sp/s
# Train: epoch 0, step 450, inferLoss 0.58, cmpLoss 0.21, totalLoss 0.79, acc 0.789062, time 11.489 sp/s
# Train: epoch 0, step 460, inferLoss 0.48, cmpLoss 0.17, totalLoss 0.64, acc 0.816406, time 12.613 sp/s
# Train: epoch 0, step 470, inferLoss 0.52, cmpLoss 0.18, totalLoss 0.70, acc 0.800781, time 12.756 sp/s
# Train: epoch 0, step 480, inferLoss 0.45, cmpLoss 0.17, totalLoss 0.63, acc 0.796875, time 16.248 sp/s
# Train: epoch 0, step 490, inferLoss 0.52, cmpLoss 0.16, totalLoss 0.69, acc 0.777344, time 14.518 sp/s
# Train: epoch 0, step 500, inferLoss 0.44, cmpLoss 0.17, totalLoss 0.61, acc 0.824219, time 16.742 sp/s
# Train: epoch 0, step 510, inferLoss 0.39, cmpLoss 0.14, totalLoss 0.53, acc 0.851562, time 15.304 sp/s
# Train: epoch 0, step 520, inferLoss 0.54, cmpLoss 0.20, totalLoss 0.74, acc 0.769531, time 15.904 sp/s
# Train: epoch 0, step 530, inferLoss 0.49, cmpLoss 0.19, totalLoss 0.69, acc 0.808594, time 16.196 sp/s
# Train: epoch 0, step 540, inferLoss 0.38, cmpLoss 0.15, totalLoss 0.53, acc 0.867188, time 12.628 sp/s
# Train: epoch 0, step 550, inferLoss 0.51, cmpLoss 0.21, totalLoss 0.72, acc 0.796875, time 16.160 sp/s
# Train: epoch 0, step 560, inferLoss 0.50, cmpLoss 0.22, totalLoss 0.72, acc 0.804688, time 15.593 sp/s
# Train: epoch 0, step 570, inferLoss 0.38, cmpLoss 0.16, totalLoss 0.53, acc 0.871094, time 14.798 sp/s
# Train: epoch 0, step 580, inferLoss 0.49, cmpLoss 0.16, totalLoss 0.65, acc 0.789062, time 15.021 sp/s
# Train: epoch 0, step 590, inferLoss 0.49, cmpLoss 0.17, totalLoss 0.66, acc 0.839844, time 13.221 sp/s
# Train: epoch 0, step 600, inferLoss 0.46, cmpLoss 0.16, totalLoss 0.63, acc 0.808594, time 10.566 sp/s
# Train: epoch 0, step 610, inferLoss 0.41, cmpLoss 0.18, totalLoss 0.59, acc 0.855469, time 13.634 sp/s
# Train: epoch 0, step 620, inferLoss 0.41, cmpLoss 0.15, totalLoss 0.56, acc 0.828125, time 11.755 sp/s
# Train: epoch 0, step 630, inferLoss 0.41, cmpLoss 0.18, totalLoss 0.59, acc 0.871094, time 14.870 sp/s
# Train: epoch 0, step 640, inferLoss 0.44, cmpLoss 0.17, totalLoss 0.61, acc 0.843750, time 14.625 sp/s
# Train: epoch 0, step 650, inferLoss 0.40, cmpLoss 0.21, totalLoss 0.61, acc 0.832031, time 12.009 sp/s
# Train: epoch 0, step 660, inferLoss 0.36, cmpLoss 0.17, totalLoss 0.53, acc 0.871094, time 12.539 sp/s
# Train: epoch 0, step 670, inferLoss 0.40, cmpLoss 0.19, totalLoss 0.59, acc 0.851562, time 11.868 sp/s
# Train: epoch 0, step 680, inferLoss 0.38, cmpLoss 0.13, totalLoss 0.51, acc 0.851562, time 15.839 sp/s
# Train: epoch 0, step 690, inferLoss 0.41, cmpLoss 0.15, totalLoss 0.56, acc 0.847656, time 15.388 sp/s
# Train: epoch 0, step 700, inferLoss 0.33, cmpLoss 0.18, totalLoss 0.51, acc 0.875000, time 12.267 sp/s
# Train: epoch 0, step 710, inferLoss 0.38, cmpLoss 0.20, totalLoss 0.58, acc 0.851562, time 11.577 sp/s
# Train: epoch 0, step 720, inferLoss 0.33, cmpLoss 0.14, totalLoss 0.47, acc 0.898438, time 13.118 sp/s
# Train: epoch 0, step 730, inferLoss 0.48, cmpLoss 0.16, totalLoss 0.63, acc 0.796875, time 11.831 sp/s
# Train: epoch 0, step 740, inferLoss 0.42, cmpLoss 0.15, totalLoss 0.57, acc 0.832031, time 59.752 sp/s
# Train: epoch 0, step 750, inferLoss 0.27, cmpLoss 0.15, totalLoss 0.42, acc 0.910156, time 59.006 sp/s
# Train: epoch 0, step 760, inferLoss 0.35, cmpLoss 0.16, totalLoss 0.52, acc 0.847656, time 56.657 sp/s
# Train: epoch 0, step 770, inferLoss 0.38, cmpLoss 0.17, totalLoss 0.55, acc 0.863281, time 52.716 sp/s
# End of epoch 0
# ######### Save checkpoint: /home/macul/libraries/mk_utils/tf_spoof/output1/train_23/train_23_0.ckpt
# $$$$$$$$ Validation: epoch 0, accuracy is 0.735594
# Train: epoch 1, step 780, inferLoss 0.37, cmpLoss 0.14, totalLoss 0.51, acc 0.839844, time 17.010 sp/s
# Train: epoch 1, step 790, inferLoss 0.34, cmpLoss 0.17, totalLoss 0.51, acc 0.867188, time 15.564 sp/s
# Train: epoch 1, step 800, inferLoss 0.28, cmpLoss 0.14, totalLoss 0.41, acc 0.917969, time 12.318 sp/s
# Train: epoch 1, step 810, inferLoss 0.40, cmpLoss 0.17, totalLoss 0.57, acc 0.820312, time 12.119 sp/s
# Train: epoch 1, step 820, inferLoss 0.43, cmpLoss 0.17, totalLoss 0.60, acc 0.843750, time 17.758 sp/s
# Train: epoch 1, step 830, inferLoss 0.38, cmpLoss 0.16, totalLoss 0.54, acc 0.878906, time 11.113 sp/s
# Train: epoch 1, step 840, inferLoss 0.37, cmpLoss 0.17, totalLoss 0.54, acc 0.851562, time 10.711 sp/s
# Train: epoch 1, step 850, inferLoss 0.43, cmpLoss 0.16, totalLoss 0.59, acc 0.816406, time 13.725 sp/s
# Train: epoch 1, step 860, inferLoss 0.38, cmpLoss 0.18, totalLoss 0.55, acc 0.875000, time 12.200 sp/s
# Train: epoch 1, step 870, inferLoss 0.37, cmpLoss 0.16, totalLoss 0.53, acc 0.851562, time 12.313 sp/s
# Train: epoch 1, step 880, inferLoss 0.42, cmpLoss 0.18, totalLoss 0.60, acc 0.824219, time 12.341 sp/s
# Train: epoch 1, step 890, inferLoss 0.38, cmpLoss 0.15, totalLoss 0.52, acc 0.867188, time 13.030 sp/s
# Train: epoch 1, step 900, inferLoss 0.41, cmpLoss 0.15, totalLoss 0.55, acc 0.859375, time 14.729 sp/s
# Train: epoch 1, step 910, inferLoss 0.34, cmpLoss 0.13, totalLoss 0.47, acc 0.878906, time 11.131 sp/s
# Train: epoch 1, step 920, inferLoss 0.31, cmpLoss 0.17, totalLoss 0.49, acc 0.875000, time 11.870 sp/s
# Train: epoch 1, step 930, inferLoss 0.33, cmpLoss 0.15, totalLoss 0.47, acc 0.882812, time 12.606 sp/s
# Train: epoch 1, step 940, inferLoss 0.31, cmpLoss 0.19, totalLoss 0.49, acc 0.890625, time 14.493 sp/s
# Train: epoch 1, step 950, inferLoss 0.33, cmpLoss 0.18, totalLoss 0.52, acc 0.863281, time 12.122 sp/s
# Train: epoch 1, step 960, inferLoss 0.37, cmpLoss 0.14, totalLoss 0.51, acc 0.863281, time 11.560 sp/s
# Train: epoch 1, step 970, inferLoss 0.32, cmpLoss 0.18, totalLoss 0.51, acc 0.871094, time 11.348 sp/s
# Train: epoch 1, step 980, inferLoss 0.34, cmpLoss 0.19, totalLoss 0.53, acc 0.851562, time 15.971 sp/s
# Train: epoch 1, step 990, inferLoss 0.41, cmpLoss 0.18, totalLoss 0.59, acc 0.839844, time 15.572 sp/s
# Train: epoch 1, step 1000, inferLoss 0.39, cmpLoss 0.18, totalLoss 0.57, acc 0.847656, time 14.951 sp/s
# Train: epoch 1, step 1010, inferLoss 0.38, cmpLoss 0.17, totalLoss 0.55, acc 0.863281, time 13.268 sp/s
# Train: epoch 1, step 1020, inferLoss 0.32, cmpLoss 0.18, totalLoss 0.51, acc 0.882812, time 17.305 sp/s
# Train: epoch 1, step 1030, inferLoss 0.35, cmpLoss 0.19, totalLoss 0.54, acc 0.851562, time 13.097 sp/s
# Train: epoch 1, step 1040, inferLoss 0.31, cmpLoss 0.15, totalLoss 0.46, acc 0.875000, time 12.692 sp/s
# Train: epoch 1, step 1050, inferLoss 0.32, cmpLoss 0.15, totalLoss 0.47, acc 0.890625, time 11.484 sp/s
# Train: epoch 1, step 1060, inferLoss 0.34, cmpLoss 0.17, totalLoss 0.50, acc 0.886719, time 11.729 sp/s
# Train: epoch 1, step 1070, inferLoss 0.35, cmpLoss 0.18, totalLoss 0.53, acc 0.871094, time 13.890 sp/s
# Train: epoch 1, step 1080, inferLoss 0.30, cmpLoss 0.16, totalLoss 0.46, acc 0.917969, time 10.287 sp/s
# Train: epoch 1, step 1090, inferLoss 0.34, cmpLoss 0.16, totalLoss 0.49, acc 0.855469, time 13.920 sp/s
# Train: epoch 1, step 1100, inferLoss 0.32, cmpLoss 0.12, totalLoss 0.44, acc 0.871094, time 14.995 sp/s
# Train: epoch 1, step 1110, inferLoss 0.37, cmpLoss 0.13, totalLoss 0.51, acc 0.859375, time 15.692 sp/s
# Train: epoch 1, step 1120, inferLoss 0.28, cmpLoss 0.12, totalLoss 0.40, acc 0.882812, time 18.914 sp/s
# Train: epoch 1, step 1130, inferLoss 0.30, cmpLoss 0.17, totalLoss 0.47, acc 0.886719, time 14.305 sp/s
# Train: epoch 1, step 1140, inferLoss 0.28, cmpLoss 0.12, totalLoss 0.40, acc 0.886719, time 15.540 sp/s
# Train: epoch 1, step 1150, inferLoss 0.35, cmpLoss 0.15, totalLoss 0.50, acc 0.886719, time 14.484 sp/s
# Train: epoch 1, step 1160, inferLoss 0.30, cmpLoss 0.17, totalLoss 0.47, acc 0.882812, time 14.470 sp/s
# Train: epoch 1, step 1170, inferLoss 0.29, cmpLoss 0.15, totalLoss 0.44, acc 0.898438, time 15.653 sp/s
# Train: epoch 1, step 1180, inferLoss 0.43, cmpLoss 0.19, totalLoss 0.61, acc 0.839844, time 14.941 sp/s
# Train: epoch 1, step 1190, inferLoss 0.35, cmpLoss 0.20, totalLoss 0.55, acc 0.878906, time 16.931 sp/s
# Train: epoch 1, step 1200, inferLoss 0.38, cmpLoss 0.18, totalLoss 0.56, acc 0.875000, time 16.760 sp/s
# Train: epoch 1, step 1210, inferLoss 0.27, cmpLoss 0.14, totalLoss 0.41, acc 0.890625, time 15.903 sp/s
# Train: epoch 1, step 1220, inferLoss 0.33, cmpLoss 0.12, totalLoss 0.45, acc 0.875000, time 15.984 sp/s
# Train: epoch 1, step 1230, inferLoss 0.26, cmpLoss 0.16, totalLoss 0.43, acc 0.890625, time 15.470 sp/s
# Train: epoch 1, step 1240, inferLoss 0.37, cmpLoss 0.14, totalLoss 0.51, acc 0.855469, time 15.188 sp/s
# Train: epoch 1, step 1250, inferLoss 0.34, cmpLoss 0.15, totalLoss 0.49, acc 0.882812, time 18.113 sp/s
# Train: epoch 1, step 1260, inferLoss 0.31, cmpLoss 0.16, totalLoss 0.47, acc 0.894531, time 12.710 sp/s
# Train: epoch 1, step 1270, inferLoss 0.29, cmpLoss 0.17, totalLoss 0.47, acc 0.886719, time 13.394 sp/s
# Train: epoch 1, step 1280, inferLoss 0.25, cmpLoss 0.13, totalLoss 0.38, acc 0.898438, time 13.581 sp/s
# Train: epoch 1, step 1290, inferLoss 0.30, cmpLoss 0.13, totalLoss 0.43, acc 0.906250, time 13.604 sp/s
# Train: epoch 1, step 1300, inferLoss 0.29, cmpLoss 0.14, totalLoss 0.44, acc 0.882812, time 15.021 sp/s
# Train: epoch 1, step 1310, inferLoss 0.34, cmpLoss 0.17, totalLoss 0.50, acc 0.878906, time 13.790 sp/s
# Train: epoch 1, step 1320, inferLoss 0.27, cmpLoss 0.14, totalLoss 0.41, acc 0.898438, time 15.427 sp/s
# Train: epoch 1, step 1330, inferLoss 0.35, cmpLoss 0.14, totalLoss 0.50, acc 0.875000, time 12.972 sp/s
# Train: epoch 1, step 1340, inferLoss 0.31, cmpLoss 0.15, totalLoss 0.46, acc 0.886719, time 14.072 sp/s
# Train: epoch 1, step 1350, inferLoss 0.38, cmpLoss 0.17, totalLoss 0.54, acc 0.878906, time 16.959 sp/s
# Train: epoch 1, step 1360, inferLoss 0.24, cmpLoss 0.12, totalLoss 0.36, acc 0.898438, time 13.601 sp/s
# Train: epoch 1, step 1370, inferLoss 0.28, cmpLoss 0.13, totalLoss 0.40, acc 0.890625, time 16.240 sp/s
# Train: epoch 1, step 1380, inferLoss 0.26, cmpLoss 0.13, totalLoss 0.39, acc 0.917969, time 15.092 sp/s
# Train: epoch 1, step 1390, inferLoss 0.25, cmpLoss 0.14, totalLoss 0.39, acc 0.917969, time 14.722 sp/s
# Train: epoch 1, step 1400, inferLoss 0.42, cmpLoss 0.18, totalLoss 0.60, acc 0.851562, time 15.683 sp/s
# Train: epoch 1, step 1410, inferLoss 0.31, cmpLoss 0.17, totalLoss 0.48, acc 0.886719, time 14.547 sp/s
# Train: epoch 1, step 1420, inferLoss 0.31, cmpLoss 0.13, totalLoss 0.44, acc 0.890625, time 15.079 sp/s
# Train: epoch 1, step 1430, inferLoss 0.24, cmpLoss 0.15, totalLoss 0.39, acc 0.914062, time 14.961 sp/s
# Train: epoch 1, step 1440, inferLoss 0.29, cmpLoss 0.14, totalLoss 0.43, acc 0.890625, time 16.306 sp/s
# Train: epoch 1, step 1450, inferLoss 0.36, cmpLoss 0.15, totalLoss 0.51, acc 0.867188, time 14.909 sp/s
# Train: epoch 1, step 1460, inferLoss 0.25, cmpLoss 0.14, totalLoss 0.39, acc 0.890625, time 13.134 sp/s
# Train: epoch 1, step 1470, inferLoss 0.27, cmpLoss 0.15, totalLoss 0.42, acc 0.882812, time 16.397 sp/s
# Train: epoch 1, step 1480, inferLoss 0.32, cmpLoss 0.14, totalLoss 0.46, acc 0.882812, time 16.104 sp/s
# Train: epoch 1, step 1490, inferLoss 0.29, cmpLoss 0.14, totalLoss 0.43, acc 0.898438, time 16.782 sp/s
# Train: epoch 1, step 1500, inferLoss 0.29, cmpLoss 0.16, totalLoss 0.45, acc 0.878906, time 13.732 sp/s
# Train: epoch 1, step 1510, inferLoss 0.28, cmpLoss 0.14, totalLoss 0.42, acc 0.906250, time 66.129 sp/s
# Train: epoch 1, step 1520, inferLoss 0.29, cmpLoss 0.15, totalLoss 0.44, acc 0.878906, time 72.215 sp/s
# Train: epoch 1, step 1530, inferLoss 0.32, cmpLoss 0.14, totalLoss 0.46, acc 0.871094, time 58.315 sp/s
# Train: epoch 1, step 1540, inferLoss 0.31, cmpLoss 0.16, totalLoss 0.47, acc 0.902344, time 69.044 sp/s
# End of epoch 1
# ######### Save checkpoint: /home/macul/libraries/mk_utils/tf_spoof/output1/train_23/train_23_1.ckpt
# $$$$$$$$ Validation: epoch 1, accuracy is 0.794588
# Train: epoch 2, step 1550, inferLoss 0.25, cmpLoss 0.10, totalLoss 0.35, acc 0.925781, time 12.628 sp/s
# Train: epoch 2, step 1560, inferLoss 0.21, cmpLoss 0.13, totalLoss 0.34, acc 0.914062, time 14.552 sp/s
# Train: epoch 2, step 1570, inferLoss 0.32, cmpLoss 0.15, totalLoss 0.48, acc 0.882812, time 17.595 sp/s
# Train: epoch 2, step 1580, inferLoss 0.26, cmpLoss 0.17, totalLoss 0.43, acc 0.898438, time 16.042 sp/s
# Train: epoch 2, step 1590, inferLoss 0.29, cmpLoss 0.13, totalLoss 0.42, acc 0.875000, time 11.537 sp/s
# Train: epoch 2, step 1600, inferLoss 0.24, cmpLoss 0.12, totalLoss 0.35, acc 0.929688, time 15.468 sp/s
# Train: epoch 2, step 1610, inferLoss 0.40, cmpLoss 0.16, totalLoss 0.55, acc 0.855469, time 16.163 sp/s
# Train: epoch 2, step 1620, inferLoss 0.23, cmpLoss 0.14, totalLoss 0.37, acc 0.902344, time 12.181 sp/s
# Train: epoch 2, step 1630, inferLoss 0.29, cmpLoss 0.13, totalLoss 0.42, acc 0.890625, time 12.915 sp/s
# Train: epoch 2, step 1640, inferLoss 0.27, cmpLoss 0.14, totalLoss 0.41, acc 0.890625, time 12.764 sp/s
# Train: epoch 2, step 1650, inferLoss 0.22, cmpLoss 0.14, totalLoss 0.36, acc 0.917969, time 13.558 sp/s
# Train: epoch 2, step 1660, inferLoss 0.25, cmpLoss 0.13, totalLoss 0.38, acc 0.910156, time 15.238 sp/s
# Train: epoch 2, step 1670, inferLoss 0.28, cmpLoss 0.14, totalLoss 0.43, acc 0.894531, time 12.912 sp/s
# Train: epoch 2, step 1680, inferLoss 0.29, cmpLoss 0.13, totalLoss 0.41, acc 0.898438, time 12.728 sp/s
# Train: epoch 2, step 1690, inferLoss 0.28, cmpLoss 0.13, totalLoss 0.41, acc 0.890625, time 16.418 sp/s
# Train: epoch 2, step 1700, inferLoss 0.25, cmpLoss 0.14, totalLoss 0.39, acc 0.910156, time 14.314 sp/s
# Train: epoch 2, step 1710, inferLoss 0.20, cmpLoss 0.11, totalLoss 0.31, acc 0.929688, time 11.068 sp/s
# Train: epoch 2, step 1720, inferLoss 0.23, cmpLoss 0.14, totalLoss 0.37, acc 0.921875, time 12.267 sp/s
# Train: epoch 2, step 1730, inferLoss 0.30, cmpLoss 0.14, totalLoss 0.44, acc 0.898438, time 13.264 sp/s
# Train: epoch 2, step 1740, inferLoss 0.37, cmpLoss 0.12, totalLoss 0.49, acc 0.886719, time 13.652 sp/s
# Train: epoch 2, step 1750, inferLoss 0.31, cmpLoss 0.16, totalLoss 0.47, acc 0.859375, time 12.022 sp/s
# Train: epoch 2, step 1760, inferLoss 0.28, cmpLoss 0.11, totalLoss 0.40, acc 0.894531, time 13.448 sp/s
# Train: epoch 2, step 1770, inferLoss 0.27, cmpLoss 0.14, totalLoss 0.41, acc 0.914062, time 12.427 sp/s
# Train: epoch 2, step 1780, inferLoss 0.26, cmpLoss 0.15, totalLoss 0.41, acc 0.894531, time 15.955 sp/s
# Train: epoch 2, step 1790, inferLoss 0.26, cmpLoss 0.11, totalLoss 0.37, acc 0.917969, time 12.055 sp/s
# Train: epoch 2, step 1800, inferLoss 0.27, cmpLoss 0.10, totalLoss 0.37, acc 0.917969, time 12.542 sp/s
# Train: epoch 2, step 1810, inferLoss 0.37, cmpLoss 0.15, totalLoss 0.52, acc 0.878906, time 12.583 sp/s
# Train: epoch 2, step 1820, inferLoss 0.29, cmpLoss 0.13, totalLoss 0.42, acc 0.886719, time 12.018 sp/s
# Train: epoch 2, step 1830, inferLoss 0.29, cmpLoss 0.14, totalLoss 0.43, acc 0.894531, time 12.017 sp/s
# Train: epoch 2, step 1840, inferLoss 0.29, cmpLoss 0.14, totalLoss 0.42, acc 0.890625, time 13.233 sp/s
# Train: epoch 2, step 1850, inferLoss 0.33, cmpLoss 0.13, totalLoss 0.46, acc 0.886719, time 15.380 sp/s
# Train: epoch 2, step 1860, inferLoss 0.33, cmpLoss 0.14, totalLoss 0.47, acc 0.871094, time 12.777 sp/s
# Train: epoch 2, step 1870, inferLoss 0.26, cmpLoss 0.13, totalLoss 0.39, acc 0.914062, time 12.302 sp/s
# Train: epoch 2, step 1880, inferLoss 0.26, cmpLoss 0.13, totalLoss 0.39, acc 0.914062, time 13.490 sp/s
# Train: epoch 2, step 1890, inferLoss 0.28, cmpLoss 0.13, totalLoss 0.41, acc 0.914062, time 12.293 sp/s
# Train: epoch 2, step 1900, inferLoss 0.22, cmpLoss 0.13, totalLoss 0.35, acc 0.921875, time 11.289 sp/s
# Train: epoch 2, step 1910, inferLoss 0.22, cmpLoss 0.14, totalLoss 0.36, acc 0.917969, time 13.824 sp/s
# Train: epoch 2, step 1920, inferLoss 0.26, cmpLoss 0.14, totalLoss 0.40, acc 0.898438, time 15.480 sp/s
# Train: epoch 2, step 1930, inferLoss 0.26, cmpLoss 0.11, totalLoss 0.36, acc 0.906250, time 15.709 sp/s
# Train: epoch 2, step 1940, inferLoss 0.23, cmpLoss 0.11, totalLoss 0.34, acc 0.937500, time 14.525 sp/s
# Train: epoch 2, step 1950, inferLoss 0.22, cmpLoss 0.12, totalLoss 0.34, acc 0.914062, time 11.924 sp/s
# Train: epoch 2, step 1960, inferLoss 0.21, cmpLoss 0.12, totalLoss 0.33, acc 0.914062, time 14.257 sp/s
# Train: epoch 2, step 1970, inferLoss 0.25, cmpLoss 0.12, totalLoss 0.37, acc 0.906250, time 13.297 sp/s
# Train: epoch 2, step 1980, inferLoss 0.23, cmpLoss 0.12, totalLoss 0.35, acc 0.906250, time 14.465 sp/s
# Train: epoch 2, step 1990, inferLoss 0.26, cmpLoss 0.11, totalLoss 0.38, acc 0.898438, time 12.651 sp/s
# Train: epoch 2, step 2000, inferLoss 0.22, cmpLoss 0.12, totalLoss 0.34, acc 0.914062, time 15.255 sp/s
# Train: epoch 2, step 2010, inferLoss 0.27, cmpLoss 0.13, totalLoss 0.40, acc 0.882812, time 14.190 sp/s
# Train: epoch 2, step 2020, inferLoss 0.23, cmpLoss 0.12, totalLoss 0.34, acc 0.914062, time 10.843 sp/s
# Train: epoch 2, step 2030, inferLoss 0.20, cmpLoss 0.13, totalLoss 0.34, acc 0.921875, time 14.602 sp/s
# Train: epoch 2, step 2040, inferLoss 0.29, cmpLoss 0.12, totalLoss 0.42, acc 0.882812, time 14.634 sp/s
# Train: epoch 2, step 2050, inferLoss 0.20, cmpLoss 0.13, totalLoss 0.33, acc 0.921875, time 12.889 sp/s
# Train: epoch 2, step 2060, inferLoss 0.25, cmpLoss 0.16, totalLoss 0.41, acc 0.910156, time 11.460 sp/s
# Train: epoch 2, step 2070, inferLoss 0.23, cmpLoss 0.13, totalLoss 0.37, acc 0.917969, time 14.330 sp/s
# Train: epoch 2, step 2080, inferLoss 0.32, cmpLoss 0.11, totalLoss 0.43, acc 0.882812, time 16.400 sp/s
# Train: epoch 2, step 2090, inferLoss 0.24, cmpLoss 0.14, totalLoss 0.38, acc 0.902344, time 11.553 sp/s
# Train: epoch 2, step 2100, inferLoss 0.30, cmpLoss 0.13, totalLoss 0.43, acc 0.894531, time 14.077 sp/s
# Train: epoch 2, step 2110, inferLoss 0.26, cmpLoss 0.13, totalLoss 0.40, acc 0.914062, time 14.547 sp/s
# Train: epoch 2, step 2120, inferLoss 0.25, cmpLoss 0.13, totalLoss 0.38, acc 0.910156, time 12.521 sp/s
# Train: epoch 2, step 2130, inferLoss 0.27, cmpLoss 0.13, totalLoss 0.40, acc 0.898438, time 13.707 sp/s
# Train: epoch 2, step 2140, inferLoss 0.26, cmpLoss 0.14, totalLoss 0.40, acc 0.906250, time 10.846 sp/s
# Train: epoch 2, step 2150, inferLoss 0.24, cmpLoss 0.15, totalLoss 0.39, acc 0.921875, time 15.220 sp/s
# Train: epoch 2, step 2160, inferLoss 0.23, cmpLoss 0.14, totalLoss 0.37, acc 0.902344, time 12.084 sp/s
# Train: epoch 2, step 2170, inferLoss 0.26, cmpLoss 0.12, totalLoss 0.38, acc 0.902344, time 11.701 sp/s
# Train: epoch 2, step 2180, inferLoss 0.22, cmpLoss 0.13, totalLoss 0.35, acc 0.906250, time 13.089 sp/s
# Train: epoch 2, step 2190, inferLoss 0.29, cmpLoss 0.14, totalLoss 0.43, acc 0.906250, time 13.017 sp/s
# Train: epoch 2, step 2200, inferLoss 0.29, cmpLoss 0.13, totalLoss 0.42, acc 0.894531, time 13.749 sp/s
# Train: epoch 2, step 2210, inferLoss 0.27, cmpLoss 0.14, totalLoss 0.41, acc 0.898438, time 15.869 sp/s
# Train: epoch 2, step 2220, inferLoss 0.37, cmpLoss 0.14, totalLoss 0.51, acc 0.882812, time 11.423 sp/s
# Train: epoch 2, step 2230, inferLoss 0.26, cmpLoss 0.13, totalLoss 0.39, acc 0.921875, time 12.639 sp/s
# Train: epoch 2, step 2240, inferLoss 0.30, cmpLoss 0.12, totalLoss 0.42, acc 0.886719, time 14.417 sp/s
# Train: epoch 2, step 2250, inferLoss 0.23, cmpLoss 0.12, totalLoss 0.35, acc 0.914062, time 17.717 sp/s
# Train: epoch 2, step 2260, inferLoss 0.24, cmpLoss 0.12, totalLoss 0.35, acc 0.917969, time 13.679 sp/s
# Train: epoch 2, step 2270, inferLoss 0.32, cmpLoss 0.13, totalLoss 0.45, acc 0.882812, time 16.777 sp/s
# Train: epoch 2, step 2280, inferLoss 0.18, cmpLoss 0.10, totalLoss 0.28, acc 0.941406, time 57.687 sp/s
# Train: epoch 2, step 2290, inferLoss 0.21, cmpLoss 0.14, totalLoss 0.35, acc 0.929688, time 59.124 sp/s
# Train: epoch 2, step 2300, inferLoss 0.22, cmpLoss 0.12, totalLoss 0.35, acc 0.914062, time 61.474 sp/s
# Train: epoch 2, step 2310, inferLoss 0.18, cmpLoss 0.11, totalLoss 0.28, acc 0.925781, time 61.053 sp/s
# End of epoch 2
# ######### Save checkpoint: /home/macul/libraries/mk_utils/tf_spoof/output1/train_23/train_23_2.ckpt
# $$$$$$$$ Validation: epoch 2, accuracy is 0.786758
# Train: epoch 3, step 2320, inferLoss 0.25, cmpLoss 0.14, totalLoss 0.39, acc 0.921875, time 14.277 sp/s
# Train: epoch 3, step 2330, inferLoss 0.22, cmpLoss 0.11, totalLoss 0.33, acc 0.929688, time 11.533 sp/s
# Train: epoch 3, step 2340, inferLoss 0.23, cmpLoss 0.12, totalLoss 0.35, acc 0.921875, time 12.347 sp/s
# Train: epoch 3, step 2350, inferLoss 0.27, cmpLoss 0.14, totalLoss 0.41, acc 0.878906, time 11.130 sp/s
# Train: epoch 3, step 2360, inferLoss 0.30, cmpLoss 0.15, totalLoss 0.45, acc 0.906250, time 15.664 sp/s
# Train: epoch 3, step 2370, inferLoss 0.22, cmpLoss 0.11, totalLoss 0.33, acc 0.902344, time 14.974 sp/s
# Train: epoch 3, step 2380, inferLoss 0.23, cmpLoss 0.10, totalLoss 0.34, acc 0.921875, time 16.346 sp/s
# Train: epoch 3, step 2390, inferLoss 0.22, cmpLoss 0.10, totalLoss 0.32, acc 0.906250, time 12.981 sp/s
# Train: epoch 3, step 2400, inferLoss 0.25, cmpLoss 0.13, totalLoss 0.38, acc 0.921875, time 15.371 sp/s
# Train: epoch 3, step 2410, inferLoss 0.32, cmpLoss 0.15, totalLoss 0.46, acc 0.886719, time 13.980 sp/s
# Train: epoch 3, step 2420, inferLoss 0.29, cmpLoss 0.13, totalLoss 0.43, acc 0.886719, time 15.456 sp/s
# Train: epoch 3, step 2430, inferLoss 0.18, cmpLoss 0.13, totalLoss 0.30, acc 0.937500, time 15.862 sp/s
# Train: epoch 3, step 2440, inferLoss 0.21, cmpLoss 0.14, totalLoss 0.35, acc 0.902344, time 15.429 sp/s
# Train: epoch 3, step 2450, inferLoss 0.18, cmpLoss 0.11, totalLoss 0.28, acc 0.925781, time 16.111 sp/s
# Train: epoch 3, step 2460, inferLoss 0.18, cmpLoss 0.12, totalLoss 0.30, acc 0.937500, time 14.230 sp/s
# Train: epoch 3, step 2470, inferLoss 0.24, cmpLoss 0.11, totalLoss 0.35, acc 0.910156, time 14.488 sp/s
# Train: epoch 3, step 2480, inferLoss 0.21, cmpLoss 0.12, totalLoss 0.33, acc 0.917969, time 15.138 sp/s
# Train: epoch 3, step 2490, inferLoss 0.21, cmpLoss 0.13, totalLoss 0.34, acc 0.921875, time 15.776 sp/s
# Train: epoch 3, step 2500, inferLoss 0.34, cmpLoss 0.16, totalLoss 0.50, acc 0.886719, time 15.544 sp/s
# Train: epoch 3, step 2510, inferLoss 0.26, cmpLoss 0.13, totalLoss 0.39, acc 0.910156, time 14.926 sp/s
# Train: epoch 3, step 2520, inferLoss 0.26, cmpLoss 0.15, totalLoss 0.41, acc 0.910156, time 15.238 sp/s
# Train: epoch 3, step 2530, inferLoss 0.24, cmpLoss 0.13, totalLoss 0.38, acc 0.902344, time 16.282 sp/s
# Train: epoch 3, step 2540, inferLoss 0.30, cmpLoss 0.11, totalLoss 0.41, acc 0.875000, time 14.380 sp/s
# Train: epoch 3, step 2550, inferLoss 0.22, cmpLoss 0.12, totalLoss 0.34, acc 0.902344, time 14.184 sp/s
# Train: epoch 3, step 2560, inferLoss 0.21, cmpLoss 0.15, totalLoss 0.36, acc 0.929688, time 14.596 sp/s
# Train: epoch 3, step 2570, inferLoss 0.26, cmpLoss 0.13, totalLoss 0.38, acc 0.902344, time 14.671 sp/s
# Train: epoch 3, step 2580, inferLoss 0.18, cmpLoss 0.11, totalLoss 0.29, acc 0.937500, time 16.088 sp/s
# Train: epoch 3, step 2590, inferLoss 0.12, cmpLoss 0.12, totalLoss 0.25, acc 0.964844, time 15.534 sp/s
# Train: epoch 3, step 2600, inferLoss 0.27, cmpLoss 0.14, totalLoss 0.40, acc 0.902344, time 15.288 sp/s
# Train: epoch 3, step 2610, inferLoss 0.28, cmpLoss 0.13, totalLoss 0.41, acc 0.898438, time 13.358 sp/s
# Train: epoch 3, step 2620, inferLoss 0.22, cmpLoss 0.13, totalLoss 0.35, acc 0.914062, time 20.126 sp/s
# Train: epoch 3, step 2630, inferLoss 0.18, cmpLoss 0.13, totalLoss 0.31, acc 0.921875, time 16.078 sp/s
# Train: epoch 3, step 2640, inferLoss 0.23, cmpLoss 0.12, totalLoss 0.36, acc 0.906250, time 15.784 sp/s
# Train: epoch 3, step 2650, inferLoss 0.25, cmpLoss 0.11, totalLoss 0.36, acc 0.910156, time 14.901 sp/s
# Train: epoch 3, step 2660, inferLoss 0.16, cmpLoss 0.09, totalLoss 0.25, acc 0.937500, time 15.158 sp/s
# Train: epoch 3, step 2670, inferLoss 0.23, cmpLoss 0.11, totalLoss 0.34, acc 0.921875, time 17.688 sp/s
# Train: epoch 3, step 2680, inferLoss 0.23, cmpLoss 0.13, totalLoss 0.36, acc 0.937500, time 17.091 sp/s
# Train: epoch 3, step 2690, inferLoss 0.24, cmpLoss 0.15, totalLoss 0.40, acc 0.898438, time 15.512 sp/s
# Train: epoch 3, step 2700, inferLoss 0.24, cmpLoss 0.14, totalLoss 0.39, acc 0.902344, time 15.983 sp/s
# Train: epoch 3, step 2710, inferLoss 0.18, cmpLoss 0.13, totalLoss 0.31, acc 0.937500, time 12.761 sp/s
# Train: epoch 3, step 2720, inferLoss 0.24, cmpLoss 0.12, totalLoss 0.37, acc 0.914062, time 15.283 sp/s
# Train: epoch 3, step 2730, inferLoss 0.20, cmpLoss 0.15, totalLoss 0.35, acc 0.921875, time 17.317 sp/s
# Train: epoch 3, step 2740, inferLoss 0.19, cmpLoss 0.10, totalLoss 0.29, acc 0.925781, time 17.157 sp/s
# Train: epoch 3, step 2750, inferLoss 0.23, cmpLoss 0.14, totalLoss 0.37, acc 0.910156, time 16.290 sp/s
# Train: epoch 3, step 2760, inferLoss 0.24, cmpLoss 0.12, totalLoss 0.36, acc 0.921875, time 14.726 sp/s
# Train: epoch 3, step 2770, inferLoss 0.21, cmpLoss 0.11, totalLoss 0.32, acc 0.914062, time 14.423 sp/s
# Train: epoch 3, step 2780, inferLoss 0.29, cmpLoss 0.14, totalLoss 0.43, acc 0.894531, time 13.044 sp/s
# Train: epoch 3, step 2790, inferLoss 0.21, cmpLoss 0.14, totalLoss 0.35, acc 0.910156, time 15.189 sp/s
# Train: epoch 3, step 2800, inferLoss 0.23, cmpLoss 0.14, totalLoss 0.37, acc 0.929688, time 13.195 sp/s
# Train: epoch 3, step 2810, inferLoss 0.25, cmpLoss 0.13, totalLoss 0.39, acc 0.894531, time 16.348 sp/s
# Train: epoch 3, step 2820, inferLoss 0.20, cmpLoss 0.13, totalLoss 0.33, acc 0.925781, time 14.587 sp/s
# Train: epoch 3, step 2830, inferLoss 0.24, cmpLoss 0.10, totalLoss 0.34, acc 0.914062, time 14.405 sp/s
# Train: epoch 3, step 2840, inferLoss 0.21, cmpLoss 0.11, totalLoss 0.32, acc 0.910156, time 15.484 sp/s
# Train: epoch 3, step 2850, inferLoss 0.21, cmpLoss 0.12, totalLoss 0.33, acc 0.917969, time 18.814 sp/s
# Train: epoch 3, step 2860, inferLoss 0.17, cmpLoss 0.13, totalLoss 0.30, acc 0.941406, time 14.871 sp/s
# Train: epoch 3, step 2870, inferLoss 0.20, cmpLoss 0.13, totalLoss 0.33, acc 0.933594, time 13.417 sp/s
# Train: epoch 3, step 2880, inferLoss 0.31, cmpLoss 0.15, totalLoss 0.46, acc 0.894531, time 17.141 sp/s
# Train: epoch 3, step 2890, inferLoss 0.22, cmpLoss 0.14, totalLoss 0.37, acc 0.906250, time 12.449 sp/s
# Train: epoch 3, step 2900, inferLoss 0.18, cmpLoss 0.12, totalLoss 0.30, acc 0.949219, time 12.328 sp/s
# Train: epoch 3, step 2910, inferLoss 0.19, cmpLoss 0.12, totalLoss 0.30, acc 0.933594, time 12.152 sp/s
# Train: epoch 3, step 2920, inferLoss 0.21, cmpLoss 0.15, totalLoss 0.36, acc 0.917969, time 15.738 sp/s
# Train: epoch 3, step 2930, inferLoss 0.20, cmpLoss 0.12, totalLoss 0.32, acc 0.933594, time 15.842 sp/s
# Train: epoch 3, step 2940, inferLoss 0.22, cmpLoss 0.12, totalLoss 0.34, acc 0.917969, time 17.011 sp/s
# Train: epoch 3, step 2950, inferLoss 0.18, cmpLoss 0.12, totalLoss 0.30, acc 0.945312, time 16.197 sp/s
# Train: epoch 3, step 2960, inferLoss 0.18, cmpLoss 0.11, totalLoss 0.29, acc 0.925781, time 16.348 sp/s
# Train: epoch 3, step 2970, inferLoss 0.18, cmpLoss 0.11, totalLoss 0.29, acc 0.921875, time 12.120 sp/s
# Train: epoch 3, step 2980, inferLoss 0.19, cmpLoss 0.10, totalLoss 0.29, acc 0.945312, time 16.683 sp/s
# Train: epoch 3, step 2990, inferLoss 0.18, cmpLoss 0.10, totalLoss 0.28, acc 0.925781, time 18.365 sp/s
# Train: epoch 3, step 3000, inferLoss 0.19, cmpLoss 0.12, totalLoss 0.31, acc 0.925781, time 16.365 sp/s
# Train: epoch 3, step 3010, inferLoss 0.25, cmpLoss 0.15, totalLoss 0.40, acc 0.906250, time 14.688 sp/s
# Train: epoch 3, step 3020, inferLoss 0.23, cmpLoss 0.11, totalLoss 0.34, acc 0.925781, time 15.582 sp/s
# Train: epoch 3, step 3030, inferLoss 0.19, cmpLoss 0.10, totalLoss 0.29, acc 0.929688, time 15.001 sp/s
# Train: epoch 3, step 3040, inferLoss 0.16, cmpLoss 0.10, totalLoss 0.27, acc 0.941406, time 16.410 sp/s
# Train: epoch 3, step 3050, inferLoss 0.24, cmpLoss 0.13, totalLoss 0.36, acc 0.894531, time 14.875 sp/s
# Train: epoch 3, step 3060, inferLoss 0.16, cmpLoss 0.09, totalLoss 0.26, acc 0.941406, time 61.713 sp/s
# Train: epoch 3, step 3070, inferLoss 0.17, cmpLoss 0.10, totalLoss 0.27, acc 0.941406, time 63.184 sp/s
# Train: epoch 3, step 3080, inferLoss 0.21, cmpLoss 0.12, totalLoss 0.32, acc 0.925781, time 67.901 sp/s
# Train: epoch 3, step 3090, inferLoss 0.24, cmpLoss 0.13, totalLoss 0.36, acc 0.917969, time 64.404 sp/s
# End of epoch 3
# ######### Save checkpoint: /home/macul/libraries/mk_utils/tf_spoof/output1/train_23/train_23_3.ckpt
# $$$$$$$$ Validation: epoch 3, accuracy is 0.817965
# Train: epoch 4, step 3100, inferLoss 0.22, cmpLoss 0.13, totalLoss 0.34, acc 0.906250, time 15.846 sp/s
# Train: epoch 4, step 3110, inferLoss 0.21, cmpLoss 0.12, totalLoss 0.33, acc 0.910156, time 16.118 sp/s
# Train: epoch 4, step 3120, inferLoss 0.30, cmpLoss 0.16, totalLoss 0.46, acc 0.890625, time 17.313 sp/s
# Train: epoch 4, step 3130, inferLoss 0.18, cmpLoss 0.13, totalLoss 0.31, acc 0.945312, time 14.855 sp/s
# Train: epoch 4, step 3140, inferLoss 0.13, cmpLoss 0.11, totalLoss 0.24, acc 0.941406, time 15.140 sp/s
# Train: epoch 4, step 3150, inferLoss 0.19, cmpLoss 0.11, totalLoss 0.29, acc 0.929688, time 15.683 sp/s
# Train: epoch 4, step 3160, inferLoss 0.18, cmpLoss 0.13, totalLoss 0.32, acc 0.914062, time 17.513 sp/s
# Train: epoch 4, step 3170, inferLoss 0.18, cmpLoss 0.10, totalLoss 0.29, acc 0.933594, time 16.066 sp/s
# Train: epoch 4, step 3180, inferLoss 0.17, cmpLoss 0.12, totalLoss 0.29, acc 0.925781, time 15.259 sp/s
# Train: epoch 4, step 3190, inferLoss 0.25, cmpLoss 0.17, totalLoss 0.42, acc 0.894531, time 13.970 sp/s
# Train: epoch 4, step 3200, inferLoss 0.16, cmpLoss 0.09, totalLoss 0.24, acc 0.949219, time 14.764 sp/s
# Train: epoch 4, step 3210, inferLoss 0.18, cmpLoss 0.11, totalLoss 0.29, acc 0.941406, time 17.184 sp/s
# Train: epoch 4, step 3220, inferLoss 0.24, cmpLoss 0.14, totalLoss 0.38, acc 0.929688, time 15.554 sp/s
# Train: epoch 4, step 3230, inferLoss 0.16, cmpLoss 0.09, totalLoss 0.24, acc 0.953125, time 15.347 sp/s
# Train: epoch 4, step 3240, inferLoss 0.18, cmpLoss 0.11, totalLoss 0.29, acc 0.929688, time 14.827 sp/s
# Train: epoch 4, step 3250, inferLoss 0.22, cmpLoss 0.13, totalLoss 0.34, acc 0.914062, time 12.220 sp/s
# Train: epoch 4, step 3260, inferLoss 0.24, cmpLoss 0.13, totalLoss 0.37, acc 0.910156, time 16.126 sp/s
# Train: epoch 4, step 3270, inferLoss 0.20, cmpLoss 0.15, totalLoss 0.35, acc 0.925781, time 16.331 sp/s
# Train: epoch 4, step 3280, inferLoss 0.23, cmpLoss 0.14, totalLoss 0.36, acc 0.910156, time 14.981 sp/s
# Train: epoch 4, step 3290, inferLoss 0.22, cmpLoss 0.11, totalLoss 0.34, acc 0.906250, time 13.775 sp/s
# Train: epoch 4, step 3300, inferLoss 0.20, cmpLoss 0.13, totalLoss 0.33, acc 0.921875, time 15.388 sp/s
# Train: epoch 4, step 3310, inferLoss 0.24, cmpLoss 0.14, totalLoss 0.38, acc 0.914062, time 14.783 sp/s
# Train: epoch 4, step 3320, inferLoss 0.18, cmpLoss 0.10, totalLoss 0.28, acc 0.929688, time 15.107 sp/s
# Train: epoch 4, step 3330, inferLoss 0.19, cmpLoss 0.14, totalLoss 0.33, acc 0.925781, time 16.838 sp/s
# Train: epoch 4, step 3340, inferLoss 0.23, cmpLoss 0.09, totalLoss 0.32, acc 0.914062, time 15.085 sp/s
# Train: epoch 4, step 3350, inferLoss 0.22, cmpLoss 0.12, totalLoss 0.34, acc 0.921875, time 13.697 sp/s
# Train: epoch 4, step 3360, inferLoss 0.26, cmpLoss 0.15, totalLoss 0.40, acc 0.921875, time 14.139 sp/s
# Train: epoch 4, step 3370, inferLoss 0.23, cmpLoss 0.15, totalLoss 0.38, acc 0.917969, time 15.050 sp/s
# Train: epoch 4, step 3380, inferLoss 0.18, cmpLoss 0.13, totalLoss 0.32, acc 0.957031, time 15.203 sp/s
# Train: epoch 4, step 3390, inferLoss 0.16, cmpLoss 0.11, totalLoss 0.26, acc 0.937500, time 17.613 sp/s
# Train: epoch 4, step 3400, inferLoss 0.23, cmpLoss 0.10, totalLoss 0.33, acc 0.906250, time 15.441 sp/s
# Train: epoch 4, step 3410, inferLoss 0.19, cmpLoss 0.12, totalLoss 0.32, acc 0.925781, time 14.238 sp/s
# Train: epoch 4, step 3420, inferLoss 0.21, cmpLoss 0.10, totalLoss 0.31, acc 0.921875, time 16.582 sp/s
# Train: epoch 4, step 3430, inferLoss 0.16, cmpLoss 0.11, totalLoss 0.27, acc 0.945312, time 18.481 sp/s
# Train: epoch 4, step 3440, inferLoss 0.25, cmpLoss 0.13, totalLoss 0.38, acc 0.906250, time 14.602 sp/s
# Train: epoch 4, step 3450, inferLoss 0.18, cmpLoss 0.11, totalLoss 0.29, acc 0.933594, time 14.420 sp/s
# Train: epoch 4, step 3460, inferLoss 0.17, cmpLoss 0.15, totalLoss 0.32, acc 0.933594, time 16.538 sp/s
# Train: epoch 4, step 3470, inferLoss 0.17, cmpLoss 0.12, totalLoss 0.29, acc 0.953125, time 17.631 sp/s
# Train: epoch 4, step 3480, inferLoss 0.22, cmpLoss 0.13, totalLoss 0.34, acc 0.917969, time 15.814 sp/s
# Train: epoch 4, step 3490, inferLoss 0.19, cmpLoss 0.11, totalLoss 0.30, acc 0.941406, time 14.772 sp/s
# Train: epoch 4, step 3500, inferLoss 0.23, cmpLoss 0.14, totalLoss 0.38, acc 0.910156, time 15.588 sp/s
# Train: epoch 4, step 3510, inferLoss 0.15, cmpLoss 0.12, totalLoss 0.27, acc 0.937500, time 15.664 sp/s
# Train: epoch 4, step 3520, inferLoss 0.17, cmpLoss 0.11, totalLoss 0.29, acc 0.925781, time 14.696 sp/s
# Train: epoch 4, step 3530, inferLoss 0.20, cmpLoss 0.12, totalLoss 0.32, acc 0.921875, time 15.609 sp/s
# Train: epoch 4, step 3540, inferLoss 0.18, cmpLoss 0.13, totalLoss 0.32, acc 0.929688, time 12.079 sp/s
# Train: epoch 4, step 3550, inferLoss 0.23, cmpLoss 0.15, totalLoss 0.38, acc 0.914062, time 18.123 sp/s
# Train: epoch 4, step 3560, inferLoss 0.19, cmpLoss 0.13, totalLoss 0.32, acc 0.929688, time 15.295 sp/s
# Train: epoch 4, step 3570, inferLoss 0.13, cmpLoss 0.11, totalLoss 0.24, acc 0.960938, time 13.933 sp/s
# Train: epoch 4, step 3580, inferLoss 0.19, cmpLoss 0.12, totalLoss 0.31, acc 0.921875, time 14.671 sp/s
# Train: epoch 4, step 3590, inferLoss 0.20, cmpLoss 0.12, totalLoss 0.32, acc 0.945312, time 16.161 sp/s
# Train: epoch 4, step 3600, inferLoss 0.18, cmpLoss 0.13, totalLoss 0.31, acc 0.941406, time 14.896 sp/s
# Train: epoch 4, step 3610, inferLoss 0.21, cmpLoss 0.12, totalLoss 0.33, acc 0.925781, time 15.582 sp/s
# Train: epoch 4, step 3620, inferLoss 0.16, cmpLoss 0.10, totalLoss 0.26, acc 0.941406, time 16.777 sp/s
# Train: epoch 4, step 3630, inferLoss 0.22, cmpLoss 0.08, totalLoss 0.30, acc 0.917969, time 12.790 sp/s
# Train: epoch 4, step 3640, inferLoss 0.21, cmpLoss 0.12, totalLoss 0.33, acc 0.925781, time 15.357 sp/s
# Train: epoch 4, step 3650, inferLoss 0.19, cmpLoss 0.11, totalLoss 0.30, acc 0.929688, time 17.689 sp/s
# Train: epoch 4, step 3660, inferLoss 0.24, cmpLoss 0.14, totalLoss 0.39, acc 0.914062, time 15.342 sp/s
# Train: epoch 4, step 3670, inferLoss 0.16, cmpLoss 0.11, totalLoss 0.26, acc 0.941406, time 14.547 sp/s
# Train: epoch 4, step 3680, inferLoss 0.14, cmpLoss 0.13, totalLoss 0.26, acc 0.953125, time 14.708 sp/s
# Train: epoch 4, step 3690, inferLoss 0.15, cmpLoss 0.11, totalLoss 0.26, acc 0.937500, time 15.287 sp/s
# Train: epoch 4, step 3700, inferLoss 0.23, cmpLoss 0.15, totalLoss 0.38, acc 0.914062, time 15.878 sp/s
# Train: epoch 4, step 3710, inferLoss 0.21, cmpLoss 0.12, totalLoss 0.33, acc 0.917969, time 17.379 sp/s
# Train: epoch 4, step 3720, inferLoss 0.17, cmpLoss 0.09, totalLoss 0.26, acc 0.929688, time 17.351 sp/s
# Train: epoch 4, step 3730, inferLoss 0.22, cmpLoss 0.12, totalLoss 0.34, acc 0.921875, time 17.255 sp/s
# Train: epoch 4, step 3740, inferLoss 0.15, cmpLoss 0.10, totalLoss 0.25, acc 0.953125, time 15.384 sp/s
# Train: epoch 4, step 3750, inferLoss 0.15, cmpLoss 0.09, totalLoss 0.23, acc 0.949219, time 15.147 sp/s
# Train: epoch 4, step 3760, inferLoss 0.21, cmpLoss 0.11, totalLoss 0.32, acc 0.917969, time 15.285 sp/s
# Train: epoch 4, step 3770, inferLoss 0.26, cmpLoss 0.11, totalLoss 0.36, acc 0.910156, time 16.490 sp/s
# Train: epoch 4, step 3780, inferLoss 0.15, cmpLoss 0.10, totalLoss 0.25, acc 0.949219, time 16.930 sp/s
# Train: epoch 4, step 3790, inferLoss 0.08, cmpLoss 0.08, totalLoss 0.16, acc 0.972656, time 17.212 sp/s
# Train: epoch 4, step 3800, inferLoss 0.19, cmpLoss 0.14, totalLoss 0.33, acc 0.933594, time 12.070 sp/s
# Train: epoch 4, step 3810, inferLoss 0.16, cmpLoss 0.09, totalLoss 0.25, acc 0.941406, time 12.440 sp/s
# Train: epoch 4, step 3820, inferLoss 0.23, cmpLoss 0.12, totalLoss 0.35, acc 0.925781, time 13.696 sp/s
# Train: epoch 4, step 3830, inferLoss 0.18, cmpLoss 0.12, totalLoss 0.30, acc 0.929688, time 45.203 sp/s
# Train: epoch 4, step 3840, inferLoss 0.13, cmpLoss 0.11, totalLoss 0.25, acc 0.941406, time 55.202 sp/s
# Train: epoch 4, step 3850, inferLoss 0.18, cmpLoss 0.11, totalLoss 0.29, acc 0.929688, time 50.612 sp/s
# Train: epoch 4, step 3860, inferLoss 0.14, cmpLoss 0.11, totalLoss 0.25, acc 0.941406, time 49.810 sp/s
# End of epoch 4
# ######### Save checkpoint: /home/macul/libraries/mk_utils/tf_spoof/output1/train_23/train_23_4.ckpt
# $$$$$$$$ Validation: epoch 4, accuracy is 0.813157
# Train: epoch 5, step 3870, inferLoss 0.25, cmpLoss 0.11, totalLoss 0.36, acc 0.894531, time 15.577 sp/s
# Train: epoch 5, step 3880, inferLoss 0.20, cmpLoss 0.14, totalLoss 0.34, acc 0.910156, time 14.372 sp/s
# Train: epoch 5, step 3890, inferLoss 0.19, cmpLoss 0.12, totalLoss 0.31, acc 0.917969, time 14.768 sp/s
# Train: epoch 5, step 3900, inferLoss 0.14, cmpLoss 0.10, totalLoss 0.24, acc 0.941406, time 14.614 sp/s
# Train: epoch 5, step 3910, inferLoss 0.19, cmpLoss 0.14, totalLoss 0.33, acc 0.933594, time 14.492 sp/s
# Train: epoch 5, step 3920, inferLoss 0.12, cmpLoss 0.11, totalLoss 0.23, acc 0.945312, time 16.488 sp/s
# Train: epoch 5, step 3930, inferLoss 0.18, cmpLoss 0.12, totalLoss 0.30, acc 0.929688, time 10.239 sp/s
# Train: epoch 5, step 3940, inferLoss 0.18, cmpLoss 0.12, totalLoss 0.30, acc 0.937500, time 9.879 sp/s
# Train: epoch 5, step 3950, inferLoss 0.19, cmpLoss 0.12, totalLoss 0.31, acc 0.921875, time 16.144 sp/s
# Train: epoch 5, step 3960, inferLoss 0.19, cmpLoss 0.11, totalLoss 0.31, acc 0.929688, time 15.988 sp/s
# Train: epoch 5, step 3970, inferLoss 0.14, cmpLoss 0.13, totalLoss 0.26, acc 0.949219, time 14.648 sp/s
# Train: epoch 5, step 3980, inferLoss 0.19, cmpLoss 0.12, totalLoss 0.31, acc 0.933594, time 14.108 sp/s
# Train: epoch 5, step 3990, inferLoss 0.17, cmpLoss 0.13, totalLoss 0.30, acc 0.941406, time 16.726 sp/s
# Train: epoch 5, step 4000, inferLoss 0.18, cmpLoss 0.11, totalLoss 0.29, acc 0.945312, time 16.123 sp/s
# Train: epoch 5, step 4010, inferLoss 0.20, cmpLoss 0.10, totalLoss 0.30, acc 0.925781, time 15.185 sp/s
# Train: epoch 5, step 4020, inferLoss 0.16, cmpLoss 0.12, totalLoss 0.28, acc 0.957031, time 9.596 sp/s
# Train: epoch 5, step 4030, inferLoss 0.14, cmpLoss 0.11, totalLoss 0.25, acc 0.945312, time 9.988 sp/s
# Train: epoch 5, step 4040, inferLoss 0.25, cmpLoss 0.12, totalLoss 0.38, acc 0.902344, time 11.452 sp/s
# Train: epoch 5, step 4050, inferLoss 0.18, cmpLoss 0.14, totalLoss 0.31, acc 0.917969, time 15.814 sp/s
# Train: epoch 5, step 4060, inferLoss 0.16, cmpLoss 0.11, totalLoss 0.27, acc 0.937500, time 9.116 sp/s
# Train: epoch 5, step 4070, inferLoss 0.16, cmpLoss 0.14, totalLoss 0.30, acc 0.941406, time 10.757 sp/s
# Train: epoch 5, step 4080, inferLoss 0.13, cmpLoss 0.11, totalLoss 0.23, acc 0.968750, time 11.943 sp/s
# Train: epoch 5, step 4090, inferLoss 0.11, cmpLoss 0.08, totalLoss 0.19, acc 0.972656, time 10.363 sp/s
# Train: epoch 5, step 4100, inferLoss 0.17, cmpLoss 0.12, totalLoss 0.29, acc 0.921875, time 10.586 sp/s
# Train: epoch 5, step 4110, inferLoss 0.15, cmpLoss 0.12, totalLoss 0.28, acc 0.949219, time 14.148 sp/s
# Train: epoch 5, step 4120, inferLoss 0.15, cmpLoss 0.13, totalLoss 0.28, acc 0.933594, time 14.290 sp/s
# Train: epoch 5, step 4130, inferLoss 0.14, cmpLoss 0.11, totalLoss 0.24, acc 0.964844, time 13.455 sp/s
# Train: epoch 5, step 4140, inferLoss 0.13, cmpLoss 0.12, totalLoss 0.24, acc 0.945312, time 12.705 sp/s
# Train: epoch 5, step 4150, inferLoss 0.17, cmpLoss 0.13, totalLoss 0.29, acc 0.941406, time 14.784 sp/s
# Train: epoch 5, step 4160, inferLoss 0.15, cmpLoss 0.10, totalLoss 0.25, acc 0.941406, time 16.406 sp/s
# Train: epoch 5, step 4170, inferLoss 0.14, cmpLoss 0.10, totalLoss 0.24, acc 0.957031, time 14.851 sp/s
# Train: epoch 5, step 4180, inferLoss 0.19, cmpLoss 0.12, totalLoss 0.31, acc 0.929688, time 15.270 sp/s
# Train: epoch 5, step 4190, inferLoss 0.15, cmpLoss 0.11, totalLoss 0.26, acc 0.933594, time 15.693 sp/s
# Train: epoch 5, step 4200, inferLoss 0.17, cmpLoss 0.15, totalLoss 0.32, acc 0.937500, time 14.914 sp/s
# Train: epoch 5, step 4210, inferLoss 0.22, cmpLoss 0.15, totalLoss 0.36, acc 0.933594, time 12.895 sp/s
# Train: epoch 5, step 4220, inferLoss 0.13, cmpLoss 0.10, totalLoss 0.23, acc 0.953125, time 15.769 sp/s
# Train: epoch 5, step 4230, inferLoss 0.13, cmpLoss 0.11, totalLoss 0.24, acc 0.957031, time 11.091 sp/s
# Train: epoch 5, step 4240, inferLoss 0.17, cmpLoss 0.10, totalLoss 0.27, acc 0.929688, time 14.845 sp/s
# Train: epoch 5, step 4250, inferLoss 0.18, cmpLoss 0.11, totalLoss 0.28, acc 0.949219, time 14.930 sp/s
# Train: epoch 5, step 4260, inferLoss 0.24, cmpLoss 0.15, totalLoss 0.39, acc 0.921875, time 12.405 sp/s
# Train: epoch 5, step 4270, inferLoss 0.19, cmpLoss 0.13, totalLoss 0.32, acc 0.921875, time 16.422 sp/s
# Train: epoch 5, step 4280, inferLoss 0.23, cmpLoss 0.11, totalLoss 0.34, acc 0.937500, time 16.224 sp/s
# Train: epoch 5, step 4290, inferLoss 0.15, cmpLoss 0.13, totalLoss 0.28, acc 0.949219, time 17.227 sp/s
# Train: epoch 5, step 4300, inferLoss 0.13, cmpLoss 0.11, totalLoss 0.24, acc 0.957031, time 14.531 sp/s
# Train: epoch 5, step 4310, inferLoss 0.12, cmpLoss 0.13, totalLoss 0.25, acc 0.964844, time 16.030 sp/s
# Train: epoch 5, step 4320, inferLoss 0.19, cmpLoss 0.12, totalLoss 0.30, acc 0.925781, time 15.420 sp/s
# Train: epoch 5, step 4330, inferLoss 0.12, cmpLoss 0.09, totalLoss 0.21, acc 0.957031, time 13.775 sp/s
# Train: epoch 5, step 4340, inferLoss 0.20, cmpLoss 0.12, totalLoss 0.31, acc 0.953125, time 15.586 sp/s
# Train: epoch 5, step 4350, inferLoss 0.16, cmpLoss 0.11, totalLoss 0.27, acc 0.937500, time 14.376 sp/s
# Train: epoch 5, step 4360, inferLoss 0.15, cmpLoss 0.10, totalLoss 0.24, acc 0.941406, time 16.254 sp/s
# Train: epoch 5, step 4370, inferLoss 0.16, cmpLoss 0.12, totalLoss 0.28, acc 0.941406, time 15.977 sp/s
# Train: epoch 5, step 4380, inferLoss 0.15, cmpLoss 0.12, totalLoss 0.26, acc 0.957031, time 13.992 sp/s
# Train: epoch 5, step 4390, inferLoss 0.12, cmpLoss 0.11, totalLoss 0.23, acc 0.957031, time 13.717 sp/s
# Train: epoch 5, step 4400, inferLoss 0.16, cmpLoss 0.10, totalLoss 0.26, acc 0.953125, time 14.104 sp/s
# Train: epoch 5, step 4410, inferLoss 0.21, cmpLoss 0.14, totalLoss 0.35, acc 0.937500, time 15.067 sp/s
# Train: epoch 5, step 4420, inferLoss 0.22, cmpLoss 0.16, totalLoss 0.38, acc 0.917969, time 12.832 sp/s
# Train: epoch 5, step 4430, inferLoss 0.11, cmpLoss 0.10, totalLoss 0.21, acc 0.960938, time 14.304 sp/s
# Train: epoch 5, step 4440, inferLoss 0.17, cmpLoss 0.11, totalLoss 0.28, acc 0.945312, time 16.049 sp/s
# Train: epoch 5, step 4450, inferLoss 0.22, cmpLoss 0.13, totalLoss 0.36, acc 0.910156, time 14.205 sp/s
# Train: epoch 5, step 4460, inferLoss 0.22, cmpLoss 0.12, totalLoss 0.34, acc 0.925781, time 15.269 sp/s
# Train: epoch 5, step 4470, inferLoss 0.20, cmpLoss 0.12, totalLoss 0.32, acc 0.917969, time 15.881 sp/s
# Train: epoch 5, step 4480, inferLoss 0.15, cmpLoss 0.10, totalLoss 0.24, acc 0.945312, time 17.909 sp/s
# Train: epoch 5, step 4490, inferLoss 0.11, cmpLoss 0.10, totalLoss 0.21, acc 0.957031, time 15.219 sp/s
# Train: epoch 5, step 4500, inferLoss 0.15, cmpLoss 0.09, totalLoss 0.24, acc 0.945312, time 15.823 sp/s
# Train: epoch 5, step 4510, inferLoss 0.14, cmpLoss 0.10, totalLoss 0.24, acc 0.933594, time 16.353 sp/s
# Train: epoch 5, step 4520, inferLoss 0.19, cmpLoss 0.12, totalLoss 0.31, acc 0.941406, time 14.404 sp/s
# Train: epoch 5, step 4530, inferLoss 0.20, cmpLoss 0.13, totalLoss 0.33, acc 0.929688, time 16.367 sp/s
# Train: epoch 5, step 4540, inferLoss 0.20, cmpLoss 0.10, totalLoss 0.31, acc 0.921875, time 16.371 sp/s
# ...
# Train: epoch 11, step 9200, inferLoss 0.07, cmpLoss 0.09, totalLoss 0.16, acc 0.960938, time 15.583 sp/s
# Train: epoch 11, step 9210, inferLoss 0.11, cmpLoss 0.11, totalLoss 0.22, acc 0.957031, time 15.887 sp/s
# Train: epoch 11, step 9220, inferLoss 0.07, cmpLoss 0.11, totalLoss 0.18, acc 0.968750, time 15.435 sp/s
# Train: epoch 11, step 9230, inferLoss 0.08, cmpLoss 0.09, totalLoss 0.17, acc 0.976562, time 13.623 sp/s
# Train: epoch 11, step 9240, inferLoss 0.12, cmpLoss 0.09, totalLoss 0.21, acc 0.964844, time 66.655 sp/s
# Train: epoch 11, step 9250, inferLoss 0.10, cmpLoss 0.09, totalLoss 0.19, acc 0.972656, time 65.384 sp/s
# Train: epoch 11, step 9260, inferLoss 0.05, cmpLoss 0.09, totalLoss 0.15, acc 0.984375, time 53.862 sp/s
# Train: epoch 11, step 9270, inferLoss 0.07, cmpLoss 0.11, totalLoss 0.18, acc 0.972656, time 62.921 sp/s
# End of epoch 11
# ######### Save checkpoint: /home/macul/libraries/mk_utils/tf_spoof/output1/train_23/train_23_11.ckpt
# $$$$$$$$ Validation: epoch 11, accuracy is 0.865321
# Train: epoch 12, step 9280, inferLoss 0.07, cmpLoss 0.08, totalLoss 0.14, acc 0.980469, time 14.693 sp/s
# Train: epoch 12, step 9290, inferLoss 0.08, cmpLoss 0.06, totalLoss 0.14, acc 0.972656, time 14.876 sp/s
# Train: epoch 12, step 9300, inferLoss 0.10, cmpLoss 0.07, totalLoss 0.17, acc 0.964844, time 16.518 sp/s
# Train: epoch 12, step 9310, inferLoss 0.09, cmpLoss 0.09, totalLoss 0.18, acc 0.972656, time 15.797 sp/s
# Train: epoch 12, step 9320, inferLoss 0.10, cmpLoss 0.09, totalLoss 0.19, acc 0.972656, time 10.987 sp/s
# Train: epoch 12, step 9330, inferLoss 0.10, cmpLoss 0.09, totalLoss 0.19, acc 0.964844, time 15.104 sp/s
# Train: epoch 12, step 9340, inferLoss 0.14, cmpLoss 0.11, totalLoss 0.26, acc 0.949219, time 16.569 sp/s
# Train: epoch 12, step 9350, inferLoss 0.10, cmpLoss 0.08, totalLoss 0.18, acc 0.960938, time 14.935 sp/s
# Train: epoch 12, step 9360, inferLoss 0.11, cmpLoss 0.11, totalLoss 0.22, acc 0.964844, time 15.821 sp/s
# Train: epoch 12, step 9370, inferLoss 0.09, cmpLoss 0.08, totalLoss 0.17, acc 0.964844, time 15.660 sp/s
# Train: epoch 12, step 9380, inferLoss 0.08, cmpLoss 0.07, totalLoss 0.15, acc 0.960938, time 13.253 sp/s
# Train: epoch 12, step 9390, inferLoss 0.08, cmpLoss 0.08, totalLoss 0.16, acc 0.960938, time 13.969 sp/s
# Train: epoch 12, step 9400, inferLoss 0.06, cmpLoss 0.09, totalLoss 0.15, acc 0.976562, time 15.783 sp/s
# Train: epoch 12, step 9410, inferLoss 0.08, cmpLoss 0.08, totalLoss 0.17, acc 0.972656, time 16.526 sp/s
# Train: epoch 12, step 9420, inferLoss 0.06, cmpLoss 0.07, totalLoss 0.13, acc 0.980469, time 16.598 sp/s
# Train: epoch 12, step 9430, inferLoss 0.11, cmpLoss 0.10, totalLoss 0.21, acc 0.953125, time 13.169 sp/s
# Train: epoch 12, step 9440, inferLoss 0.05, cmpLoss 0.09, totalLoss 0.14, acc 0.988281, time 11.006 sp/s
# Train: epoch 12, step 9450, inferLoss 0.13, cmpLoss 0.09, totalLoss 0.22, acc 0.953125, time 14.845 sp/s
# Train: epoch 12, step 9460, inferLoss 0.08, cmpLoss 0.09, totalLoss 0.17, acc 0.960938, time 11.840 sp/s
# Train: epoch 12, step 9470, inferLoss 0.09, cmpLoss 0.08, totalLoss 0.17, acc 0.968750, time 10.420 sp/s
# Train: epoch 12, step 9480, inferLoss 0.06, cmpLoss 0.08, totalLoss 0.14, acc 0.976562, time 14.716 sp/s
# Train: epoch 12, step 9490, inferLoss 0.07, cmpLoss 0.08, totalLoss 0.15, acc 0.984375, time 16.757 sp/s
# Train: epoch 12, step 9500, inferLoss 0.14, cmpLoss 0.09, totalLoss 0.22, acc 0.957031, time 15.077 sp/s
# Train: epoch 12, step 9510, inferLoss 0.11, cmpLoss 0.09, totalLoss 0.20, acc 0.968750, time 14.354 sp/s
# Train: epoch 12, step 9520, inferLoss 0.08, cmpLoss 0.07, totalLoss 0.15, acc 0.976562, time 15.250 sp/s
# Train: epoch 12, step 9530, inferLoss 0.12, cmpLoss 0.12, totalLoss 0.24, acc 0.949219, time 15.858 sp/s
# Train: epoch 12, step 9540, inferLoss 0.12, cmpLoss 0.11, totalLoss 0.22, acc 0.957031, time 14.944 sp/s
# Train: epoch 12, step 9550, inferLoss 0.06, cmpLoss 0.08, totalLoss 0.13, acc 0.980469, time 13.967 sp/s
# Train: epoch 12, step 9560, inferLoss 0.08, cmpLoss 0.13, totalLoss 0.21, acc 0.972656, time 13.576 sp/s
# Train: epoch 12, step 9570, inferLoss 0.09, cmpLoss 0.06, totalLoss 0.15, acc 0.960938, time 16.121 sp/s
# Train: epoch 12, step 9580, inferLoss 0.07, cmpLoss 0.10, totalLoss 0.16, acc 0.980469, time 15.051 sp/s
# Train: epoch 12, step 9590, inferLoss 0.06, cmpLoss 0.08, totalLoss 0.14, acc 0.984375, time 15.721 sp/s
# Train: epoch 12, step 9600, inferLoss 0.08, cmpLoss 0.07, totalLoss 0.15, acc 0.968750, time 15.856 sp/s
# Train: epoch 12, step 9610, inferLoss 0.09, cmpLoss 0.07, totalLoss 0.16, acc 0.976562, time 17.370 sp/s
# Train: epoch 12, step 9620, inferLoss 0.09, cmpLoss 0.08, totalLoss 0.17, acc 0.972656, time 14.917 sp/s
# Train: epoch 12, step 9630, inferLoss 0.11, cmpLoss 0.10, totalLoss 0.21, acc 0.953125, time 14.231 sp/s
# Train: epoch 12, step 9640, inferLoss 0.07, cmpLoss 0.09, totalLoss 0.15, acc 0.972656, time 14.432 sp/s
# Train: epoch 12, step 9650, inferLoss 0.10, cmpLoss 0.08, totalLoss 0.18, acc 0.964844, time 15.267 sp/s
# Train: epoch 12, step 9660, inferLoss 0.09, cmpLoss 0.08, totalLoss 0.17, acc 0.972656, time 15.144 sp/s
# Train: epoch 12, step 9670, inferLoss 0.07, cmpLoss 0.07, totalLoss 0.15, acc 0.984375, time 14.193 sp/s
# Train: epoch 12, step 9680, inferLoss 0.08, cmpLoss 0.07, totalLoss 0.15, acc 0.976562, time 14.422 sp/s
# Train: epoch 12, step 9690, inferLoss 0.07, cmpLoss 0.07, totalLoss 0.14, acc 0.972656, time 12.978 sp/s
# Train: epoch 12, step 9700, inferLoss 0.12, cmpLoss 0.09, totalLoss 0.21, acc 0.964844, time 13.998 sp/s
# Train: epoch 12, step 9710, inferLoss 0.10, cmpLoss 0.09, totalLoss 0.19, acc 0.964844, time 16.912 sp/s
# Train: epoch 12, step 9720, inferLoss 0.09, cmpLoss 0.09, totalLoss 0.18, acc 0.976562, time 14.998 sp/s
# Train: epoch 12, step 9730, inferLoss 0.08, cmpLoss 0.09, totalLoss 0.17, acc 0.964844, time 14.802 sp/s
# Train: epoch 12, step 9740, inferLoss 0.09, cmpLoss 0.10, totalLoss 0.19, acc 0.972656, time 14.258 sp/s
# Train: epoch 12, step 9750, inferLoss 0.14, cmpLoss 0.09, totalLoss 0.24, acc 0.941406, time 13.412 sp/s
# Train: epoch 12, step 9760, inferLoss 0.05, cmpLoss 0.09, totalLoss 0.14, acc 0.980469, time 14.441 sp/s
# Train: epoch 12, step 9770, inferLoss 0.13, cmpLoss 0.09, totalLoss 0.22, acc 0.949219, time 14.148 sp/s
# Train: epoch 12, step 9780, inferLoss 0.06, cmpLoss 0.08, totalLoss 0.13, acc 0.984375, time 15.388 sp/s
# Train: epoch 12, step 9790, inferLoss 0.08, cmpLoss 0.08, totalLoss 0.16, acc 0.964844, time 13.829 sp/s
# Train: epoch 12, step 9800, inferLoss 0.09, cmpLoss 0.08, totalLoss 0.18, acc 0.972656, time 12.141 sp/s
# Train: epoch 12, step 9810, inferLoss 0.08, cmpLoss 0.07, totalLoss 0.15, acc 0.976562, time 18.135 sp/s
# Train: epoch 12, step 9820, inferLoss 0.06, cmpLoss 0.10, totalLoss 0.15, acc 0.976562, time 13.899 sp/s
# Train: epoch 12, step 9830, inferLoss 0.09, cmpLoss 0.08, totalLoss 0.17, acc 0.972656, time 17.640 sp/s
# Train: epoch 12, step 9840, inferLoss 0.07, cmpLoss 0.10, totalLoss 0.17, acc 0.984375, time 13.852 sp/s
# Train: epoch 12, step 9850, inferLoss 0.06, cmpLoss 0.10, totalLoss 0.17, acc 0.972656, time 14.750 sp/s
# Train: epoch 12, step 9860, inferLoss 0.07, cmpLoss 0.08, totalLoss 0.15, acc 0.980469, time 17.291 sp/s
# Train: epoch 12, step 9870, inferLoss 0.07, cmpLoss 0.09, totalLoss 0.15, acc 0.988281, time 13.538 sp/s
# Train: epoch 12, step 9880, inferLoss 0.09, cmpLoss 0.10, totalLoss 0.19, acc 0.972656, time 15.904 sp/s
# Train: epoch 12, step 9890, inferLoss 0.07, cmpLoss 0.07, totalLoss 0.14, acc 0.980469, time 14.725 sp/s
# Train: epoch 12, step 9900, inferLoss 0.08, cmpLoss 0.08, totalLoss 0.15, acc 0.976562, time 14.111 sp/s
# Train: epoch 12, step 9910, inferLoss 0.09, cmpLoss 0.09, totalLoss 0.18, acc 0.960938, time 14.370 sp/s
# Train: epoch 12, step 9920, inferLoss 0.08, cmpLoss 0.08, totalLoss 0.16, acc 0.972656, time 16.215 sp/s
# Train: epoch 12, step 9930, inferLoss 0.10, cmpLoss 0.09, totalLoss 0.19, acc 0.976562, time 16.534 sp/s
# Train: epoch 12, step 9940, inferLoss 0.08, cmpLoss 0.08, totalLoss 0.16, acc 0.972656, time 15.213 sp/s
# Train: epoch 12, step 9950, inferLoss 0.05, cmpLoss 0.08, totalLoss 0.13, acc 0.976562, time 14.259 sp/s
# Train: epoch 12, step 9960, inferLoss 0.13, cmpLoss 0.09, totalLoss 0.22, acc 0.949219, time 15.390 sp/s
# Train: epoch 12, step 9970, inferLoss 0.13, cmpLoss 0.11, totalLoss 0.24, acc 0.964844, time 15.883 sp/s
# Train: epoch 12, step 9980, inferLoss 0.08, cmpLoss 0.10, totalLoss 0.18, acc 0.976562, time 17.970 sp/s
# Train: epoch 12, step 9990, inferLoss 0.09, cmpLoss 0.12, totalLoss 0.20, acc 0.968750, time 13.227 sp/s
# Train: epoch 12, step 10000, inferLoss 0.06, cmpLoss 0.09, totalLoss 0.15, acc 0.988281, time 16.792 sp/s
# Train: epoch 12, step 10010, inferLoss 0.05, cmpLoss 0.09, totalLoss 0.14, acc 0.988281, time 57.400 sp/s
# Train: epoch 12, step 10020, inferLoss 0.08, cmpLoss 0.07, totalLoss 0.15, acc 0.972656, time 60.203 sp/s
# Train: epoch 12, step 10030, inferLoss 0.12, cmpLoss 0.09, totalLoss 0.20, acc 0.964844, time 63.735 sp/s
# Train: epoch 12, step 10040, inferLoss 0.06, cmpLoss 0.09, totalLoss 0.15, acc 0.988281, time 61.772 sp/s
# End of epoch 12
# ######### Save checkpoint: /home/macul/libraries/mk_utils/tf_spoof/output1/train_23/train_23_12.ckpt
# $$$$$$$$ Validation: epoch 12, accuracy is 0.852818
# Train: epoch 13, step 10050, inferLoss 0.08, cmpLoss 0.08, totalLoss 0.16, acc 0.968750, time 17.302 sp/s
# Train: epoch 13, step 10060, inferLoss 0.07, cmpLoss 0.06, totalLoss 0.14, acc 0.968750, time 14.635 sp/s
# Train: epoch 13, step 10070, inferLoss 0.11, cmpLoss 0.08, totalLoss 0.19, acc 0.957031, time 14.898 sp/s
# Train: epoch 13, step 10080, inferLoss 0.05, cmpLoss 0.07, totalLoss 0.12, acc 0.988281, time 13.723 sp/s
# Train: epoch 13, step 10090, inferLoss 0.10, cmpLoss 0.09, totalLoss 0.20, acc 0.957031, time 15.841 sp/s
# Train: epoch 13, step 10100, inferLoss 0.15, cmpLoss 0.09, totalLoss 0.24, acc 0.949219, time 15.308 sp/s
# Train: epoch 13, step 10110, inferLoss 0.09, cmpLoss 0.08, totalLoss 0.17, acc 0.976562, time 15.871 sp/s
# Train: epoch 13, step 10120, inferLoss 0.13, cmpLoss 0.09, totalLoss 0.22, acc 0.945312, time 12.805 sp/s
# Train: epoch 13, step 10130, inferLoss 0.13, cmpLoss 0.10, totalLoss 0.23, acc 0.953125, time 14.835 sp/s
# Train: epoch 13, step 10140, inferLoss 0.04, cmpLoss 0.08, totalLoss 0.12, acc 0.992188, time 14.849 sp/s
# Train: epoch 13, step 10150, inferLoss 0.08, cmpLoss 0.07, totalLoss 0.15, acc 0.972656, time 15.645 sp/s
# Train: epoch 13, step 10160, inferLoss 0.07, cmpLoss 0.08, totalLoss 0.15, acc 0.976562, time 15.887 sp/s
# Train: epoch 13, step 10170, inferLoss 0.10, cmpLoss 0.09, totalLoss 0.19, acc 0.968750, time 15.319 sp/s
# Train: epoch 13, step 10180, inferLoss 0.06, cmpLoss 0.08, totalLoss 0.14, acc 0.980469, time 15.817 sp/s
# Train: epoch 13, step 10190, inferLoss 0.06, cmpLoss 0.08, totalLoss 0.14, acc 0.972656, time 13.680 sp/s
# Train: epoch 13, step 10200, inferLoss 0.05, cmpLoss 0.07, totalLoss 0.12, acc 0.984375, time 14.969 sp/s
# Train: epoch 13, step 10210, inferLoss 0.07, cmpLoss 0.07, totalLoss 0.14, acc 0.980469, time 14.926 sp/s
# Train: epoch 13, step 10220, inferLoss 0.08, cmpLoss 0.09, totalLoss 0.17, acc 0.968750, time 14.836 sp/s
# Train: epoch 13, step 10230, inferLoss 0.06, cmpLoss 0.09, totalLoss 0.16, acc 0.984375, time 15.425 sp/s
# Train: epoch 13, step 10240, inferLoss 0.04, cmpLoss 0.08, totalLoss 0.12, acc 0.984375, time 14.129 sp/s
# Train: epoch 13, step 10250, inferLoss 0.12, cmpLoss 0.09, totalLoss 0.22, acc 0.968750, time 14.593 sp/s
# Train: epoch 13, step 10260, inferLoss 0.08, cmpLoss 0.08, totalLoss 0.16, acc 0.972656, time 15.858 sp/s
# Train: epoch 13, step 10270, inferLoss 0.11, cmpLoss 0.09, totalLoss 0.20, acc 0.957031, time 14.122 sp/s
# Train: epoch 13, step 10280, inferLoss 0.07, cmpLoss 0.11, totalLoss 0.18, acc 0.964844, time 13.243 sp/s
# Train: epoch 13, step 10290, inferLoss 0.14, cmpLoss 0.10, totalLoss 0.24, acc 0.953125, time 13.400 sp/s
# Train: epoch 13, step 10300, inferLoss 0.07, cmpLoss 0.08, totalLoss 0.14, acc 0.976562, time 15.054 sp/s
# Train: epoch 13, step 10310, inferLoss 0.10, cmpLoss 0.10, totalLoss 0.20, acc 0.964844, time 15.806 sp/s
# Train: epoch 13, step 10320, inferLoss 0.05, cmpLoss 0.08, totalLoss 0.13, acc 0.976562, time 14.965 sp/s
# Train: epoch 13, step 10330, inferLoss 0.08, cmpLoss 0.10, totalLoss 0.18, acc 0.972656, time 14.387 sp/s
# Train: epoch 13, step 10340, inferLoss 0.12, cmpLoss 0.08, totalLoss 0.20, acc 0.972656, time 10.526 sp/s
# Train: epoch 13, step 10350, inferLoss 0.08, cmpLoss 0.08, totalLoss 0.16, acc 0.964844, time 18.112 sp/s
# Train: epoch 13, step 10360, inferLoss 0.12, cmpLoss 0.08, totalLoss 0.20, acc 0.964844, time 15.895 sp/s
# Train: epoch 13, step 10370, inferLoss 0.12, cmpLoss 0.13, totalLoss 0.25, acc 0.968750, time 12.856 sp/s
# Train: epoch 13, step 10380, inferLoss 0.11, cmpLoss 0.08, totalLoss 0.19, acc 0.972656, time 11.218 sp/s
# Train: epoch 13, step 10390, inferLoss 0.09, cmpLoss 0.09, totalLoss 0.19, acc 0.972656, time 15.087 sp/s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-f13da4672063> in <module>
# ----> 1 SpoofVal.train_net(-1)
#
# ~/libraries/mk_utils/spoofing_ld_conv/SpoofLineConvTf.py in train_net(self, start_epoch)
#     313                     start = time.time()
#     314                     images1_train, labels1_train = sess.run(next_element_train)
# --> 315                     images2_train, labels2_train = sess.run(next_element_train)
#     316                     #images_train, images_show, labels_train = sess.run(next_element_train) # for dataset debug
#     317                     if img_verify_flag: # for dataset debug
#
# ~/tf_venv/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/tf_venv/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~/tf_venv/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/tf_venv/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# ~/tf_venv/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/tf_venv/lib/python3.5/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
SpoofVal = SpoofLineConvTf(config)
start_epoch = 8
copyfile(config.CFG_PATH+'/net_config_ld_conv.py', os.path.sep.join([SpoofVal.checkpointsPath,'net_config_ld_conv_{}.py'.format(start_epoch+1)]))

# %%
SpoofVal.train_net(start_epoch)

# %%
# RESTART KERNEL AND RUN FROM HERE TO DO VALIDATION

# %%
import tensorflow as tf
import numpy as np
import os
from os.path import isdir
from os import mkdir
from shutil import copyfile
import time
from PIL import Image
import pickle
from spoofing_lbp.SpoofDspTf import SpoofDspTf

# %%
ckpt_num = 9
prefix = 'train_1'
import sys
sys.path.append('/home/macul/libraries/mk_utils/tf_spoof/output/{}'.format(prefix))
import net_config_0 as config
config.BASE_PATH = '/media/macul/black/spoof_db/train_test_all/tfrecord'
config.CFG_PATH = '/home/macul/libraries/mk_utils/tf_spoof/config'
config.OUT_PATH = '/home/macul/libraries/mk_utils/tf_spoof/output'
config.VAL_REC = os.path.sep.join([config.BASE_PATH, "validation.tfrecords"])

SpoofVal = SpoofDspTf(config)

rst_val = SpoofVal.validate_net(ckpt_num, '/home/macul/test.pkl')

# %%
# RESTART KERNEL AND RUN FROM HERE TO DO EVALUATION

# %%
import tensorflow as tf
import numpy as np
import os
from os.path import isdir
from os import mkdir
from shutil import copyfile
import time
from PIL import Image
import pickle
from spoofing_lbp.SpoofDspTf import SpoofDspTf

# %%
ckpt_num = 9
prefix = 'train_1'
import sys
sys.path.append('/home/macul/libraries/mk_utils/tf_spoof/output/{}'.format(prefix))
import net_config_0 as config
config.BASE_PATH = '/media/macul/black/spoof_db/train_test_all/tfrecord'
config.CFG_PATH = '/home/macul/libraries/mk_utils/tf_spoof/config'
config.OUT_PATH = '/home/macul/libraries/mk_utils/tf_spoof/output'

SpoofVal = SpoofDspTf(config)

sess, embeddings, logit, pred, acc = SpoofVal.deploy_net(ckpt_num)

# %%
import cv2

# %%
img = cv2.imread('/home/macul/figure_1-5.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
rst = SpoofVal.eval(img, sess, pred)

# %%
print(rst[0])

# %%
a.shape

# %%
a.reshape([1,-1])

# %%
a.shape

# %%
a[np.newaxis,:].shape

# %%
a
