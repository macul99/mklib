# %%
import tensorflow as tf
import numpy as np
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0,"
from os.path import isdir
from os import mkdir
from shutil import copyfile
import time
from PIL import Image
import pickle
from spoofing_ld_conv.SpoofLineConvTf import SpoofLineConvTf
from mklib.nn.tfnet.tfresnet import TfResNet
from tensorflow.keras.regularizers import l1, l2
from tensorflow.core.protobuf import config_pb2
#import sys
#sys.path.append('/home/macul/libraries/mk_utils/mklib/nn/tfnet/')
#sys.path.append('/home/macul/libraries/mk_utils/mklib/nn/tfloss/')
#sys.path.append('/home/macul/libraries/mk_utils/tf_spoof/')
#sys.path.append('/home/macul/libraries/mk_utils/spoofing_ld_conv/')
from tf_spoof.dgxout.train_2 import net_config_ld_conv_0 as config
#from tf_spoof.config import net_config_ld_conv as config
config.OUT_PATH='/home/macul/libraries/mk_utils/tf_spoof/dgxout'

# %%
SpoofVal = SpoofLineConvTf(config)

# %%
sess, _, _ = SpoofVal.deploy_net(7)
# Out:
# INFO:tensorflow:Restoring parameters from /home/macul/libraries/mk_utils/tf_spoof/dgxout/train_2/train_2_7.ckpt

# %%
names1 = [n.name for n in tf.get_default_graph().as_graph_def().node]

# %%
print(names1)
# Out:
# ['label1', 'image1', 'label2', 'image2', 'label_val', 'image_val', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel/Initializer/truncated_normal/shape', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel/Initializer/truncated_normal/mean', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel/Initializer/truncated_normal/stddev', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel/Initializer/truncated_normal/TruncatedNormal', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel/Initializer/truncated_normal/mul', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel/Initializer/truncated_normal', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel/Assign', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel/read', 'SpoofLdConvNet/conv_stem/stem_conv1/dilation_rate', 'SpoofLdConvNet/conv_stem/stem_conv1/Conv2D', 'SpoofLdConvNet/conv_stem/stem_bn2/gamma/Initializer/ones', 'SpoofLdConvNet/conv_stem/stem_bn2/gamma', 'SpoofLdConvNet/conv_stem/stem_bn2/gamma/Assign', 'SpoofLdConvNet/conv_stem/stem_bn2/gamma/read', 'SpoofLdConvNet/conv_stem/stem_bn2/beta/Initializer/zeros', 'SpoofLdConvNet/conv_stem/stem_bn2/beta', 'SpoofLdConvNet/conv_stem/stem_bn2/beta/Assign', 'SpoofLdConvNet/conv_stem/stem_bn2/beta/read', 'SpoofLdConvNet/conv_stem/stem_bn2/moving_mean/Initializer/zeros', 'SpoofLdConvNet/conv_stem/stem_bn2/moving_mean', 'SpoofLdConvNet/conv_stem/stem_bn2/moving_mean/Assign', 'SpoofLdConvNet/conv_stem/stem_bn2/moving_mean/read', 'SpoofLdConvNet/conv_stem/stem_bn2/moving_variance/Initializer/ones', 'SpoofLdConvNet/conv_stem/stem_bn2/moving_variance', 'SpoofLdConvNet/conv_stem/stem_bn2/moving_variance/Assign', 'SpoofLdConvNet/conv_stem/stem_bn2/moving_variance/read', 'SpoofLdConvNet/conv_stem/stem_bn2/FusedBatchNorm', 'SpoofLdConvNet/conv_stem/stem_bn2/Const', 'SpoofLdConvNet/conv_stem/stem_relu1/alpha/Initializer/zeros/shape_as_tensor', 'SpoofLdConvNet/conv_stem/stem_relu1/alpha/Initializer/zeros/Const', 'SpoofLdConvNet/conv_stem/stem_relu1/alpha/Initializer/zeros', 'SpoofLdConvNet/conv_stem/stem_relu1/alpha', 'SpoofLdConvNet/conv_stem/stem_relu1/alpha/IsInitialized/VarIsInitializedOp', 'SpoofLdConvNet/conv_stem/stem_relu1/alpha/Assign', 'SpoofLdConvNet/conv_stem/stem_relu1/alpha/Read/ReadVariableOp', 'SpoofLdConvNet/conv_stem/stem_relu1/Relu', 'SpoofLdConvNet/conv_stem/stem_relu1/ReadVariableOp', 'SpoofLdConvNet/conv_stem/stem_relu1/Neg', 'SpoofLdConvNet/conv_stem/stem_relu1/Neg_1', 'SpoofLdConvNet/conv_stem/stem_relu1/Relu_1', 'SpoofLdConvNet/conv_stem/stem_relu1/mul', 'SpoofLdConvNet/conv_stem/stem_relu1/add', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/gamma/Initializer/ones', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/gamma', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/gamma/Assign', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/gamma/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/beta/Initializer/zeros', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/beta', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/beta/Assign', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/beta/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/moving_mean/Initializer/zeros', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/moving_mean', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/moving_mean/Assign', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/moving_mean/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/moving_variance/Initializer/ones', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/moving_variance', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/moving_variance/Assign', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/moving_variance/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/FusedBatchNorm', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/Const', 'SpoofLdConvNet/conv_stem/stage1_unit1/conv1/kernel/Initializer/truncated_normal/shape', 'SpoofLdConvNet/conv_stem/stage1_unit1/conv1/kernel/Initializer/truncated_normal/mean', 'SpoofLdConvNet/conv_stem/stage1_unit1/conv1/kernel/Initializer/truncated_normal/stddev', 'SpoofLdConvNet/conv_stem/stage1_unit1/conv1/kernel/Initializer/truncated_normal/TruncatedNorm ...

# %%
print(names)
# Out:
# ['label1', 'image1', 'label2', 'image2', 'label_val', 'image_val', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel/Initializer/truncated_normal/shape', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel/Initializer/truncated_normal/mean', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel/Initializer/truncated_normal/stddev', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel/Initializer/truncated_normal/TruncatedNormal', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel/Initializer/truncated_normal/mul', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel/Initializer/truncated_normal', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel/Assign', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel/read', 'SpoofLdConvNet/conv_stem/stem_conv1/dilation_rate', 'SpoofLdConvNet/conv_stem/stem_conv1/Conv2D', 'SpoofLdConvNet/conv_stem/stem_bn2/gamma/Initializer/ones', 'SpoofLdConvNet/conv_stem/stem_bn2/gamma', 'SpoofLdConvNet/conv_stem/stem_bn2/gamma/Assign', 'SpoofLdConvNet/conv_stem/stem_bn2/gamma/read', 'SpoofLdConvNet/conv_stem/stem_bn2/beta/Initializer/zeros', 'SpoofLdConvNet/conv_stem/stem_bn2/beta', 'SpoofLdConvNet/conv_stem/stem_bn2/beta/Assign', 'SpoofLdConvNet/conv_stem/stem_bn2/beta/read', 'SpoofLdConvNet/conv_stem/stem_bn2/moving_mean/Initializer/zeros', 'SpoofLdConvNet/conv_stem/stem_bn2/moving_mean', 'SpoofLdConvNet/conv_stem/stem_bn2/moving_mean/Assign', 'SpoofLdConvNet/conv_stem/stem_bn2/moving_mean/read', 'SpoofLdConvNet/conv_stem/stem_bn2/moving_variance/Initializer/ones', 'SpoofLdConvNet/conv_stem/stem_bn2/moving_variance', 'SpoofLdConvNet/conv_stem/stem_bn2/moving_variance/Assign', 'SpoofLdConvNet/conv_stem/stem_bn2/moving_variance/read', 'SpoofLdConvNet/conv_stem/stem_bn2/FusedBatchNorm', 'SpoofLdConvNet/conv_stem/stem_bn2/Const', 'SpoofLdConvNet/conv_stem/stem_relu1/alpha/Initializer/zeros/shape_as_tensor', 'SpoofLdConvNet/conv_stem/stem_relu1/alpha/Initializer/zeros/Const', 'SpoofLdConvNet/conv_stem/stem_relu1/alpha/Initializer/zeros', 'SpoofLdConvNet/conv_stem/stem_relu1/alpha', 'SpoofLdConvNet/conv_stem/stem_relu1/alpha/IsInitialized/VarIsInitializedOp', 'SpoofLdConvNet/conv_stem/stem_relu1/alpha/Assign', 'SpoofLdConvNet/conv_stem/stem_relu1/alpha/Read/ReadVariableOp', 'SpoofLdConvNet/conv_stem/stem_relu1/Relu', 'SpoofLdConvNet/conv_stem/stem_relu1/ReadVariableOp', 'SpoofLdConvNet/conv_stem/stem_relu1/Neg', 'SpoofLdConvNet/conv_stem/stem_relu1/Neg_1', 'SpoofLdConvNet/conv_stem/stem_relu1/Relu_1', 'SpoofLdConvNet/conv_stem/stem_relu1/mul', 'SpoofLdConvNet/conv_stem/stem_relu1/add', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/gamma/Initializer/ones', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/gamma', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/gamma/Assign', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/gamma/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/beta/Initializer/zeros', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/beta', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/beta/Assign', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/beta/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/moving_mean/Initializer/zeros', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/moving_mean', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/moving_mean/Assign', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/moving_mean/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/moving_variance/Initializer/ones', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/moving_variance', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/moving_variance/Assign', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/moving_variance/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/FusedBatchNorm', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/Const', 'SpoofLdConvNet/conv_stem/stage1_unit1/conv1/kernel/Initializer/truncated_normal/shape', 'SpoofLdConvNet/conv_stem/stage1_unit1/conv1/kernel/Initializer/truncated_normal/mean', 'SpoofLdConvNet/conv_stem/stage1_unit1/conv1/kernel/Initializer/truncated_normal/stddev', 'SpoofLdConvNet/conv_stem/stage1_unit1/conv1/kernel/Initializer/truncated_normal/TruncatedNorm ...

# %%
saver = tf.train.Saver()

# %%
ckpt_filename = SpoofVal.config.PREFIX+'_{:d}'.format(20) + '.ckpt'
ckpt_filename = os.path.join(SpoofVal.checkpointsPath, ckpt_filename)

# %%
ckpt_filename
# Out:
# '/home/macul/libraries/mk_utils/tf_spoof/dgxout/train_2/train_2_20.ckpt'

# %%
saver.save(sess, ckpt_filename)
# Out:
# '/home/macul/libraries/mk_utils/tf_spoof/dgxout/train_2/train_2_20.ckpt'

# %%
sess, img_ph, pred, _, _ = SpoofVal.load_pb('/home/macul/Projects/ego_prj/spoofing_cnn_tf/models/clf.pb')

# %%
import cv2
im = cv2.imread('/home/macul/Projects/ego_prj/spoofing_cnn_tf/test_r480640_10_119_imgneg.jpg')
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
bbox = [172, 255, 172+143-1, 255+142-1]
imc = SpoofVal.preprocess_img_test(im, bbox)
rst = SpoofVal.eval_pb2(imc, sess, img_ph, pred)
print(rst)

# %%
np.zeros([1,2,3])

# %%
face_crop = SpoofVal.preprocess_img(frame, [p1[0], p1[1], p2[0], p2[1]])

# %%
import cv2
im = cv2.imread('/home/macul/Projects/ego_prj/spoofing_cnn_tf/test_r480640_10_119_imgneg.jpg')
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
bbox = [172, 255, 172+143-1, 255+142-1]

# %%
imc = SpoofVal.preprocess_img_test(im, bbox)
#imc = cv2.resize(imc, (16,16))

# %%
-0.20703125, -0.91796875, -0.34765625, -0.95703125, -0.55780029, -0.92697906, -0.32553864, -0.94591522, -0.09765625, -0.94140625, -0.027160645, -0.95233917, -0.38085938, -0.98583984, -0.2097702, -0.98273468, -0.09765625, -0.93132782, -0.09765625, -0.93359375, -0.41015625, -0.97265625, -0.60546875, -0.9519043, -0.47729492, -0.96728516, -0.66796875, -0.93359375, -0.41015625, -0.97265625, -0.41015625, -0.97265625;
 -0.12890625, -0.90234375, -0.19140625, -0.92578125, -0.74902344, -0.86889648, -0.86128235, -0.98261261, -0.76025391, -0.97192383, -0.072944641, -0.79052734, -0.066650391, -0.78588867, -0.043045044, -0.8553009, -0.06640625, -0.76879883, -0.066650391, -0.73486328, -0.074707031, -0.73901367, -0.065429688, -0.72241211, -0.05859375, -0.88925934, -0.72265625, -0.91015625, -0.60546875, -0.96484375, -0.60546875, -0.96484375;

# %%
-0.20703125, -0.91796875, -0.34765625, -0.95703125, -0.52734375, -0.93359375, -0.29296875, -0.95703125, -0.09765625, -0.94140625, -0.05859375, -0.95703125, -0.05859375, -0.98046875, -0.17578125, -0.98046875, -0.09765625, -0.93359375, -0.09765625, -0.93359375, -0.41015625, -0.97265625, -0.52734375, -0.96484375, -0.52734375, -0.97265625, -0.66796875, -0.93359375, -0.29296875, -0.98046875, -0.41015625, -0.97265625;
 -0.12890625, -0.90234375, -0.19140625, -0.92578125, -0.73828125, -0.87109375, -0.76171875, -0.98828125, -0.76171875, -0.97265625, -0.07421875, -0.79296875, -0.06640625, -0.78515625, -0.04296875, -0.83984375, -0.06640625, -0.76171875, -0.06640625, -0.73828125, -0.07421875, -0.73828125, -0.06640625, -0.72265625, -0.05859375, -0.88671875, -0.72265625, -0.91015625, -0.60546875, -0.96484375, -0.60546875, -0.96484375;

# %%
print(imc)

# %%
names = SpoofVal.get_output_name()
# Out:
# INFO:tensorflow:Restoring parameters from /home/macul/libraries/mk_utils/tf_spoof/dgxout/train_2/train_2_0.ckpt

# %%
print(names)
# Out:
# ['label1', 'image1', 'label2', 'image2', 'label_val', 'image_val', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel/Initializer/truncated_normal/shape', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel/Initializer/truncated_normal/mean', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel/Initializer/truncated_normal/stddev', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel/Initializer/truncated_normal/TruncatedNormal', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel/Initializer/truncated_normal/mul', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel/Initializer/truncated_normal', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel/Assign', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel/read', 'SpoofLdConvNet/conv_stem/stem_conv1/dilation_rate', 'SpoofLdConvNet/conv_stem/stem_conv1/Conv2D', 'SpoofLdConvNet/conv_stem/stem_bn2/gamma/Initializer/ones', 'SpoofLdConvNet/conv_stem/stem_bn2/gamma', 'SpoofLdConvNet/conv_stem/stem_bn2/gamma/Assign', 'SpoofLdConvNet/conv_stem/stem_bn2/gamma/read', 'SpoofLdConvNet/conv_stem/stem_bn2/beta/Initializer/zeros', 'SpoofLdConvNet/conv_stem/stem_bn2/beta', 'SpoofLdConvNet/conv_stem/stem_bn2/beta/Assign', 'SpoofLdConvNet/conv_stem/stem_bn2/beta/read', 'SpoofLdConvNet/conv_stem/stem_bn2/moving_mean/Initializer/zeros', 'SpoofLdConvNet/conv_stem/stem_bn2/moving_mean', 'SpoofLdConvNet/conv_stem/stem_bn2/moving_mean/Assign', 'SpoofLdConvNet/conv_stem/stem_bn2/moving_mean/read', 'SpoofLdConvNet/conv_stem/stem_bn2/moving_variance/Initializer/ones', 'SpoofLdConvNet/conv_stem/stem_bn2/moving_variance', 'SpoofLdConvNet/conv_stem/stem_bn2/moving_variance/Assign', 'SpoofLdConvNet/conv_stem/stem_bn2/moving_variance/read', 'SpoofLdConvNet/conv_stem/stem_bn2/FusedBatchNorm', 'SpoofLdConvNet/conv_stem/stem_bn2/Const', 'SpoofLdConvNet/conv_stem/stem_relu1/alpha/Initializer/zeros/shape_as_tensor', 'SpoofLdConvNet/conv_stem/stem_relu1/alpha/Initializer/zeros/Const', 'SpoofLdConvNet/conv_stem/stem_relu1/alpha/Initializer/zeros', 'SpoofLdConvNet/conv_stem/stem_relu1/alpha', 'SpoofLdConvNet/conv_stem/stem_relu1/alpha/IsInitialized/VarIsInitializedOp', 'SpoofLdConvNet/conv_stem/stem_relu1/alpha/Assign', 'SpoofLdConvNet/conv_stem/stem_relu1/alpha/Read/ReadVariableOp', 'SpoofLdConvNet/conv_stem/stem_relu1/Relu', 'SpoofLdConvNet/conv_stem/stem_relu1/ReadVariableOp', 'SpoofLdConvNet/conv_stem/stem_relu1/Neg', 'SpoofLdConvNet/conv_stem/stem_relu1/Neg_1', 'SpoofLdConvNet/conv_stem/stem_relu1/Relu_1', 'SpoofLdConvNet/conv_stem/stem_relu1/mul', 'SpoofLdConvNet/conv_stem/stem_relu1/add', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/gamma/Initializer/ones', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/gamma', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/gamma/Assign', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/gamma/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/beta/Initializer/zeros', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/beta', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/beta/Assign', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/beta/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/moving_mean/Initializer/zeros', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/moving_mean', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/moving_mean/Assign', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/moving_mean/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/moving_variance/Initializer/ones', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/moving_variance', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/moving_variance/Assign', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/moving_variance/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/FusedBatchNorm', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/Const', 'SpoofLdConvNet/conv_stem/stage1_unit1/conv1/kernel/Initializer/truncated_normal/shape', 'SpoofLdConvNet/conv_stem/stage1_unit1/conv1/kernel/Initializer/truncated_normal/mean', 'SpoofLdConvNet/conv_stem/stage1_unit1/conv1/kernel/Initializer/truncated_normal/stddev', 'SpoofLdConvNet/conv_stem/stage1_unit1/conv1/kernel/Initializer/truncated_normal/TruncatedNorm ...

# %%
SpoofVal.save_pb(7)
# Out:
# INFO:tensorflow:Restoring parameters from /home/macul/libraries/mk_utils/tf_spoof/dgxout/train_2/train_2_7.ckpt
# INFO:tensorflow:Froze 124 variables.
# INFO:tensorflow:Converted 124 variables to const ops.

# %%
sess, image_in, pred_out, names, graph_nodes = SpoofVal.load_pb('/home/macul/libraries/mk_utils/tf_spoof/dgxout/train_2/train_2_7.pb')
# Out:
# load graph
# WARNING:tensorflow:From /home/macul/libraries/mk_utils/spoofing_ld_conv/SpoofLineConvTf.py:743: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.

# %%
print(names)
# Out:
# ['image_val', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel', 'SpoofLdConvNet/conv_stem/stem_conv1/kernel/read', 'SpoofLdConvNet/conv_stem/stem_conv1/Conv2D', 'SpoofLdConvNet/conv_stem/stem_bn2/gamma', 'SpoofLdConvNet/conv_stem/stem_bn2/gamma/read', 'SpoofLdConvNet/conv_stem/stem_bn2/beta', 'SpoofLdConvNet/conv_stem/stem_bn2/beta/read', 'SpoofLdConvNet/conv_stem/stem_bn2/moving_mean', 'SpoofLdConvNet/conv_stem/stem_bn2/moving_mean/read', 'SpoofLdConvNet/conv_stem/stem_bn2/moving_variance', 'SpoofLdConvNet/conv_stem/stem_bn2/moving_variance/read', 'SpoofLdConvNet/conv_stem/stem_bn2/FusedBatchNorm', 'SpoofLdConvNet/conv_stem/stem_relu1/alpha', 'SpoofLdConvNet/conv_stem/stem_relu1/Relu', 'SpoofLdConvNet/conv_stem/stem_relu1/ReadVariableOp', 'SpoofLdConvNet/conv_stem/stem_relu1/Neg', 'SpoofLdConvNet/conv_stem/stem_relu1/Neg_1', 'SpoofLdConvNet/conv_stem/stem_relu1/Relu_1', 'SpoofLdConvNet/conv_stem/stem_relu1/mul', 'SpoofLdConvNet/conv_stem/stem_relu1/add', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/gamma', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/gamma/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/beta', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/beta/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/moving_mean', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/moving_mean/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/moving_variance', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/moving_variance/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn1/FusedBatchNorm', 'SpoofLdConvNet/conv_stem/stage1_unit1/conv1/kernel', 'SpoofLdConvNet/conv_stem/stage1_unit1/conv1/kernel/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/conv1/Conv2D', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn2/gamma', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn2/gamma/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn2/beta', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn2/beta/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn2/moving_mean', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn2/moving_mean/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn2/moving_variance', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn2/moving_variance/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn2/FusedBatchNorm', 'SpoofLdConvNet/conv_stem/stage1_unit1/prelu2/alpha', 'SpoofLdConvNet/conv_stem/stage1_unit1/prelu2/Relu', 'SpoofLdConvNet/conv_stem/stage1_unit1/prelu2/ReadVariableOp', 'SpoofLdConvNet/conv_stem/stage1_unit1/prelu2/Neg', 'SpoofLdConvNet/conv_stem/stage1_unit1/prelu2/Neg_1', 'SpoofLdConvNet/conv_stem/stage1_unit1/prelu2/Relu_1', 'SpoofLdConvNet/conv_stem/stage1_unit1/prelu2/mul', 'SpoofLdConvNet/conv_stem/stage1_unit1/prelu2/add', 'SpoofLdConvNet/conv_stem/stage1_unit1/conv2/kernel', 'SpoofLdConvNet/conv_stem/stage1_unit1/conv2/kernel/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/conv2/Conv2D', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn4/gamma', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn4/gamma/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn4/beta', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn4/beta/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn4/moving_mean', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn4/moving_mean/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn4/moving_variance', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn4/moving_variance/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/bn4/FusedBatchNorm', 'SpoofLdConvNet/conv_stem/stage1_unit1/convr/kernel', 'SpoofLdConvNet/conv_stem/stage1_unit1/convr/kernel/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/convr/Conv2D', 'SpoofLdConvNet/conv_stem/stage1_unit1/bnr/gamma', 'SpoofLdConvNet/conv_stem/stage1_unit1/bnr/gamma/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/bnr/beta', 'SpoofLdConvNet/conv_stem/stage1_unit1/bnr/beta/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/bnr/moving_mean', 'SpoofLdConvNet/conv_stem/stage1_unit1/bnr/moving_mean/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/bnr/moving_variance', 'SpoofLdConvNet/conv_stem/stage1_unit1/bnr/moving_variance/read', 'SpoofLdConvNet/conv_stem/stage1_unit1/bnr/FusedBatchNorm', 'SpoofLdConvNet/conv_stem/ ...

# %%
weights = tf.get_variable(name='embedding_weights', shape=(2,3),
                                  initializer=tf.contrib.layers.xavier_initializer(uniform=False), dtype=tf.float32, trainable=True)
embedding_norm = tf.math.l2_normalize([[0., 0., 0., 0., 0., 0., 0., 0., 0.]], axis=1)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    a1=sess.run(weights)
    a2=sess.run(embedding_norm)
    print(a2,a1)

# %%
img_ph1 = tf.placeholder(name='data1',shape=[1,112,112,3], dtype=tf.float32)
label_ph1 = tf.placeholder(name='label1',shape=[1,], dtype=tf.int64)
config1 = {'Regularizer': config.Regularizer, 'Activation': config.Activation,
           'Arc_margin_scale': 64.0, 'Arc_margin_angle': 0.5,
           'loss_type': 'arc'}

embedding, logit, inference_loss, pred, acc  = TfResNet.build_with_loss(img_ph1, label_ph1, 3, 128, [3], [64,32], training=True, loss_config=config1, initializer=config.Initializer, scope='test2')

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    sess.run(tf.local_variables_initializer())
    embedding1, logit1, inference_loss1, pred1, acc1 = sess.run([embedding, logit, inference_loss, pred, acc], feed_dict={img_ph1: np.random.rand(1,112,112,3), label_ph1:[2]})

# %%
print(embedding1, logit1, inference_loss1, pred1, acc1)

# %%
spfLC = SpoofLineConvTf(config)

# %%
#spfLC.test_dataset()

# %%
iterator, next_element = spfLC.build_dataset(config.TRAIN_REC, 1, config.NUM_CLASSES, 
                                             target_size=config.Image_Height, fill_value=config.Fill_Value, 
                                             ratio_h=config.Fill_Ratio_H, ratio_w=config.Fill_Ratio_W, 
                                             training=True)
logit, inference_loss, pred, acc, embeddings, _, _= spfLC.build_net(training=True, reuse=None)

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    sess.run(iterator.initializer)
    images_train, labels_train = sess.run(next_element)
    images_train2, labels_train2 = sess.run(next_element)
    feed_dict = {spfLC.images1_ph: images_train, spfLC.labels1_ph: labels_train,
                 spfLC.images2_ph: images_train2, spfLC.labels2_ph: labels_train2}
    logit_t, inference_loss_t, pred_t, acc_t, embeddings_t = \
                        sess.run([logit, inference_loss, pred, acc, embeddings],
                                  feed_dict=feed_dict,
                                  options=config_pb2.RunOptions(report_tensor_allocations_upon_oom=True))

# %%
print(logit_t)
print(inference_loss_t)
print(pred_t)
print(acc_t)

# %%
embeddings1, logit1, inference_loss1, pred1, acc1 = spfLC.build_net(training=False, reuse=True)

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    sess.run(iterator.initializer)
    images_train, labels_train = sess.run(next_element)
    feed_dict = {spfLC.images_val_ph: images_train, spfLC.labels_val_ph: labels_train}
    logit1_t, inference_loss1_t, pred1_t, acc1_t, embeddings1_t = \
                        sess.run([embeddings1, logit1, inference_loss1, pred1, acc1],
                                  feed_dict=feed_dict,
                                  options=config_pb2.RunOptions(report_tensor_allocations_upon_oom=True))

# %%
print(logit1_t)
print(inference_loss1_t)
print(pred1_t)
print(acc1_t)

# %%
with tf.Session() as sess:
    sess.run(iterator.initializer)
    images_train, labels_train = sess.run(next_element)
    
    print(images_train, labels_train)

# %%
print(images_train.shape)

# %%
img = Image.fromarray(images_train[0,...].astype(np.uint8), 'RGB')
img.show()

# %%
img_ph = tf.placeholder(name='data',shape=[2,224,224,3], dtype=tf.float32)
img_ph1 = tf.placeholder(name='data1',shape=[2,224,224,3], dtype=tf.float32)

act3_1= TfResNet.build_modules(img_ph, 512, [1,1,1,1,1], [8,8,8,16,16,8], training=True, initializer=Initializer, scope='test1')
act3_2= TfResNet.build_modules(img_ph, 512, [1,1,1,1,1], [8,8,8,16,16,8], training=True, initializer=Initializer, scope='test1', reuse=True)
act3=tf.concat([act3_1,act3_2],3)

act3_3=tf.layers.conv2d( inputs=act3, padding='same', kernel_size=(3, 3), strides=(2, 2), filters=32,use_bias=False, name='stem_conv1')
act3_4=tf.layers.conv2d( inputs=act3_3, padding='same', kernel_size=(3, 3), strides=(2, 2), filters=16,use_bias=False, name='stem_conv2')
act3_5=tf.layers.conv2d( inputs=act3_4, padding='valid', kernel_size=(2, 2), strides=(1, 1), filters=1,use_bias=False, name='stem_conv3')
act3_5=tf.squeeze(act3_5)

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    act = sess.run(act3_5, feed_dict={img_ph: np.random.rand(2,224,224,3),img_ph1: np.random.rand(2,224,224,3)})
    
print(act)

# %%
img_ph = tf.placeholder(name='data',shape=[1,112,112,3], dtype=tf.float32)

embedding0, act2_1= TfResNet.build_embedding(img_ph, 512, [3], [64,32], training=True, initializer=Initializer, scope='test1')

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    emb,act2 = sess.run([embedding0,act2_1], feed_dict={img_ph: np.random.rand(1,112,112,3)})

# %%
print(emb[0],act2)

# %%
label_ph2 = tf.placeholder(name='label2',shape=[3,], dtype=tf.int64)
label_ph3 = tf.placeholder(name='label3',shape=[3,], dtype=tf.int64)

label_x = tf.cast(tf.equal(label_ph2,label_ph3), tf.int64)

# %%
with tf.Session() as sess:
    lb = sess.run(label_x, feed_dict={label_ph2:[1,1,1], label_ph3:[1,0,2]})
print(lb)

# %%
img_ph1 = tf.placeholder(name='data1',shape=[2,112,112,3], dtype=tf.float32)
img = tf.image.resize_bilinear(img_ph1, (64, 64))
with tf.Session() as sess:
    emb= sess.run(img, feed_dict={img_ph1: np.random.rand(2,112,112,3)})
print(emb.shape)

# %%
mask = np.ones([1,112,112,3])
mask[0,0:10,0:10,:] = 0
mask_tf=tf.convert_to_tensor(mask, dtype=tf.float32)

img_ph1 = tf.placeholder(name='data1',shape=[1,112,112,3], dtype=tf.float32)
img_mask = tf.multiply(mask_tf, img_ph1)
with tf.Session() as sess:
    emb= sess.run(img_mask, feed_dict={img_ph1: np.random.rand(1,112,112,3)})
print(mask_tf.dtype)

# %%
def img_fill_center(img, fill_value=127, ratio_h=0.4, ratio_w=0.35):

    def fill_c(img, fill_value, ratio_h, ratio_w):
        im = img.copy()
        b,h,w,c = img.shape
        cp_h = int(h*ratio_h)
        cp_w = int(w*ratio_w)
        cp_x = int((w-cp_w)/2)
        cp_y = int((h-cp_h)/2)
        im[:,cp_y:cp_y+cp_h,cp_x:cp_x+cp_w,:] = fill_value

        return im

    return tf.cast(tf.py_func(fill_c, [img, fill_value, ratio_h, ratio_w], tf.float32),tf.float32)

a=np.random.rand(1,112,112,3)
img_ph1 = tf.placeholder(name='data1',shape=[1,112,112,3], dtype=tf.float32)
img_mask=img_fill_center(img_ph1)
with tf.Session() as sess:
    emb= sess.run(img_mask, feed_dict={img_ph1: a})
print(np.sum(emb==127))

# %%
print(emb[0,33,:,0])

# %%
a = np.ones([1,112,112,3])
a[0,0:10,0:10,:] = 0
at=tf.convert_to_tensor(a)
with tf.Session() as sess:
    emb= sess.run(at)
print(emb)

# %%
a=100
b=tf.cast(a,tf.int64)
with tf.Session() as sess:
    bb = sess.run(b)
print(bb)

# %%
tfSpoofLd = TfSpoofLd()

# %%
sess, lines_in, pred_out, names, graph_nodes = tfSpoofLd.load_pb(pb_path)

# %%
prediction = tfSpoofLd.eval(sess, lines_in, pred_out)
print(prediction)

# %%
print(nodes)

# %%
print(names)

# %%
np.random.rand(1,2)

# %%
a=np.array([[[[9.999995e-01, 5.332333e-07]]]])

# %%
a.shape

# %%
np.squeeze(a)

# %%
a_ph = tf.placeholder(name='a',shape=[2,3], dtype=tf.int64)
b_ph = tf.placeholder(name='b',shape=[2,1], dtype=tf.int64)
c=tf.multiply(b_ph,a_ph)

# %%
with tf.Session() as sess:
    rst = sess.run(c, feed_dict={a_ph: np.array([[1,1,1],[1,1,1]]), b_ph: np.array([[0],[1]])})
    print(rst)
